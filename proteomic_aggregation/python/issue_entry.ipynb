# %%
import requests
from io import StringIO
import pandas as pd
import aggregation_functions as agg_func
func=agg_func.import_relative_module("nmdc_api", "../../NOM_visualizations/python/nmdc_api.py")

# %% [markdown]
# On friday I decided it made more sense for the flow of the notebook to go from biosample (searching using study id) down to processed sample and then filter processed samples that cna be analyzed together using in manifest. But for some reason this traversal is giving me 32 results instead of the 33 i get when i filter by in manifest slot. I went backwards using the four outputs missing from my new traversal (but present from in manifest traversal) so i have all the ids and info, but everything looks to be correct. so i dont know hwy im missing it.

# %%
stegan_biosample_info = func.get_next_results(collection='biosample_set',\
                       filter='{"associated_studies":"nmdc:sty-11-aygzgv51"}',\
                        max_page_size=100,fields='id,name,description')

# %%
#omics generation records for these biosamples
data_generation=func.get_id_results(newest_results=stegan_biosample_info,\
                                    id_field="id",\
                                    query_collection="data_generation_set",\
                                    match_id_field="has_input",\
                                    query_fields="has_input,has_output,associated_studies,analyte_category,type")

#data_generation=pd.DataFrame(data_generation)[pd.DataFrame(data_generation)['analyte_category']=='metaproteome'].reset_index(drop=True)
display(pd.DataFrame(data_generation)[pd.DataFrame(data_generation)['analyte_category']=='metaproteome'].reset_index(drop=True))
#data_generation=data_generation.to_dict(orient='records')

#raw files produced by these omics generation records
rawfiles=func.get_id_results(newest_results=data_generation,\
                                id_field="has_output",\
                                query_collection="data_object_set",\
                                match_id_field="id",\
                                query_fields="id,data_object_type,url")

#display(pd.DataFrame(rawfiles))

#analysis workflows that were run using these raw files
workflow=func.get_id_results(newest_results=rawfiles,\
                                id_field="id",\
                                query_collection="workflow_execution_set",\
                                match_id_field="has_input",\
                                query_fields="has_output,has_input")
#display(pd.DataFrame(workflow))

#results from these workflows
workflow_outputs=func.get_id_results(newest_results=workflow,\
                                id_field="has_output",\
                                query_collection="data_object_set",\
                                match_id_field="id",\
                                query_fields="")

#display(pd.DataFrame(workflow_outputs))

#what different data files are there for each processed data set?
#pd.DataFrame(workflow_outputs)[['data_object_type','description']].value_counts()
# Out:
#                         id                   type               has_input  \
# 0   nmdc:omprc-11-07jg9980  nmdc:MassSpectrometry  [nmdc:bsm-13-2yga6857]
# 1   nmdc:omprc-11-1zw3ez08  nmdc:MassSpectrometry  [nmdc:bsm-13-sepcxd06]
# 2   nmdc:omprc-11-3a8sb985  nmdc:MassSpectrometry  [nmdc:bsm-13-xvf06c81]
# 3   nmdc:omprc-11-3mbk2q18  nmdc:MassSpectrometry  [nmdc:bsm-13-mvpx4z13]
# 4   nmdc:omprc-11-3wsn0s07  nmdc:MassSpectrometry  [nmdc:bsm-13-hxr5ks11]
# 5   nmdc:omprc-11-4a8d5j62  nmdc:MassSpectrometry  [nmdc:bsm-13-an5fyr03]
# 6   nmdc:omprc-11-4xyj5b22  nmdc:MassSpectrometry  [nmdc:bsm-13-drp3nj25]
# 7   nmdc:omprc-11-5svnja50  nmdc:MassSpectrometry  [nmdc:bsm-13-zms1jq91]
# 8   nmdc:omprc-11-5yj1dd81  nmdc:MassSpectrometry  [nmdc:bsm-13-9qwsvm77]
# 9   nmdc:omprc-11-6vefsz40  nmdc:MassSpectrometry  [nmdc:bsm-13-5bfhqy53]
# 10  nmdc:omprc-11-6ygpws48  nmdc:MassSpectrometry  [nmdc:bsm-13-yjp2dx65]
# 11  nmdc:omprc-11-793vc240  nmdc:MassSpectrometry  [nmdc:bsm-13-khnf9f29]
# 12  nmdc:omprc-11-87bntc15  nmdc:MassSpectrometry  [nmdc:bsm-13-8e1rjf10]
# 13  nmdc:omprc-11-970xc869  nmdc:MassSpectrometry  [nmdc:bsm-13-dd9rmc16]
# 14  nmdc:omprc-11-a45ncw83  nmdc:MassSpectrometry  [nmdc:bsm-13-vqk1y255]
# 15  nmdc:omprc-11-av32k402  nmdc:MassSpectrometry  [nmdc:bsm-13-13145k83]
# 16  nmdc:omprc-11-bnrw2r65  nmdc:MassSpectrometry  [nmdc:bsm-13-3dt9xs73]
# 17  nmdc:omprc-11-cty5ax47  nmdc:MassSpectrometry  [nmdc:bsm-13-kcdh3w94]
# 18  nmdc:omprc-11-dhmqjx65  nmdc:MassSpectrometry  [nmdc:bsm-13-937ebx72]
# 19  nmdc:omprc-11-eft0mp09  nmdc:MassSpectrometry  [nmdc:bsm-13-3pvn5d70]
# 20  nmdc:omprc-11-evnx4a83  nmdc:MassSpectrometry  [nmdc:bsm-13-as680w10]
# 21  nmdc:omprc-11-gp3et725  nmdc:MassSpectrometry  [nmdc:bsm-13-hvpzqc38]
# 22  nmdc:omprc-11-hs4k0380  nmdc:MassSpectrometry  [nmdc:bsm-13-amdcp906]
# 23  nmdc:omprc-11-m926kb51  nmdc:MassSpectrometry  [nmdc:bsm-13-fs4zf767]
# 24  nmdc:omprc-11-mkam5c55  nmdc:MassSpectrometry  [nmdc:bsm-13-2fw5j754]
# 25  nmdc:omprc-11-qn780a74  nmdc:MassSpectrometry  [nmdc:bsm-13-1p0tct86]
# 26  nmdc:omprc-11-qxt63828  nmdc:MassSpectrometry  [nmdc:bsm-13-kem2v355]
# 27  nmdc:omprc-11-r0hzrh88  nmdc:MassSpectrometry  [nmdc:bsm-13-0jw5n594]
# 28  nmdc:omprc-11-shwfms36  nmdc:MassSpectrometry  [nmdc:bsm-13-6naxpa52]
# 29  nmdc:omprc-11-sqhqwq89  nmdc:MassSpectrometry  [nmdc:bsm-13-c0xjg970]
# 30  nmdc:omprc-11-w693w477  nmdc:MassSpectrometry  [nmdc:bsm-13-ay11wa90]
# 31  nmdc:omprc-11-yx0zqm32  nmdc:MassSpectrometry  [nmdc:bsm-13-peafgc08]
#
#                  has_output analyte_category      associated_studies
# 0   [nmdc:dobj-11-d4qdbq55]     metaproteome  [nmdc:sty-11-aygzgv51]
# 1   [nmdc:dobj-11-6n49rm30]     metaproteome  [nmdc:sty-11-aygzgv51]
# 2   [nmdc:dobj-11-5bdpnq27]     metaproteome  [nmdc:sty-11-aygzgv51]
# 3   [nmdc:dobj-11-r03nbg69]     metaproteome  [nmdc:sty-11-aygzgv51]
# 4   [nmdc:dobj-11-ap9bg907]     metaproteome  [nmdc:sty-11-aygzgv51]
# 5   [nmdc:dobj-11-vs45wb84]     metaproteome  [nmdc:sty-11-aygzgv51]
# 6   [nmdc:dobj-11-t07ryb39]     metaproteome  [nmdc:sty-11-aygzgv51]
# 7   [nmdc:dobj-11-agsd2f41]     metaproteome  [nmdc:sty-11-aygzgv51]
# 8   [nmdc:dobj-11-tgsasn46]     metaproteome  [nmdc:sty-11-aygzgv51]
# 9   [nmdc:dobj-11-mz0d0076]     metaproteome  [nmdc:sty-11-aygzgv51]
# 10  [nmdc:dobj-11-zd25ft61]     metaproteome  [nmdc:sty-11-aygzgv51]
# 11  [nmdc:dobj-11-76xdx588]     metaproteome  [nmdc:sty-11-aygzgv51]
# 12  [nmdc:dobj-11-ms76kj12]     metaproteome  [nmdc:sty-11-aygzgv51]
# 13  [nmdc:dobj-11-zv2mke38]     metaproteome  [nmdc:sty-11-aygzgv51]
# 14  [nmdc:dobj-11-tezmee57]     metaproteome  [nmdc:sty-11-aygzgv51]
# 15  [nmdc:dobj-11-k9e5nm54]     metaproteome  [nmdc:sty-11-aygzgv51]
# 16  [nmdc:dobj-11-wgqh5s45]     metaproteome  [nmdc:sty-11-aygzgv51]
# 17  [nmdc:dobj-11-rrmg7w64]     metaproteome  [nmdc:sty-11-aygzgv51]
# 18  [nmdc:dobj-11-wtsjqv17]     metaproteome  [nmdc:sty-11-aygzgv51]
# 19  [nmdc:dobj-11-erc74h90]     metaproteome  [nmdc:sty-11-aygzgv51]
# 20  [nmdc:dobj-11-mzxj8743]     metaproteome  [nmdc:sty-11-aygzgv51]
# 21  [nmdc:dobj-11-xmvv4977]     metaproteome  [nmdc:sty-11-aygzgv51]
# 22  [nmdc:dobj-11-e2309414]     metaproteome  [nmdc:sty-11-aygzgv51]
# 23  [nmdc:dobj-11-xy4hz717]     metaproteome  [nmdc:sty-11-aygzgv51]
# 24  [nmdc:dobj-11-hp2vmj63]     metaproteome  [nmdc:sty-11-aygzgv51]
# 25  [nmdc:dobj-11-xvmb4058]     metaproteome  [nmdc:sty-11-aygzgv51]
# 26  [nmdc:dobj-11-rqssmk98]     metaproteome  [nmdc:sty-11-aygzgv51]
# 27  [nmdc:dobj-11-4kwfhk83]     metaproteome  [nmdc:sty-11-aygzgv51]
# 28  [nmdc:dobj-11-fn371w16]     metaproteome  [nmdc:sty-11-aygzgv51]
# 29  [nmdc:dobj-11-32dr2y07]     metaproteome  [nmdc:sty-11-aygzgv51]
# 30  [nmdc:dobj-11-35xc2b05]     metaproteome  [nmdc:sty-11-aygzgv51]
# 31  [nmdc:dobj-11-qtxceg35]     metaproteome  [nmdc:sty-11-aygzgv51]

# %%
#workflow outputs when using in manifest
workflow_outputs_via_inmanifest=func.get_next_results(collection='data_object_set',\
                       filter='{"in_manifest":"nmdc:manif-11-7796sg87"}',\
                        max_page_size=100,fields='')

missing_workflow = func.get_id_results(newest_results=workflow_outputs_via_inmanifest,\
                                id_field="id",\
                                query_collection="workflow_execution_set",\
                                match_id_field="has_output",\
                                query_fields="has_output,has_input")

#display(pd.DataFrame(missing_workflow))

missing_rawfiles = func.get_id_results(newest_results=missing_workflow,\
                                id_field="has_input",\
                                query_collection="data_object_set",\
                                match_id_field="id",\
                                query_fields="id,data_object_type,url")
#display(pd.DataFrame(missing_rawfiles))

missing_datageneration = func.get_id_results(newest_results=missing_rawfiles,\
                                id_field="id",\
                                query_collection="data_generation_set",\
                                match_id_field="has_output",\
                                query_fields="has_input,has_output,associated_studies,analyte_category,type")
#display(pd.DataFrame(missing_datageneration)[pd.DataFrame(missing_datageneration)['analyte_category']=='metaproteome'].reset_index(drop=True))


#missing
datagen_metaproteome_manifest = pd.DataFrame(missing_datageneration)[pd.DataFrame(missing_datageneration)['analyte_category']=='metaproteome'].reset_index(drop=True)
datagen_metaproteome_traversal = pd.DataFrame(data_generation)[pd.DataFrame(data_generation)['analyte_category']=='metaproteome'].reset_index(drop=True)

datagen_metaproteome_manifest[~datagen_metaproteome_manifest['id'].isin(datagen_metaproteome_traversal['id'].unique().tolist())]
# Out:
#                         id               has_input               has_output  \
# 21  nmdc:omprc-11-z841e208  [nmdc:bsm-13-7qxjvr77]  [nmdc:dobj-11-steksn39]
# 44  nmdc:omprc-11-z841e208  [nmdc:bsm-13-7qxjvr77]  [nmdc:dobj-11-steksn39]
#
#                      type analyte_category      associated_studies
# 21  nmdc:MassSpectrometry     metaproteome  [nmdc:sty-11-aygzgv51]
# 44  nmdc:MassSpectrometry     metaproteome  [nmdc:sty-11-aygzgv51]

# %%
pd.DataFrame(stegan_biosample_info)[pd.DataFrame(stegan_biosample_info)['id']=='nmdc:bsm-13-7qxjvr77']
# Out:
#                       id                                               name  \
# 30  nmdc:bsm-13-7qxjvr77  Riverbed sediment microbial communities from a...
#
#                                           description
# 30  Riverbed sediment samples were collected from ...

# %%
pd.DataFrame(data_generation)[pd.DataFrame(data_generation)['id']=='nmdc:omprc-11-z841e208'].reset_index(drop=True)
# Out:
# Empty DataFrame
# Columns: [id, type, has_input, has_output, analyte_category, associated_studies]
# Index: []

# %%
func.get_next_results(collection='data_generation_set',\
                       filter='{"id":"nmdc:omprc-11-z841e208","has_input":"nmdc:bsm-13-7qxjvr77"}',\
                        max_page_size=100,fields='')
# Out:
# [{'id': 'nmdc:omprc-11-z841e208',
#   'name': 'Froze_Core_2015_S1_0_10_18_QE_26May16_Pippin_16-03-39',
#   'description': 'High res MS with high res HCD MSn',
#   'has_input': ['nmdc:bsm-13-7qxjvr77'],
#   'has_output': ['nmdc:dobj-11-steksn39'],
#   'processing_institution': 'EMSL',
#   'type': 'nmdc:MassSpectrometry',
#   'alternative_identifiers': ['emsl:500164'],
#   'analyte_category': 'metaproteome',
#   'associated_studies': ['nmdc:sty-11-aygzgv51'],
#   'instrument_used': ['nmdc:inst-14-e32bpm65'],
#   'eluent_introduction_category': 'liquid_chromatography',
#   'end_date': '2016-05-29 14:39:30.000',
#   'has_chromatography_configuration': 'nmdc:chrcon-14-j1wpdg41',
#   'has_mass_spectrometry_configuration': 'nmdc:mscon-14-0se5av08',
#   'mod_date': '2024-11-07T15:02:18',
#   'start_date': '2016-05-29 12:59:30.000'}]
