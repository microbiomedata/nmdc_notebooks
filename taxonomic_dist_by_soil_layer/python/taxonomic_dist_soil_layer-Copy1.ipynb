# %%
# How does the taxonomic distribution of contigs differ by soil layer (mineral vs organic)?

# %%
import requests
import pandas as pd
from io import StringIO

# %%
# Define a function to get first page of results (we will use again for other requests, which is why we are defining a function)
def get_first_page_results(collection: str, filter: str, max_page_size: int, fields: str):
    og_url = f'https://api.microbiomedata.org/nmdcschema/{collection}?&filter={filter}&max_page_size={max_page_size}&projection={fields}'
    resp = requests.get(og_url)
    data = resp.json()
    
    return data

# %%
# Define another function to get the rest of the results using the next_page_token by calling the first funtion to get
# the initial results and then using the next_page_token to get the other results. This function returns a list of the results

def get_next_results(collection: str, filter: str, max_page_size: int, fields: str):

    # Get initial results (before next_page_token is given in results)
    initial_data = get_first_page_results(collection, filter, max_page_size, fields)
    results = initial_data["resources"]
    next_page_token = initial_data["next_page_token"]
    result_list = []

    # append first page of results to an empty list
    for result in results:
        result_list.append(result)
    
    while True:
        url = f'https://api.microbiomedata.org/nmdcschema/{collection}?&filter={filter}&max_page_size={max_page_size}&page_token={next_page_token}&projection={fields}'
        response = requests.get(url)
        data_next = response.json()
        
        results = data_next.get("resources", [])
        result_list.extend(results)
        next_page_token = data_next.get("next_page_token")
    
        if not next_page_token:
            break

    return result_list

# %%
def convert_df(results_list: list):

    df = pd.DataFrame(results_list)

    return df

# %%
# Get biosamples using functions
biosamples = get_next_results("biosample_set", '{"soil_horizon":{"$exists": true}}', 100, "id,soil_horizon")

# clarify names
for biosample in biosamples:
    biosample["biosample_id"] = biosample.pop("id")

# convert to df
biosample_df = convert_df(biosamples)

biosample_df
# Out:
#      soil_horizon          biosample_id
# 0       O horizon  nmdc:bsm-11-002vgm56
# 1       M horizon  nmdc:bsm-11-00dkyf35
# 2       O horizon  nmdc:bsm-11-00hrxp98
# 3       M horizon  nmdc:bsm-11-00m15h97
# 4       M horizon  nmdc:bsm-11-00yhef97
# ...           ...                   ...
# 4645    M horizon  nmdc:bsm-11-zyhk8g66
# 4646    B horizon  nmdc:bsm-11-zz9hq391
# 4647    A horizon  nmdc:bsm-11-zzahyk07
# 4648    M horizon  nmdc:bsm-11-zzdpcm17
# 4649    M horizon  nmdc:bsm-11-zzrx6210
#
# [4650 rows x 2 columns]

# %%
# Define a function to split ids into chunks
def split_list(input_list, chunk_size=100):
    result = []
    
    for i in range(0, len(input_list), chunk_size):
        result.append(input_list[i:i + chunk_size])
        
    return result

# %%
# Adjust filter list for double quote string - important for mongo queries
def string_mongo_list(a_list: list):
    
    string_with_double_quotes = str(a_list).replace("'", '"')

    return string_with_double_quotes

# %%
# Get list of ids (to eventually feed into query)
def get_id_list(result_list, id_name):
    id_list = []
    for item in result_list:
        if type(item[id_name]) == str:
            id_list.append(item[id_name])
        elif type(item[id_name]) == list:
            for another_item in item[id_name]:
                id_list.append(another_item)

    return id_list

# %%
# Define function to request NMDC metadata based on list of identifiers
def get_id_results(newest_results: list, id_field: str, query_collection: str, match_id_field: str, query_fields: str):

    # split old results into list
    result_ids = get_id_list(newest_results, id_field)

    # # make sure match_id_field has double quotes (important for mongo query)
    match_id_field.replace("'", "\"")

    # chunk up the results into sets of 100 using the split_list function and call the get_first_page_results function and append
    # results to list
    chunked_list = split_list(result_ids)
    next_results = []
    for chunk in chunked_list:
        filter_string = string_mongo_list(chunk)
        # quotes around match_id_field need to look a lot different for the final data object query
        if "data_object_type" in match_id_field:
            data = get_first_page_results(query_collection, f'{{{match_id_field}: {{"$in": {filter_string}}}}}', 100, query_fields)
        else: 
            data = get_first_page_results(query_collection, f'{{"{match_id_field}": {{"$in": {filter_string}}}}}', 100, query_fields)
        next_results.extend(data["resources"])

    return next_results

# %%
# Get pooling results where biosample identifiers are "has_input" in the pooling_set collection
pooling = get_id_results(biosamples, "biosample_id", "pooling_set", "has_input", "id,has_input,has_output")

# clarify names/keys/identifiers
for pool in pooling:
    pool["pooling_has_input"] = pool.pop("has_input")
    pool["pooling_has_output"] = pool.pop("has_output")
    pool["pooling_id"] = pool.pop("id")

# convert to data frame
pooling_df = convert_df(pooling)

pooling_df
# Out:
#                                       pooling_has_input  \
# 0     [nmdc:bsm-11-zw0jr671, nmdc:bsm-11-ftr88019, n...
# 1     [nmdc:bsm-11-pgpaf592, nmdc:bsm-11-07qq9z23, n...
# 2     [nmdc:bsm-11-01g9wf51, nmdc:bsm-11-d8mzds05, n...
# 3     [nmdc:bsm-11-t21kbh64, nmdc:bsm-11-0d4a3v31, n...
# 4     [nmdc:bsm-11-32fzkb25, nmdc:bsm-11-0earmn44, n...
# ...                                                 ...
# 4284  [nmdc:bsm-11-d8254g62, nmdc:bsm-11-zr06ct75, n...
# 4285  [nmdc:bsm-11-zx7j9919, nmdc:bsm-11-ywmc3x87, n...
# 4286       [nmdc:bsm-11-1kzrnd52, nmdc:bsm-11-zx0m7409]
# 4287  [nmdc:bsm-11-r0nqvg54, nmdc:bsm-11-3w0vf491, n...
# 4288  [nmdc:bsm-11-rce9y809, nmdc:bsm-11-104brf69, n...
#
#              pooling_has_output              pooling_id
# 0     [nmdc:procsm-11-m6cgda89]  nmdc:poolp-11-myygnt07
# 1     [nmdc:procsm-11-4x35gd93]  nmdc:poolp-11-fg19qm11
# 2     [nmdc:procsm-11-z19p2488]  nmdc:poolp-11-phdxxg80
# 3     [nmdc:procsm-11-f6fy8y22]  nmdc:poolp-11-d51jda20
# 4     [nmdc:procsm-11-qkhd3y74]  nmdc:poolp-11-5q9ye786
# ...                         ...                     ...
# 4284  [nmdc:procsm-11-wy01d353]  nmdc:poolp-11-zqwvqd96
# 4285  [nmdc:procsm-11-1dyvaw49]  nmdc:poolp-11-h8hehp15
# 4286  [nmdc:procsm-11-qs5tn036]  nmdc:poolp-11-59743d48
# 4287  [nmdc:procsm-11-33n43s88]  nmdc:poolp-11-dzhbts63
# 4288  [nmdc:procsm-11-rd048144]  nmdc:poolp-11-88afda35
#
# [4289 rows x 3 columns]

# %%
# Function to merge new results with old results (mapping keys together that match). df1 is the data frame with the 
# list where key1 is a list. If key_explode == True, then it means to explode the matching list key (in df1). next_key_explode == True
# then explode the next key given from the new results that will be used in the next merge.
def merge_items(df1, df2, key1: str, key2: str, key_explode: bool, next_key_explode: bool, next_key = None):

    if key_explode == True:
        if next_key_explode == True:
            
            # explode the data frame with the matching key that is a list. Df1 is dataframe with key1 that is a list
            df1_exploded = df1.explode(key1)
            merged_df = pd.merge(df1_exploded, df2, left_on=key1, right_on=key2)
        
            # explode next key:
            merged_df_exploded = merged_df.explode(next_key)

            return merged_df_exploded

        elif next_key_explode == False:
            # explode the data frame with the matching key that is a list. Df1 is dataframe with key1 that is a list
            df1_exploded = df1.explode(key1)
            merged_df = pd.merge(df1_exploded, df2, left_on=key1, right_on=key2)

            return merged_df

    elif key_explode == False:
        if next_key:
            
            # Merge the dfs and return the next key expldoed
            merged_df = pd.merge(df1, df2, left_on=key1, right_on=key2)
            merged_df_exploded = merged_df.explode(next_key)

            return merged_df_exploded

        elif not next_key:

            merged_df = pd.merge(df1, df2, left_on=key1, right_on=key2)

            return merged_df

# %%
# Merge the initial biosample results with the pooling results
merged_df1 = merge_items(pooling_df, biosample_df, "pooling_has_input", "biosample_id", True, True, "pooling_has_output")
merged_df1
# Out:
#           pooling_has_input       pooling_has_output              pooling_id  \
# 0      nmdc:bsm-11-zw0jr671  nmdc:procsm-11-m6cgda89  nmdc:poolp-11-myygnt07
# 1      nmdc:bsm-11-zw0jr671  nmdc:procsm-11-m6cgda89  nmdc:poolp-11-myygnt07
# 2      nmdc:bsm-11-zw0jr671  nmdc:procsm-11-m6cgda89  nmdc:poolp-11-myygnt07
# 3      nmdc:bsm-11-ftr88019  nmdc:procsm-11-m6cgda89  nmdc:poolp-11-myygnt07
# 4      nmdc:bsm-11-ftr88019  nmdc:procsm-11-m6cgda89  nmdc:poolp-11-myygnt07
# ...                     ...                      ...                     ...
# 12672  nmdc:bsm-11-zr7b5t24  nmdc:procsm-11-qpqz4w54  nmdc:poolp-11-evtggs98
# 12673  nmdc:bsm-11-zr7b5t24  nmdc:procsm-11-qpqz4w54  nmdc:poolp-11-evtggs98
# 12674  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54  nmdc:poolp-11-evtggs98
# 12675  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54  nmdc:poolp-11-evtggs98
# 12676  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54  nmdc:poolp-11-evtggs98
#
#       soil_horizon          biosample_id
# 0        M horizon  nmdc:bsm-11-zw0jr671
# 1        M horizon  nmdc:bsm-11-zw0jr671
# 2        M horizon  nmdc:bsm-11-zw0jr671
# 3        M horizon  nmdc:bsm-11-ftr88019
# 4        M horizon  nmdc:bsm-11-ftr88019
# ...            ...                   ...
# 12672    O horizon  nmdc:bsm-11-zr7b5t24
# 12673    O horizon  nmdc:bsm-11-zr7b5t24
# 12674    O horizon  nmdc:bsm-11-xhzk6v39
# 12675    O horizon  nmdc:bsm-11-xhzk6v39
# 12676    O horizon  nmdc:bsm-11-xhzk6v39
#
# [12677 rows x 5 columns]

# %%
# Get processed sample results from pooling_has_ouput identifiers
# We use the pooling results and the identifier "pooling_has_output" to query the "processed_sample_set" matching the "id" field, and
# we only need the "id" field returned
process_set1 = get_id_results(pooling, "pooling_has_output", "processed_sample_set", "id", "id")

# clarify names
for processed_sample in process_set1:
    processed_sample["processed_sample1"] = processed_sample.pop("id")

# convert to data frame
ps1_df = convert_df(process_set1)

ps1_df
# Out:
#             processed_sample1
# 0     nmdc:procsm-11-07kg2w70
# 1     nmdc:procsm-11-09rv7c30
# 2     nmdc:procsm-11-0rn9p334
# 3     nmdc:procsm-11-22s7xc89
# 4     nmdc:procsm-11-258vbz70
# ...                       ...
# 4262  nmdc:procsm-11-vqe1dh14
# 4263  nmdc:procsm-11-wm0mqq15
# 4264  nmdc:procsm-11-wy01d353
# 4265  nmdc:procsm-11-x0gpxh72
# 4266  nmdc:procsm-11-xkxtzg80
#
# [4267 rows x 1 columns]

# %%
# Merge the process_set1 with the merged_list based on "id" in process_set1 with "pooling_has_output" from the merged_list
# merged_list = merge_items(process_set1, merged_list, "processed_sample1", "pooling_has_output")
merged_df2 = merge_items(merged_df1, ps1_df, "pooling_has_output", "processed_sample1", False, False)
merged_df2
# Out:
#           pooling_has_input       pooling_has_output              pooling_id  \
# 0      nmdc:bsm-11-zw0jr671  nmdc:procsm-11-m6cgda89  nmdc:poolp-11-myygnt07
# 1      nmdc:bsm-11-zw0jr671  nmdc:procsm-11-m6cgda89  nmdc:poolp-11-myygnt07
# 2      nmdc:bsm-11-zw0jr671  nmdc:procsm-11-m6cgda89  nmdc:poolp-11-myygnt07
# 3      nmdc:bsm-11-zw0jr671  nmdc:procsm-11-m6cgda89  nmdc:poolp-11-myygnt07
# 4      nmdc:bsm-11-zw0jr671  nmdc:procsm-11-m6cgda89  nmdc:poolp-11-myygnt07
# ...                     ...                      ...                     ...
# 36943  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54  nmdc:poolp-11-evtggs98
# 36944  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54  nmdc:poolp-11-evtggs98
# 36945  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54  nmdc:poolp-11-evtggs98
# 36946  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54  nmdc:poolp-11-evtggs98
# 36947  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54  nmdc:poolp-11-evtggs98
#
#       soil_horizon          biosample_id        processed_sample1
# 0        M horizon  nmdc:bsm-11-zw0jr671  nmdc:procsm-11-m6cgda89
# 1        M horizon  nmdc:bsm-11-zw0jr671  nmdc:procsm-11-m6cgda89
# 2        M horizon  nmdc:bsm-11-zw0jr671  nmdc:procsm-11-m6cgda89
# 3        M horizon  nmdc:bsm-11-zw0jr671  nmdc:procsm-11-m6cgda89
# 4        M horizon  nmdc:bsm-11-zw0jr671  nmdc:procsm-11-m6cgda89
# ...            ...                   ...                      ...
# 36943    O horizon  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54
# 36944    O horizon  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54
# 36945    O horizon  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54
# 36946    O horizon  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54
# 36947    O horizon  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54
#
# [36948 rows x 6 columns]

# %%
# Get extraction results from "processed_sample1" identifiers
# We use the process_set1 results and the identifier "processed_sample1" to query the "extraction_set" collection matching the 
# "has_input" field. We need three fields returned from the extraction set: "id", "has_input", and "has_output"
extraction_set = get_id_results(process_set1, "processed_sample1", "extraction_set", "has_input", "id,has_input,has_output")

# clarify names
for extraction in extraction_set:
    extraction["extract_has_input"] = extraction.pop("has_input")
    extraction["extract_has_output"] = extraction.pop("has_output")
    extraction["extract_id"] = extraction.pop("id")

# convert to data frame
extract_df = convert_df(extraction_set)
extract_df
# Out:
#               extract_has_input         extract_has_output  \
# 0     [nmdc:procsm-11-m6cgda89]  [nmdc:procsm-11-e3m9am88]
# 1     [nmdc:procsm-11-zxr4eq64]  [nmdc:procsm-11-69w7d751]
# 2     [nmdc:procsm-11-50046m08]  [nmdc:procsm-11-wfr9gq72]
# 3     [nmdc:procsm-11-4x35gd93]  [nmdc:procsm-11-r8c2df02]
# 4     [nmdc:procsm-11-z19p2488]  [nmdc:procsm-11-6p7xet10]
# ...                         ...                        ...
# 4245  [nmdc:procsm-11-g4shfj37]  [nmdc:procsm-11-tbzk2q40]
# 4246  [nmdc:procsm-11-f4ec8e58]  [nmdc:procsm-11-pce7pn80]
# 4247  [nmdc:procsm-11-en24rw77]  [nmdc:procsm-11-6ca4kh69]
# 4248  [nmdc:procsm-11-j5t8v154]  [nmdc:procsm-11-e88p7q45]
# 4249  [nmdc:procsm-11-apjqzn80]  [nmdc:procsm-11-n6ca7j67]
#
#                   extract_id
# 0     nmdc:extrp-11-2hbzth07
# 1     nmdc:extrp-11-8aaf5q49
# 2     nmdc:extrp-11-7v16d010
# 3     nmdc:extrp-11-7mhth480
# 4     nmdc:extrp-11-1w7rz874
# ...                      ...
# 4245  nmdc:extrp-11-c07fy379
# 4246  nmdc:extrp-11-v53rv933
# 4247  nmdc:extrp-11-b89p0n80
# 4248  nmdc:extrp-11-9exgqh10
# 4249  nmdc:extrp-11-brrz8w04
#
# [4250 rows x 3 columns]

# %%
# Merge the extraction_set with the merged_list based on the extract_has_input of extraction_set with processed_sample1
# from the merged list
merged_df3 = merge_items(extract_df, merged_df2, "extract_has_input", "processed_sample1", True, True, "extract_has_output") 
merged_df3
# Out:
#               extract_has_input       extract_has_output  \
# 0       nmdc:procsm-11-m6cgda89  nmdc:procsm-11-e3m9am88
# 1       nmdc:procsm-11-m6cgda89  nmdc:procsm-11-e3m9am88
# 2       nmdc:procsm-11-m6cgda89  nmdc:procsm-11-e3m9am88
# 3       nmdc:procsm-11-m6cgda89  nmdc:procsm-11-e3m9am88
# 4       nmdc:procsm-11-m6cgda89  nmdc:procsm-11-e3m9am88
# ...                         ...                      ...
# 108246  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 108247  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 108248  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 108249  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 108250  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
#
#                     extract_id     pooling_has_input       pooling_has_output  \
# 0       nmdc:extrp-11-2hbzth07  nmdc:bsm-11-zw0jr671  nmdc:procsm-11-m6cgda89
# 1       nmdc:extrp-11-2hbzth07  nmdc:bsm-11-zw0jr671  nmdc:procsm-11-m6cgda89
# 2       nmdc:extrp-11-2hbzth07  nmdc:bsm-11-zw0jr671  nmdc:procsm-11-m6cgda89
# 3       nmdc:extrp-11-2hbzth07  nmdc:bsm-11-zw0jr671  nmdc:procsm-11-m6cgda89
# 4       nmdc:extrp-11-2hbzth07  nmdc:bsm-11-zw0jr671  nmdc:procsm-11-m6cgda89
# ...                        ...                   ...                      ...
# 108246  nmdc:extrp-11-qw3ca676  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54
# 108247  nmdc:extrp-11-qw3ca676  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54
# 108248  nmdc:extrp-11-qw3ca676  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54
# 108249  nmdc:extrp-11-qw3ca676  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54
# 108250  nmdc:extrp-11-qw3ca676  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54
#
#                     pooling_id soil_horizon          biosample_id  \
# 0       nmdc:poolp-11-myygnt07    M horizon  nmdc:bsm-11-zw0jr671
# 1       nmdc:poolp-11-myygnt07    M horizon  nmdc:bsm-11-zw0jr671
# 2       nmdc:poolp-11-myygnt07    M horizon  nmdc:bsm-11-zw0jr671
# 3       nmdc:poolp-11-myygnt07    M horizon  nmdc:bsm-11-zw0jr671
# 4       nmdc:poolp-11-myygnt07    M horizon  nmdc:bsm-11-zw0jr671
# ...                        ...          ...                   ...
# 108246  nmdc:poolp-11-evtggs98    O horizon  nmdc:bsm-11-xhzk6v39
# 108247  nmdc:poolp-11-evtggs98    O horizon  nmdc:bsm-11-xhzk6v39
# 108248  nmdc:poolp-11-evtggs98    O horizon  nmdc:bsm-11-xhzk6v39
# 108249  nmdc:poolp-11-evtggs98    O horizon  nmdc:bsm-11-xhzk6v39
# 108250  nmdc:poolp-11-evtggs98    O horizon  nmdc:bsm-11-xhzk6v39
#
#               processed_sample1
# 0       nmdc:procsm-11-m6cgda89
# 1       nmdc:procsm-11-m6cgda89
# 2       nmdc:procsm-11-m6cgda89
# 3       nmdc:procsm-11-m6cgda89
# 4       nmdc:procsm-11-m6cgda89
# ...                         ...
# 108246  nmdc:procsm-11-qpqz4w54
# 108247  nmdc:procsm-11-qpqz4w54
# 108248  nmdc:procsm-11-qpqz4w54
# 108249  nmdc:procsm-11-qpqz4w54
# 108250  nmdc:procsm-11-qpqz4w54
#
# [108251 rows x 9 columns]

# %%
# Get processed_sample_set results again from "extract_has_output"
# We use the extraction_set results and identifier "extract_has_output" to query the "processed_sample_set" collection matching the
# "id". We return only the id of the processed_sample_set
process_set2 = get_id_results(extraction_set, "extract_has_output", "processed_sample_set", "id", "id")

# clarify names
for samp in process_set2:
    samp["processed_sample2"] = samp.pop("id")

# convert to data frame
ps2_df = convert_df(process_set2)
ps2_df
# Out:
#             processed_sample2
# 0     nmdc:procsm-11-06bnpy24
# 1     nmdc:procsm-11-0q8aqj17
# 2     nmdc:procsm-11-0sva2t89
# 3     nmdc:procsm-11-18j5nz50
# 4     nmdc:procsm-11-1rzdbe82
# ...                       ...
# 4241  nmdc:procsm-11-xf9ka912
# 4242  nmdc:procsm-11-xwhjh309
# 4243  nmdc:procsm-11-xwpjt103
# 4244  nmdc:procsm-11-yrmwcm28
# 4245  nmdc:procsm-11-zg63ac02
#
# [4246 rows x 1 columns]

# %%
# Merge the process_set2 with the merged_list based on the proccessed_sample2 of process_set2 with extract_has_output
#from merged list
merged_df4 = merge_items(merged_df3, ps2_df, "extract_has_output", "processed_sample2", False, False)
merged_df4
# Out:
#               extract_has_input       extract_has_output  \
# 0       nmdc:procsm-11-m6cgda89  nmdc:procsm-11-e3m9am88
# 1       nmdc:procsm-11-m6cgda89  nmdc:procsm-11-e3m9am88
# 2       nmdc:procsm-11-m6cgda89  nmdc:procsm-11-e3m9am88
# 3       nmdc:procsm-11-m6cgda89  nmdc:procsm-11-e3m9am88
# 4       nmdc:procsm-11-m6cgda89  nmdc:procsm-11-e3m9am88
# ...                         ...                      ...
# 320080  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 320081  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 320082  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 320083  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 320084  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
#
#                     extract_id     pooling_has_input       pooling_has_output  \
# 0       nmdc:extrp-11-2hbzth07  nmdc:bsm-11-zw0jr671  nmdc:procsm-11-m6cgda89
# 1       nmdc:extrp-11-2hbzth07  nmdc:bsm-11-zw0jr671  nmdc:procsm-11-m6cgda89
# 2       nmdc:extrp-11-2hbzth07  nmdc:bsm-11-zw0jr671  nmdc:procsm-11-m6cgda89
# 3       nmdc:extrp-11-2hbzth07  nmdc:bsm-11-zw0jr671  nmdc:procsm-11-m6cgda89
# 4       nmdc:extrp-11-2hbzth07  nmdc:bsm-11-zw0jr671  nmdc:procsm-11-m6cgda89
# ...                        ...                   ...                      ...
# 320080  nmdc:extrp-11-qw3ca676  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54
# 320081  nmdc:extrp-11-qw3ca676  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54
# 320082  nmdc:extrp-11-qw3ca676  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54
# 320083  nmdc:extrp-11-qw3ca676  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54
# 320084  nmdc:extrp-11-qw3ca676  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54
#
#                     pooling_id soil_horizon          biosample_id  \
# 0       nmdc:poolp-11-myygnt07    M horizon  nmdc:bsm-11-zw0jr671
# 1       nmdc:poolp-11-myygnt07    M horizon  nmdc:bsm-11-zw0jr671
# 2       nmdc:poolp-11-myygnt07    M horizon  nmdc:bsm-11-zw0jr671
# 3       nmdc:poolp-11-myygnt07    M horizon  nmdc:bsm-11-zw0jr671
# 4       nmdc:poolp-11-myygnt07    M horizon  nmdc:bsm-11-zw0jr671
# ...                        ...          ...                   ...
# 320080  nmdc:poolp-11-evtggs98    O horizon  nmdc:bsm-11-xhzk6v39
# 320081  nmdc:poolp-11-evtggs98    O horizon  nmdc:bsm-11-xhzk6v39
# 320082  nmdc:poolp-11-evtggs98    O horizon  nmdc:bsm-11-xhzk6v39
# 320083  nmdc:poolp-11-evtggs98    O horizon  nmdc:bsm-11-xhzk6v39
# 320084  nmdc:poolp-11-evtggs98    O horizon  nmdc:bsm-11-xhzk6v39
#
#               processed_sample1        processed_sample2
# 0       nmdc:procsm-11-m6cgda89  nmdc:procsm-11-e3m9am88
# 1       nmdc:procsm-11-m6cgda89  nmdc:procsm-11-e3m9am88
# 2       nmdc:procsm-11-m6cgda89  nmdc:procsm-11-e3m9am88
# 3       nmdc:procsm-11-m6cgda89  nmdc:procsm-11-e3m9am88
# 4       nmdc:procsm-11-m6cgda89  nmdc:procsm-11-e3m9am88
# ...                         ...                      ...
# 320080  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 320081  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 320082  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 320083  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 320084  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
#
# [320085 rows x 10 columns]

# %%
# Get library_preparation_set results from "processed_sample2" 
# We use the process_set2 results and identifier "processed_sample2" to query the library_preparation_set collection matching the 
# "has_input" field. We return the "has_input", "has_output", and "id" fields.
library_prep_set = get_id_results(process_set2, "processed_sample2", "library_preparation_set", "has_input", "id,has_input,has_output")

# clarify names
for prep in library_prep_set:
    prep["lp_has_input"] = prep.pop("has_input")
    prep["lp_has_output"] = prep.pop("has_output")
    prep["lp_id"] = prep.pop("id")

# convert to data frame
lp_df = convert_df(library_prep_set)
lp_df
# Out:
#                    lp_has_input              lp_has_output  \
# 0     [nmdc:procsm-11-e3m9am88]  [nmdc:procsm-11-s71h1s64]
# 1     [nmdc:procsm-11-69w7d751]  [nmdc:procsm-11-pvq3cw40]
# 2     [nmdc:procsm-11-wfr9gq72]  [nmdc:procsm-11-g7btv939]
# 3     [nmdc:procsm-11-r8c2df02]  [nmdc:procsm-11-vvhhwt22]
# 4     [nmdc:procsm-11-6p7xet10]  [nmdc:procsm-11-062rbk44]
# ...                         ...                        ...
# 4240  [nmdc:procsm-11-tbzk2q40]  [nmdc:procsm-11-xpfxk275]
# 4241  [nmdc:procsm-11-pce7pn80]  [nmdc:procsm-11-z1jy1841]
# 4242  [nmdc:procsm-11-6ca4kh69]  [nmdc:procsm-11-241nns31]
# 4243  [nmdc:procsm-11-e88p7q45]  [nmdc:procsm-11-en1yqa35]
# 4244  [nmdc:procsm-11-n6ca7j67]  [nmdc:procsm-11-5ggf9w42]
#
#                         lp_id
# 0     nmdc:libprp-11-acbfh839
# 1     nmdc:libprp-11-e39ky379
# 2     nmdc:libprp-11-7v2sqk43
# 3     nmdc:libprp-11-7y2d1222
# 4     nmdc:libprp-11-2cy94060
# ...                       ...
# 4240  nmdc:libprp-11-m33s2x71
# 4241  nmdc:libprp-11-vwd3tn32
# 4242  nmdc:libprp-11-ftccjg43
# 4243  nmdc:libprp-11-46m5k206
# 4244  nmdc:libprp-11-ejr9ap28
#
# [4245 rows x 3 columns]

# %%
# Merge library preparation with merged_list on "processed_sample2" and "lp_has_input"
merged_df5 = merge_items(lp_df, merged_df4, "lp_has_input", "processed_sample2", True, True, "lp_has_output")
merged_df5
# Out:
#                    lp_has_input            lp_has_output  \
# 0       nmdc:procsm-11-e3m9am88  nmdc:procsm-11-s71h1s64
# 1       nmdc:procsm-11-e3m9am88  nmdc:procsm-11-s71h1s64
# 2       nmdc:procsm-11-e3m9am88  nmdc:procsm-11-s71h1s64
# 3       nmdc:procsm-11-e3m9am88  nmdc:procsm-11-s71h1s64
# 4       nmdc:procsm-11-e3m9am88  nmdc:procsm-11-s71h1s64
# ...                         ...                      ...
# 950943  nmdc:procsm-11-3rfvyd88  nmdc:procsm-11-h6y3cf29
# 950944  nmdc:procsm-11-3rfvyd88  nmdc:procsm-11-h6y3cf29
# 950945  nmdc:procsm-11-3rfvyd88  nmdc:procsm-11-h6y3cf29
# 950946  nmdc:procsm-11-3rfvyd88  nmdc:procsm-11-h6y3cf29
# 950947  nmdc:procsm-11-3rfvyd88  nmdc:procsm-11-h6y3cf29
#
#                           lp_id        extract_has_input  \
# 0       nmdc:libprp-11-acbfh839  nmdc:procsm-11-m6cgda89
# 1       nmdc:libprp-11-acbfh839  nmdc:procsm-11-m6cgda89
# 2       nmdc:libprp-11-acbfh839  nmdc:procsm-11-m6cgda89
# 3       nmdc:libprp-11-acbfh839  nmdc:procsm-11-m6cgda89
# 4       nmdc:libprp-11-acbfh839  nmdc:procsm-11-m6cgda89
# ...                         ...                      ...
# 950943  nmdc:libprp-11-86c4n641  nmdc:procsm-11-qpqz4w54
# 950944  nmdc:libprp-11-86c4n641  nmdc:procsm-11-qpqz4w54
# 950945  nmdc:libprp-11-86c4n641  nmdc:procsm-11-qpqz4w54
# 950946  nmdc:libprp-11-86c4n641  nmdc:procsm-11-qpqz4w54
# 950947  nmdc:libprp-11-86c4n641  nmdc:procsm-11-qpqz4w54
#
#              extract_has_output              extract_id     pooling_has_input  \
# 0       nmdc:procsm-11-e3m9am88  nmdc:extrp-11-2hbzth07  nmdc:bsm-11-zw0jr671
# 1       nmdc:procsm-11-e3m9am88  nmdc:extrp-11-2hbzth07  nmdc:bsm-11-zw0jr671
# 2       nmdc:procsm-11-e3m9am88  nmdc:extrp-11-2hbzth07  nmdc:bsm-11-zw0jr671
# 3       nmdc:procsm-11-e3m9am88  nmdc:extrp-11-2hbzth07  nmdc:bsm-11-zw0jr671
# 4       nmdc:procsm-11-e3m9am88  nmdc:extrp-11-2hbzth07  nmdc:bsm-11-zw0jr671
# ...                         ...                     ...                   ...
# 950943  nmdc:procsm-11-3rfvyd88  nmdc:extrp-11-qw3ca676  nmdc:bsm-11-xhzk6v39
# 950944  nmdc:procsm-11-3rfvyd88  nmdc:extrp-11-qw3ca676  nmdc:bsm-11-xhzk6v39
# 950945  nmdc:procsm-11-3rfvyd88  nmdc:extrp-11-qw3ca676  nmdc:bsm-11-xhzk6v39
# 950946  nmdc:procsm-11-3rfvyd88  nmdc:extrp-11-qw3ca676  nmdc:bsm-11-xhzk6v39
# 950947  nmdc:procsm-11-3rfvyd88  nmdc:extrp-11-qw3ca676  nmdc:bsm-11-xhzk6v39
#
#              pooling_has_output              pooling_id soil_horizon  \
# 0       nmdc:procsm-11-m6cgda89  nmdc:poolp-11-myygnt07    M horizon
# 1       nmdc:procsm-11-m6cgda89  nmdc:poolp-11-myygnt07    M horizon
# 2       nmdc:procsm-11-m6cgda89  nmdc:poolp-11-myygnt07    M horizon
# 3       nmdc:procsm-11-m6cgda89  nmdc:poolp-11-myygnt07    M horizon
# 4       nmdc:procsm-11-m6cgda89  nmdc:poolp-11-myygnt07    M horizon
# ...                         ...                     ...          ...
# 950943  nmdc:procsm-11-qpqz4w54  nmdc:poolp-11-evtggs98    O horizon
# 950944  nmdc:procsm-11-qpqz4w54  nmdc:poolp-11-evtggs98    O horizon
# 950945  nmdc:procsm-11-qpqz4w54  nmdc:poolp-11-evtggs98    O horizon
# 950946  nmdc:procsm-11-qpqz4w54  nmdc:poolp-11-evtggs98    O horizon
# 950947  nmdc:procsm-11-qpqz4w54  nmdc:poolp-11-evtggs98    O horizon
#
#                 biosample_id        processed_sample1        processed_sample2
# 0       nmdc:bsm-11-zw0jr671  nmdc:procsm-11-m6cgda89  nmdc:procsm-11-e3m9am88
# 1       nmdc:bsm-11-zw0jr671  nmdc:procsm-11-m6cgda89  nmdc:procsm-11-e3m9am88
# 2       nmdc:bsm-11-zw0jr671  nmdc:procsm-11-m6cgda89  nmdc:procsm-11-e3m9am88
# 3       nmdc:bsm-11-zw0jr671  nmdc:procsm-11-m6cgda89  nmdc:procsm-11-e3m9am88
# 4       nmdc:bsm-11-zw0jr671  nmdc:procsm-11-m6cgda89  nmdc:procsm-11-e3m9am88
# ...                      ...                      ...                      ...
# 950943  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 950944  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 950945  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 950946  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 950947  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
#
# [950948 rows x 13 columns]

# %%
# Get process_set3 results from "lp_has_output"
# Use the library_prep_set results and identifier "lp_has_output" to query the processed_sample_set collection matching the
# "id" field. We return only the "id" field
process_set3 = get_id_results(library_prep_set, "lp_has_output", "processed_sample_set", "id", "id")

# clarify keys
for samp in process_set3:
    samp["processed_sample3"] = samp.pop("id")

# convert to data frame
ps3_df = convert_df(process_set3)
ps3_df
# Out:
#             processed_sample3
# 0     nmdc:procsm-11-062rbk44
# 1     nmdc:procsm-11-0tkbt064
# 2     nmdc:procsm-11-1cmwcb97
# 3     nmdc:procsm-11-211dc865
# 4     nmdc:procsm-11-21q8jj02
# ...                       ...
# 4239  nmdc:procsm-11-xpfxk275
# 4240  nmdc:procsm-11-yzae4f85
# 4241  nmdc:procsm-11-z1jy1841
# 4242  nmdc:procsm-11-z3476h43
# 4243  nmdc:procsm-11-zkkmtr10
#
# [4244 rows x 1 columns]

# %%
# Merge proces_set3 results with merged_list on "lp_has_output" with "processed_sample3" Takes 7+ minutes??
merged_df6 = merge_items(merged_df5, ps3_df, "lp_has_output", "processed_sample3", False, False)
merged_df6
# Out:
#                     lp_has_input            lp_has_output  \
# 0        nmdc:procsm-11-e3m9am88  nmdc:procsm-11-s71h1s64
# 1        nmdc:procsm-11-e3m9am88  nmdc:procsm-11-s71h1s64
# 2        nmdc:procsm-11-e3m9am88  nmdc:procsm-11-s71h1s64
# 3        nmdc:procsm-11-e3m9am88  nmdc:procsm-11-s71h1s64
# 4        nmdc:procsm-11-e3m9am88  nmdc:procsm-11-s71h1s64
# ...                          ...                      ...
# 2826736  nmdc:procsm-11-3rfvyd88  nmdc:procsm-11-h6y3cf29
# 2826737  nmdc:procsm-11-3rfvyd88  nmdc:procsm-11-h6y3cf29
# 2826738  nmdc:procsm-11-3rfvyd88  nmdc:procsm-11-h6y3cf29
# 2826739  nmdc:procsm-11-3rfvyd88  nmdc:procsm-11-h6y3cf29
# 2826740  nmdc:procsm-11-3rfvyd88  nmdc:procsm-11-h6y3cf29
#
#                            lp_id        extract_has_input  \
# 0        nmdc:libprp-11-acbfh839  nmdc:procsm-11-m6cgda89
# 1        nmdc:libprp-11-acbfh839  nmdc:procsm-11-m6cgda89
# 2        nmdc:libprp-11-acbfh839  nmdc:procsm-11-m6cgda89
# 3        nmdc:libprp-11-acbfh839  nmdc:procsm-11-m6cgda89
# 4        nmdc:libprp-11-acbfh839  nmdc:procsm-11-m6cgda89
# ...                          ...                      ...
# 2826736  nmdc:libprp-11-86c4n641  nmdc:procsm-11-qpqz4w54
# 2826737  nmdc:libprp-11-86c4n641  nmdc:procsm-11-qpqz4w54
# 2826738  nmdc:libprp-11-86c4n641  nmdc:procsm-11-qpqz4w54
# 2826739  nmdc:libprp-11-86c4n641  nmdc:procsm-11-qpqz4w54
# 2826740  nmdc:libprp-11-86c4n641  nmdc:procsm-11-qpqz4w54
#
#               extract_has_output              extract_id  \
# 0        nmdc:procsm-11-e3m9am88  nmdc:extrp-11-2hbzth07
# 1        nmdc:procsm-11-e3m9am88  nmdc:extrp-11-2hbzth07
# 2        nmdc:procsm-11-e3m9am88  nmdc:extrp-11-2hbzth07
# 3        nmdc:procsm-11-e3m9am88  nmdc:extrp-11-2hbzth07
# 4        nmdc:procsm-11-e3m9am88  nmdc:extrp-11-2hbzth07
# ...                          ...                     ...
# 2826736  nmdc:procsm-11-3rfvyd88  nmdc:extrp-11-qw3ca676
# 2826737  nmdc:procsm-11-3rfvyd88  nmdc:extrp-11-qw3ca676
# 2826738  nmdc:procsm-11-3rfvyd88  nmdc:extrp-11-qw3ca676
# 2826739  nmdc:procsm-11-3rfvyd88  nmdc:extrp-11-qw3ca676
# 2826740  nmdc:procsm-11-3rfvyd88  nmdc:extrp-11-qw3ca676
#
#             pooling_has_input       pooling_has_output  \
# 0        nmdc:bsm-11-zw0jr671  nmdc:procsm-11-m6cgda89
# 1        nmdc:bsm-11-zw0jr671  nmdc:procsm-11-m6cgda89
# 2        nmdc:bsm-11-zw0jr671  nmdc:procsm-11-m6cgda89
# 3        nmdc:bsm-11-zw0jr671  nmdc:procsm-11-m6cgda89
# 4        nmdc:bsm-11-zw0jr671  nmdc:procsm-11-m6cgda89
# ...                       ...                      ...
# 2826736  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54
# 2826737  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54
# 2826738  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54
# 2826739  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54
# 2826740  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54
#
#                      pooling_id soil_horizon          biosample_id  \
# 0        nmdc:poolp-11-myygnt07    M horizon  nmdc:bsm-11-zw0jr671
# 1        nmdc:poolp-11-myygnt07    M horizon  nmdc:bsm-11-zw0jr671
# 2        nmdc:poolp-11-myygnt07    M horizon  nmdc:bsm-11-zw0jr671
# 3        nmdc:poolp-11-myygnt07    M horizon  nmdc:bsm-11-zw0jr671
# 4        nmdc:poolp-11-myygnt07    M horizon  nmdc:bsm-11-zw0jr671
# ...                         ...          ...                   ...
# 2826736  nmdc:poolp-11-evtggs98    O horizon  nmdc:bsm-11-xhzk6v39
# 2826737  nmdc:poolp-11-evtggs98    O horizon  nmdc:bsm-11-xhzk6v39
# 2826738  nmdc:poolp-11-evtggs98    O horizon  nmdc:bsm-11-xhzk6v39
# 2826739  nmdc:poolp-11-evtggs98    O horizon  nmdc:bsm-11-xhzk6v39
# 2826740  nmdc:poolp-11-evtggs98    O horizon  nmdc:bsm-11-xhzk6v39
#
#                processed_sample1        processed_sample2  \
# 0        nmdc:procsm-11-m6cgda89  nmdc:procsm-11-e3m9am88
# 1        nmdc:procsm-11-m6cgda89  nmdc:procsm-11-e3m9am88
# 2        nmdc:procsm-11-m6cgda89  nmdc:procsm-11-e3m9am88
# 3        nmdc:procsm-11-m6cgda89  nmdc:procsm-11-e3m9am88
# 4        nmdc:procsm-11-m6cgda89  nmdc:procsm-11-e3m9am88
# ...                          ...                      ...
# 2826736  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 2826737  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 2826738  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 2826739  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 2826740  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
#
#                processed_sample3
# 0        nmdc:procsm-11-s71h1s64
# 1        nmdc:procsm-11-s71h1s64
# 2        nmdc:procsm-11-s71h1s64
# 3        nmdc:procsm-11-s71h1s64
# 4        nmdc:procsm-11-s71h1s64
# ...                          ...
# 2826736  nmdc:procsm-11-h6y3cf29
# 2826737  nmdc:procsm-11-h6y3cf29
# 2826738  nmdc:procsm-11-h6y3cf29
# 2826739  nmdc:procsm-11-h6y3cf29
# 2826740  nmdc:procsm-11-h6y3cf29
#
# [2826741 rows x 14 columns]

# %%
# Get omics_processing results from "processed_sample3"
# Use the process_set3 results identifier "processed_sample3" to query the omics_processing_set collection matching the
# "has_input" field. Return "has_input" and "id"
omics_process_set = get_id_results(process_set3, "processed_sample3", "omics_processing_set", "has_input", "has_input,id")

# clarify keys
for op in omics_process_set:
    op["op_has_input"] = op.pop("has_input")
    op["op_id"] = op.pop("id")

# convert to data frame
op_df = convert_df(omics_process_set)
op_df
# Out:
#                    op_has_input                   op_id
# 0     [nmdc:procsm-11-062rbk44]  nmdc:omprc-11-bn309345
# 1     [nmdc:procsm-11-0tkbt064]  nmdc:omprc-11-db9g5v27
# 2     [nmdc:procsm-11-1cmwcb97]  nmdc:omprc-11-83e9ph40
# 3     [nmdc:procsm-11-211dc865]  nmdc:omprc-11-kfxafd58
# 4     [nmdc:procsm-11-21q8jj02]  nmdc:omprc-11-pwveft17
# ...                         ...                     ...
# 4205  [nmdc:procsm-11-xpfxk275]  nmdc:omprc-11-f9x2k996
# 4206  [nmdc:procsm-11-yzae4f85]  nmdc:omprc-11-9n5fc730
# 4207  [nmdc:procsm-11-z1jy1841]  nmdc:omprc-11-cv9ymw96
# 4208  [nmdc:procsm-11-z3476h43]  nmdc:omprc-11-4wq97r16
# 4209  [nmdc:procsm-11-zkkmtr10]  nmdc:omprc-11-wb44ve09
#
# [4210 rows x 2 columns]

# %%
# Merge omics_process_set with merged_list on processed "processed_sample3"
merged_df7 = merge_items(op_df, merged_df6, "op_has_input", "processed_sample3", True, False, "op_id")
merged_df7
# Out:
#                     op_has_input                   op_id  \
# 0        nmdc:procsm-11-062rbk44  nmdc:omprc-11-bn309345
# 1        nmdc:procsm-11-062rbk44  nmdc:omprc-11-bn309345
# 2        nmdc:procsm-11-062rbk44  nmdc:omprc-11-bn309345
# 3        nmdc:procsm-11-062rbk44  nmdc:omprc-11-bn309345
# 4        nmdc:procsm-11-062rbk44  nmdc:omprc-11-bn309345
# ...                          ...                     ...
# 8362274  nmdc:procsm-11-h6y3cf29  nmdc:omprc-11-bj2afq20
# 8362275  nmdc:procsm-11-h6y3cf29  nmdc:omprc-11-bj2afq20
# 8362276  nmdc:procsm-11-h6y3cf29  nmdc:omprc-11-bj2afq20
# 8362277  nmdc:procsm-11-h6y3cf29  nmdc:omprc-11-bj2afq20
# 8362278  nmdc:procsm-11-h6y3cf29  nmdc:omprc-11-bj2afq20
#
#                     lp_has_input            lp_has_output  \
# 0        nmdc:procsm-11-6p7xet10  nmdc:procsm-11-062rbk44
# 1        nmdc:procsm-11-6p7xet10  nmdc:procsm-11-062rbk44
# 2        nmdc:procsm-11-6p7xet10  nmdc:procsm-11-062rbk44
# 3        nmdc:procsm-11-6p7xet10  nmdc:procsm-11-062rbk44
# 4        nmdc:procsm-11-6p7xet10  nmdc:procsm-11-062rbk44
# ...                          ...                      ...
# 8362274  nmdc:procsm-11-3rfvyd88  nmdc:procsm-11-h6y3cf29
# 8362275  nmdc:procsm-11-3rfvyd88  nmdc:procsm-11-h6y3cf29
# 8362276  nmdc:procsm-11-3rfvyd88  nmdc:procsm-11-h6y3cf29
# 8362277  nmdc:procsm-11-3rfvyd88  nmdc:procsm-11-h6y3cf29
# 8362278  nmdc:procsm-11-3rfvyd88  nmdc:procsm-11-h6y3cf29
#
#                            lp_id        extract_has_input  \
# 0        nmdc:libprp-11-2cy94060  nmdc:procsm-11-z19p2488
# 1        nmdc:libprp-11-2cy94060  nmdc:procsm-11-z19p2488
# 2        nmdc:libprp-11-2cy94060  nmdc:procsm-11-z19p2488
# 3        nmdc:libprp-11-2cy94060  nmdc:procsm-11-z19p2488
# 4        nmdc:libprp-11-2cy94060  nmdc:procsm-11-z19p2488
# ...                          ...                      ...
# 8362274  nmdc:libprp-11-86c4n641  nmdc:procsm-11-qpqz4w54
# 8362275  nmdc:libprp-11-86c4n641  nmdc:procsm-11-qpqz4w54
# 8362276  nmdc:libprp-11-86c4n641  nmdc:procsm-11-qpqz4w54
# 8362277  nmdc:libprp-11-86c4n641  nmdc:procsm-11-qpqz4w54
# 8362278  nmdc:libprp-11-86c4n641  nmdc:procsm-11-qpqz4w54
#
#               extract_has_output              extract_id  \
# 0        nmdc:procsm-11-6p7xet10  nmdc:extrp-11-1w7rz874
# 1        nmdc:procsm-11-6p7xet10  nmdc:extrp-11-1w7rz874
# 2        nmdc:procsm-11-6p7xet10  nmdc:extrp-11-1w7rz874
# 3        nmdc:procsm-11-6p7xet10  nmdc:extrp-11-1w7rz874
# 4        nmdc:procsm-11-6p7xet10  nmdc:extrp-11-1w7rz874
# ...                          ...                     ...
# 8362274  nmdc:procsm-11-3rfvyd88  nmdc:extrp-11-qw3ca676
# 8362275  nmdc:procsm-11-3rfvyd88  nmdc:extrp-11-qw3ca676
# 8362276  nmdc:procsm-11-3rfvyd88  nmdc:extrp-11-qw3ca676
# 8362277  nmdc:procsm-11-3rfvyd88  nmdc:extrp-11-qw3ca676
# 8362278  nmdc:procsm-11-3rfvyd88  nmdc:extrp-11-qw3ca676
#
#             pooling_has_input       pooling_has_output  \
# 0        nmdc:bsm-11-01g9wf51  nmdc:procsm-11-z19p2488
# 1        nmdc:bsm-11-01g9wf51  nmdc:procsm-11-z19p2488
# 2        nmdc:bsm-11-01g9wf51  nmdc:procsm-11-z19p2488
# 3        nmdc:bsm-11-01g9wf51  nmdc:procsm-11-z19p2488
# 4        nmdc:bsm-11-01g9wf51  nmdc:procsm-11-z19p2488
# ...                       ...                      ...
# 8362274  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54
# 8362275  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54
# 8362276  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54
# 8362277  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54
# 8362278  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54
#
#                      pooling_id soil_horizon          biosample_id  \
# 0        nmdc:poolp-11-phdxxg80    O horizon  nmdc:bsm-11-01g9wf51
# 1        nmdc:poolp-11-phdxxg80    O horizon  nmdc:bsm-11-01g9wf51
# 2        nmdc:poolp-11-phdxxg80    O horizon  nmdc:bsm-11-01g9wf51
# 3        nmdc:poolp-11-phdxxg80    O horizon  nmdc:bsm-11-01g9wf51
# 4        nmdc:poolp-11-phdxxg80    O horizon  nmdc:bsm-11-01g9wf51
# ...                         ...          ...                   ...
# 8362274  nmdc:poolp-11-evtggs98    O horizon  nmdc:bsm-11-xhzk6v39
# 8362275  nmdc:poolp-11-evtggs98    O horizon  nmdc:bsm-11-xhzk6v39
# 8362276  nmdc:poolp-11-evtggs98    O horizon  nmdc:bsm-11-xhzk6v39
# 8362277  nmdc:poolp-11-evtggs98    O horizon  nmdc:bsm-11-xhzk6v39
# 8362278  nmdc:poolp-11-evtggs98    O horizon  nmdc:bsm-11-xhzk6v39
#
#                processed_sample1        processed_sample2  \
# 0        nmdc:procsm-11-z19p2488  nmdc:procsm-11-6p7xet10
# 1        nmdc:procsm-11-z19p2488  nmdc:procsm-11-6p7xet10
# 2        nmdc:procsm-11-z19p2488  nmdc:procsm-11-6p7xet10
# 3        nmdc:procsm-11-z19p2488  nmdc:procsm-11-6p7xet10
# 4        nmdc:procsm-11-z19p2488  nmdc:procsm-11-6p7xet10
# ...                          ...                      ...
# 8362274  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 8362275  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 8362276  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 8362277  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 8362278  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
#
#                processed_sample3
# 0        nmdc:procsm-11-062rbk44
# 1        nmdc:procsm-11-062rbk44
# 2        nmdc:procsm-11-062rbk44
# 3        nmdc:procsm-11-062rbk44
# 4        nmdc:procsm-11-062rbk44
# ...                          ...
# 8362274  nmdc:procsm-11-h6y3cf29
# 8362275  nmdc:procsm-11-h6y3cf29
# 8362276  nmdc:procsm-11-h6y3cf29
# 8362277  nmdc:procsm-11-h6y3cf29
# 8362278  nmdc:procsm-11-h6y3cf29
#
# [8362279 rows x 16 columns]

# %%
# Get metagenome_annotation_activity_set from "op_id"
# Use the omics_process_set results identifier "op_id" to query the metagenome_annotation_activity_set collection matching
# the "was_informed_by" field. Return "was_informed_by" and "has_output"
meta_act_ann_set = get_id_results(omics_process_set, "op_id", "metagenome_annotation_activity_set", "was_informed_by", "has_output,was_informed_by,id")

# clarify names
for mga in meta_act_ann_set:
    mga["mga_id"] = mga.pop("id")
    mga["mga_was_informed_by"] = mga.pop("was_informed_by")
    mga["mga_has_output"] = mga.pop("has_output")

# convert to data frame
mga_df = convert_df(meta_act_ann_set)
mga_df
# Out:
#                          mga_id     mga_was_informed_by  \
# 0     nmdc:wfmgan-11-h05qba23.1  nmdc:omprc-11-5qs1cd02
# 1     nmdc:wfmgan-11-4h48ff64.1  nmdc:omprc-11-1zehaw93
# 2     nmdc:wfmgan-11-f8cseh97.1  nmdc:omprc-11-bn309345
# 3     nmdc:wfmgan-11-bajw6h61.1  nmdc:omprc-11-dsv3f325
# 4     nmdc:wfmgan-11-0w0rnd53.1  nmdc:omprc-11-897qak81
# ...                         ...                     ...
# 3748  nmdc:wfmgan-11-r9xyg197.1  nmdc:omprc-11-qg2e3t41
# 3749  nmdc:wfmgan-11-dxqxre60.1  nmdc:omprc-11-cpqbew37
# 3750  nmdc:wfmgan-11-14gcar54.1  nmdc:omprc-11-px5df021
# 3751  nmdc:wfmgan-11-z6d94p37.1  nmdc:omprc-11-cv9ymw96
# 3752  nmdc:wfmgan-11-5rqhd816.1  nmdc:omprc-11-f9x2k996
#
#                                          mga_has_output
# 0     [nmdc:dobj-11-808cyq50, nmdc:dobj-11-13d79a82,...
# 1     [nmdc:dobj-11-m70ftn50, nmdc:dobj-11-kwbeyv20,...
# 2     [nmdc:dobj-11-f1trcg75, nmdc:dobj-11-5pqvfm47,...
# 3     [nmdc:dobj-11-qzsjp850, nmdc:dobj-11-tmp0t041,...
# 4     [nmdc:dobj-11-0dfd5b92, nmdc:dobj-11-04jsg262,...
# ...                                                 ...
# 3748  [nmdc:dobj-11-aav9vk45, nmdc:dobj-11-eats2y81,...
# 3749  [nmdc:dobj-11-7f8e4a45, nmdc:dobj-11-4rmq5t75,...
# 3750  [nmdc:dobj-11-dy2jsc18, nmdc:dobj-11-3amwd664,...
# 3751  [nmdc:dobj-11-f251gr10, nmdc:dobj-11-207dgx57,...
# 3752  [nmdc:dobj-11-wc0y8n82, nmdc:dobj-11-t6jrx266,...
#
# [3753 rows x 3 columns]

# %%
# Merge metagenome activity set with merged_list on mga_has_input
merged_df8 = merge_items(merged_df7, mga_df,  "op_id", "mga_was_informed_by", False, True, "mga_has_output")
merged_df8
# Out:
#                      op_has_input                   op_id  \
# 0         nmdc:procsm-11-062rbk44  nmdc:omprc-11-bn309345
# 0         nmdc:procsm-11-062rbk44  nmdc:omprc-11-bn309345
# 0         nmdc:procsm-11-062rbk44  nmdc:omprc-11-bn309345
# 0         nmdc:procsm-11-062rbk44  nmdc:omprc-11-bn309345
# 0         nmdc:procsm-11-062rbk44  nmdc:omprc-11-bn309345
# ...                           ...                     ...
# 22250971  nmdc:procsm-11-h6y3cf29  nmdc:omprc-11-bj2afq20
# 22250971  nmdc:procsm-11-h6y3cf29  nmdc:omprc-11-bj2afq20
# 22250971  nmdc:procsm-11-h6y3cf29  nmdc:omprc-11-bj2afq20
# 22250971  nmdc:procsm-11-h6y3cf29  nmdc:omprc-11-bj2afq20
# 22250971  nmdc:procsm-11-h6y3cf29  nmdc:omprc-11-bj2afq20
#
#                      lp_has_input            lp_has_output  \
# 0         nmdc:procsm-11-6p7xet10  nmdc:procsm-11-062rbk44
# 0         nmdc:procsm-11-6p7xet10  nmdc:procsm-11-062rbk44
# 0         nmdc:procsm-11-6p7xet10  nmdc:procsm-11-062rbk44
# 0         nmdc:procsm-11-6p7xet10  nmdc:procsm-11-062rbk44
# 0         nmdc:procsm-11-6p7xet10  nmdc:procsm-11-062rbk44
# ...                           ...                      ...
# 22250971  nmdc:procsm-11-3rfvyd88  nmdc:procsm-11-h6y3cf29
# 22250971  nmdc:procsm-11-3rfvyd88  nmdc:procsm-11-h6y3cf29
# 22250971  nmdc:procsm-11-3rfvyd88  nmdc:procsm-11-h6y3cf29
# 22250971  nmdc:procsm-11-3rfvyd88  nmdc:procsm-11-h6y3cf29
# 22250971  nmdc:procsm-11-3rfvyd88  nmdc:procsm-11-h6y3cf29
#
#                             lp_id        extract_has_input  \
# 0         nmdc:libprp-11-2cy94060  nmdc:procsm-11-z19p2488
# 0         nmdc:libprp-11-2cy94060  nmdc:procsm-11-z19p2488
# 0         nmdc:libprp-11-2cy94060  nmdc:procsm-11-z19p2488
# 0         nmdc:libprp-11-2cy94060  nmdc:procsm-11-z19p2488
# 0         nmdc:libprp-11-2cy94060  nmdc:procsm-11-z19p2488
# ...                           ...                      ...
# 22250971  nmdc:libprp-11-86c4n641  nmdc:procsm-11-qpqz4w54
# 22250971  nmdc:libprp-11-86c4n641  nmdc:procsm-11-qpqz4w54
# 22250971  nmdc:libprp-11-86c4n641  nmdc:procsm-11-qpqz4w54
# 22250971  nmdc:libprp-11-86c4n641  nmdc:procsm-11-qpqz4w54
# 22250971  nmdc:libprp-11-86c4n641  nmdc:procsm-11-qpqz4w54
#
#                extract_has_output              extract_id  \
# 0         nmdc:procsm-11-6p7xet10  nmdc:extrp-11-1w7rz874
# 0         nmdc:procsm-11-6p7xet10  nmdc:extrp-11-1w7rz874
# 0         nmdc:procsm-11-6p7xet10  nmdc:extrp-11-1w7rz874
# 0         nmdc:procsm-11-6p7xet10  nmdc:extrp-11-1w7rz874
# 0         nmdc:procsm-11-6p7xet10  nmdc:extrp-11-1w7rz874
# ...                           ...                     ...
# 22250971  nmdc:procsm-11-3rfvyd88  nmdc:extrp-11-qw3ca676
# 22250971  nmdc:procsm-11-3rfvyd88  nmdc:extrp-11-qw3ca676
# 22250971  nmdc:procsm-11-3rfvyd88  nmdc:extrp-11-qw3ca676
# 22250971  nmdc:procsm-11-3rfvyd88  nmdc:extrp-11-qw3ca676
# 22250971  nmdc:procsm-11-3rfvyd88  nmdc:extrp-11-qw3ca676
#
#              pooling_has_input       pooling_has_output  \
# 0         nmdc:bsm-11-01g9wf51  nmdc:procsm-11-z19p2488
# 0         nmdc:bsm-11-01g9wf51  nmdc:procsm-11-z19p2488
# 0         nmdc:bsm-11-01g9wf51  nmdc:procsm-11-z19p2488
# 0         nmdc:bsm-11-01g9wf51  nmdc:procsm-11-z19p2488
# 0         nmdc:bsm-11-01g9wf51  nmdc:procsm-11-z19p2488
# ...                        ...                      ...
# 22250971  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54
# 22250971  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54
# 22250971  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54
# 22250971  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54
# 22250971  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54
#
#                       pooling_id soil_horizon          biosample_id  \
# 0         nmdc:poolp-11-phdxxg80    O horizon  nmdc:bsm-11-01g9wf51
# 0         nmdc:poolp-11-phdxxg80    O horizon  nmdc:bsm-11-01g9wf51
# 0         nmdc:poolp-11-phdxxg80    O horizon  nmdc:bsm-11-01g9wf51
# 0         nmdc:poolp-11-phdxxg80    O horizon  nmdc:bsm-11-01g9wf51
# 0         nmdc:poolp-11-phdxxg80    O horizon  nmdc:bsm-11-01g9wf51
# ...                          ...          ...                   ...
# 22250971  nmdc:poolp-11-evtggs98    O horizon  nmdc:bsm-11-xhzk6v39
# 22250971  nmdc:poolp-11-evtggs98    O horizon  nmdc:bsm-11-xhzk6v39
# 22250971  nmdc:poolp-11-evtggs98    O horizon  nmdc:bsm-11-xhzk6v39
# 22250971  nmdc:poolp-11-evtggs98    O horizon  nmdc:bsm-11-xhzk6v39
# 22250971  nmdc:poolp-11-evtggs98    O horizon  nmdc:bsm-11-xhzk6v39
#
#                 processed_sample1        processed_sample2  \
# 0         nmdc:procsm-11-z19p2488  nmdc:procsm-11-6p7xet10
# 0         nmdc:procsm-11-z19p2488  nmdc:procsm-11-6p7xet10
# 0         nmdc:procsm-11-z19p2488  nmdc:procsm-11-6p7xet10
# 0         nmdc:procsm-11-z19p2488  nmdc:procsm-11-6p7xet10
# 0         nmdc:procsm-11-z19p2488  nmdc:procsm-11-6p7xet10
# ...                           ...                      ...
# 22250971  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 22250971  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 22250971  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 22250971  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 22250971  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
#
#                 processed_sample3                     mga_id  \
# 0         nmdc:procsm-11-062rbk44  nmdc:wfmgan-11-f8cseh97.1
# 0         nmdc:procsm-11-062rbk44  nmdc:wfmgan-11-f8cseh97.1
# 0         nmdc:procsm-11-062rbk44  nmdc:wfmgan-11-f8cseh97.1
# 0         nmdc:procsm-11-062rbk44  nmdc:wfmgan-11-f8cseh97.1
# 0         nmdc:procsm-11-062rbk44  nmdc:wfmgan-11-f8cseh97.1
# ...                           ...                        ...
# 22250971  nmdc:procsm-11-h6y3cf29  nmdc:wfmgan-11-wcy28p27.1
# 22250971  nmdc:procsm-11-h6y3cf29  nmdc:wfmgan-11-wcy28p27.1
# 22250971  nmdc:procsm-11-h6y3cf29  nmdc:wfmgan-11-wcy28p27.1
# 22250971  nmdc:procsm-11-h6y3cf29  nmdc:wfmgan-11-wcy28p27.1
# 22250971  nmdc:procsm-11-h6y3cf29  nmdc:wfmgan-11-wcy28p27.1
#
#              mga_was_informed_by         mga_has_output
# 0         nmdc:omprc-11-bn309345  nmdc:dobj-11-f1trcg75
# 0         nmdc:omprc-11-bn309345  nmdc:dobj-11-5pqvfm47
# 0         nmdc:omprc-11-bn309345  nmdc:dobj-11-55n2dk28
# 0         nmdc:omprc-11-bn309345  nmdc:dobj-11-5x2ebc40
# 0         nmdc:omprc-11-bn309345  nmdc:dobj-11-18y0s926
# ...                          ...                    ...
# 22250971  nmdc:omprc-11-bj2afq20  nmdc:dobj-11-csq6r402
# 22250971  nmdc:omprc-11-bj2afq20  nmdc:dobj-11-wv9ha238
# 22250971  nmdc:omprc-11-bj2afq20  nmdc:dobj-11-eq8ytw35
# 22250971  nmdc:omprc-11-bj2afq20  nmdc:dobj-11-f0eg5v22
# 22250971  nmdc:omprc-11-bj2afq20  nmdc:dobj-11-7j41fk22
#
# [511772356 rows x 19 columns]

# %%
# Get data_object_set from "mga_has_output"
# Use the met_act_ann_set results identifier "mga_has_output" to query the data_object_set collection matching
# the "id" field. Return "id", "data_object_type": "Scaffold Lineage tsv", "data_object_url"
data_ob_set = get_id_results(meta_act_ann_set, "mga_has_output", "data_object_set", '"data_object_type": "Scaffold Lineage tsv", "id"', 
                             "id,data_object_type,url")

# clarify fields
for ob in data_ob_set:
    ob["data_ob_id"] = ob.pop("id")

# convert to data frame
do_df = convert_df(data_ob_set)
data_ob_set
# Out:
# [{'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-897qak81/nmdc:wfmgan-11-0w0rnd53.1/nmdc_wfmgan-11-0w0rnd53.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-1txpq765'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-bn309345/nmdc:wfmgan-11-f8cseh97.1/nmdc_wfmgan-11-f8cseh97.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-2tmqv903'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-dsv3f325/nmdc:wfmgan-11-bajw6h61.1/nmdc_wfmgan-11-bajw6h61.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-5c9hjp21'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-1zehaw93/nmdc:wfmgan-11-4h48ff64.1/nmdc_wfmgan-11-4h48ff64.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-mwz10b29'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-5qs1cd02/nmdc:wfmgan-11-h05qba23.1/nmdc_wfmgan-11-h05qba23.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-q65rb692'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-0dhzzn93/nmdc:wfmgan-11-yvsnm961.1/nmdc_wfmgan-11-yvsnm961.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-4zfne963'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-a02efk90/nmdc:wfmgan-11-h5jtsx09.1/nmdc_wfmgan-11-h5jtsx09.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-bje9wb06'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-asss2v33/nmdc:wfmgan-11-z4qsx537.1/nmdc_wfmgan-11-z4qsx537.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-g81bb758'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-bfr3b327/nmdc:wfmgan-11-471x2k50.1/nmdc_wfmgan-11-471x2k50.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-gw038y92'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-3s040k28/nmdc:wfmgan-11-0shh0w56.1/nmdc_wfmgan-11-0shh0w56.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-93fmv314'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-2845ma41/nmdc:wfmgan-11-arfx5j57.1/nmdc_wfmgan-11-arfx5j57.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-m8ete609'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-aq1gj425/nmdc:wfmgan-11-y2gyfs66.1/nmdc_wfmgan-11-y2gyfs66.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-tgegnc55'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-09rnn664/nmdc:wfmgan-11-hj734354.1/nmdc_wfmgan-11-hj734354.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-vsmqf380'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-c43r0x68/nmdc:wfmgan-11-4atn4567.1/nmdc_wfmgan-11-4atn4567.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-htcrv787'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-pwveft17/nmdc:wfmgan-11-p1ef6c60.1/nmdc_wfmgan-11-p1ef6c60.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-k1a7h684'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-k8q4cz96/nmdc:wfmgan-11-se1g5373.1/nmdc_wfmgan-11-se1g5373.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-sm4jp605'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-vnp0rc88/nmdc:wfmgan-11-rb52h977.1/nmdc_wfmgan-11-rb52h977.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-t9j8ss09'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-5z0qmq63/nmdc:wfmgan-11-7kdj9d76.1/nmdc_wfmgan-11-7kdj9d76.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-z4daqd54'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-ck4j3r66/nmdc:wfmgan-11-fvb55946.1/nmdc_wfmgan-11-fvb55946.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-8601bx91'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-jxjh8432/nmdc:wfmgan-11-jgc1g226.1/nmdc_wfmgan-11-jgc1g226.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-bzx82d33'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-db9g5v27/nmdc:wfmgan-11-59p03g42.1/nmdc_wfmgan-11-59p03g42.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-g2ay8q45'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-phmtss40/nmdc:wfmgan-11-hap21m49.1/nmdc_wfmgan-11-hap21m49.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-y4zczg16'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-yev82z97/nmdc:wfmgan-11-gecapr84.1/nmdc_wfmgan-11-gecapr84.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-40rth327'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-bw8g3t44/nmdc:wfmgan-11-n5rhxy70.1/nmdc_wfmgan-11-n5rhxy70.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-4ba8nb29'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-fem07x63/nmdc:wfmgan-11-hyhmaj10.1/nmdc_wfmgan-11-hyhmaj10.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-btmbzp26'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-m856p364/nmdc:wfmgan-11-j7yxdw35.1/nmdc_wfmgan-11-j7yxdw35.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-s97qsf16'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-fxnxgx08/nmdc:wfmgan-11-j88ejc51.1/nmdc_wfmgan-11-j88ejc51.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-4brfmq02'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-t2fdcy08/nmdc:wfmgan-11-2a0ap078.1/nmdc_wfmgan-11-2a0ap078.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-8ybd1f87'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-bp805y18/nmdc:wfmgan-11-k4fap225.1/nmdc_wfmgan-11-k4fap225.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-h3mdbc65'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-vdmtnk59/nmdc:wfmgan-11-s9vdff87.1/nmdc_wfmgan-11-s9vdff87.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-hj04gx30'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-gaptm502/nmdc:wfmgan-11-me7h8h69.1/nmdc_wfmgan-11-me7h8h69.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-xt9amn82'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-whgh5b79/nmdc:wfmgan-11-89y1xr41.1/nmdc_wfmgan-11-89y1xr41.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-4nmfq842'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-w5z0gt42/nmdc:wfmgan-11-81s4wc46.1/nmdc_wfmgan-11-81s4wc46.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-7hv2f692'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-xxvmr708/nmdc:wfmgan-11-yz9gj639.1/nmdc_wfmgan-11-yz9gj639.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-91f88529'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-ykavyj55/nmdc:wfmgan-11-za4hdt23.1/nmdc_wfmgan-11-za4hdt23.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-akhzdk33'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-ca2v9c62/nmdc:wfmgan-11-5316zr85.1/nmdc_wfmgan-11-5316zr85.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-0v4exz18'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-ymncst25/nmdc:wfmgan-11-pr2khp77.1/nmdc_wfmgan-11-pr2khp77.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-3exr0a34'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-hk2mmd05/nmdc:wfmgan-11-tz9vys31.1/nmdc_wfmgan-11-tz9vys31.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-e579m196'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-w03fjn87/nmdc:wfmgan-11-6tqwtv03.1/nmdc_wfmgan-11-6tqwtv03.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-f65myx60'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-852n2062/nmdc:wfmgan-11-qwd7t781.1/nmdc_wfmgan-11-qwd7t781.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-e79cx179'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-y9pvc628/nmdc:wfmgan-11-5pd4ef46.1/nmdc_wfmgan-11-5pd4ef46.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-h40x1j33'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-exxbxg07/nmdc:wfmgan-11-dzm8ne60.1/nmdc_wfmgan-11-dzm8ne60.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-hq7sep39'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-de7htm36/nmdc:wfmgan-11-cgf22h28.1/nmdc_wfmgan-11-cgf22h28.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-xxdkp791'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-2bpvvb18/nmdc:wfmgan-11-37m4zs87.1/nmdc_wfmgan-11-37m4zs87.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-zd650m86'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-wjmt2692/nmdc:wfmgan-11-rs865809.1/nmdc_wfmgan-11-rs865809.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-0kx01g14'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-rqf3s856/nmdc:wfmgan-11-a1xxq329.1/nmdc_wfmgan-11-a1xxq329.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-5aj7w493'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-2ysdn969/nmdc:wfmgan-11-nxp15927.1/nmdc_wfmgan-11-nxp15927.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-6m2wb013'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-da2dw160/nmdc:wfmgan-11-e7384n27.1/nmdc_wfmgan-11-e7384n27.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-r8ayg256'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-qc8gjy19/nmdc:wfmgan-11-j8jjt181.1/nmdc_wfmgan-11-j8jjt181.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-aym27963'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-jzmfjm02/nmdc:wfmgan-11-3jh0x933.1/nmdc_wfmgan-11-3jh0x933.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-f059c758'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-c5q7a198/nmdc:wfmgan-11-kt7t9c54.1/nmdc_wfmgan-11-kt7t9c54.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-kq6shz70'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-7f8f1a74/nmdc:wfmgan-11-6ec79957.1/nmdc_wfmgan-11-6ec79957.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-s8rg3460'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-w3fsh287/nmdc:wfmgan-11-nxxsrg07.1/nmdc_wfmgan-11-nxxsrg07.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-4x3a2472'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-kfxafd58/nmdc:wfmgan-11-vzmzhk85.1/nmdc_wfmgan-11-vzmzhk85.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-eyjpab34'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-bhr1m721/nmdc:wfmgan-11-sj4d0265.1/nmdc_wfmgan-11-sj4d0265.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-fs00ga15'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-597mc608/nmdc:wfmgan-11-3s20yk38.1/nmdc_wfmgan-11-3s20yk38.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-jp45gr33'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-zqcjm338/nmdc:wfmgan-11-metkav64.1/nmdc_wfmgan-11-metkav64.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-tn73bk13'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-2qjvt394/nmdc:wfmgan-11-w0d1jn82.1/nmdc_wfmgan-11-w0d1jn82.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-5vvgyv09'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-bn4p7519/nmdc:wfmgan-11-275a5p28.1/nmdc_wfmgan-11-275a5p28.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-dpc28306'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-gwwdat95/nmdc:wfmgan-11-jffc7w83.1/nmdc_wfmgan-11-jffc7w83.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-q3qcmt04'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-83e9ph40/nmdc:wfmgan-11-ej6ypt19.1/nmdc_wfmgan-11-ej6ypt19.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-qseh2f73'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-jx7v9r87/nmdc:wfmgan-11-k1yde692.1/nmdc_wfmgan-11-k1yde692.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-4qm7ep87'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-gwhrdx41/nmdc:wfmgan-11-0nn14m54.1/nmdc_wfmgan-11-0nn14m54.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-655ykg81'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-6xm74047/nmdc:wfmgan-11-6czq8z12.1/nmdc_wfmgan-11-6czq8z12.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-f67rfb44'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-swmgwd64/nmdc:wfmgan-11-4ahbwk19.1/nmdc_wfmgan-11-4ahbwk19.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-xn1rtk06'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-93ewj507/nmdc:wfmgan-11-1x944976.1/nmdc_wfmgan-11-1x944976.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-0t5ybz02'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-x9rmsf86/nmdc:wfmgan-11-r82dn255.1/nmdc_wfmgan-11-r82dn255.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-0wmmy665'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-sr1vaf20/nmdc:wfmgan-11-dbj5hp91.1/nmdc_wfmgan-11-dbj5hp91.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-3f47bj49'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-6phfec47/nmdc:wfmgan-11-6d271v55.1/nmdc_wfmgan-11-6d271v55.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-cpp2p660'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-pmzafd94/nmdc:wfmgan-11-8rnnna56.1/nmdc_wfmgan-11-8rnnna56.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-kh3wq793'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-hxf20h16/nmdc:wfmgan-11-q44bzs09.1/nmdc_wfmgan-11-q44bzs09.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-84f34g63'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-xab9cn50/nmdc:wfmgan-11-63r3p718.1/nmdc_wfmgan-11-63r3p718.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-9rm0wp83'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-mejqs923/nmdc:wfmgan-11-mek8sm49.1/nmdc_wfmgan-11-mek8sm49.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-vpjkkp39'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-22gvrx90/nmdc:wfmgan-11-3ppzvz88.1/nmdc_wfmgan-11-3ppzvz88.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-wt8wz672'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-rb0cx748/nmdc:wfmgan-11-t2jaqe36.1/nmdc_wfmgan-11-t2jaqe36.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-37cb9t48'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-dmcd0v23/nmdc:wfmgan-11-rc312c89.1/nmdc_wfmgan-11-rc312c89.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-dq5g8455'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-5p6gev16/nmdc:wfmgan-11-4mq5cn46.1/nmdc_wfmgan-11-4mq5cn46.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-jtjr7t49'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-sv6r7t07/nmdc:wfmgan-11-3hb3fp61.1/nmdc_wfmgan-11-3hb3fp61.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-kmestp10'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-apr3wf70/nmdc:wfmgan-11-j8tx4g22.1/nmdc_wfmgan-11-j8tx4g22.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-va02f935'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-2cmvwg72/nmdc:wfmgan-11-365wd896.1/nmdc_wfmgan-11-365wd896.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-4v1ppg77'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-6egc3k09/nmdc:wfmgan-11-teqemf18.1/nmdc_wfmgan-11-teqemf18.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-pmv87d97'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-t4tj7908/nmdc:wfmgan-11-jfnq4g16.1/nmdc_wfmgan-11-jfnq4g16.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-sqnv8f49'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-tq14qf97/nmdc:wfmgan-11-ecsk2g35.1/nmdc_wfmgan-11-ecsk2g35.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-zcrk3229'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-p1b0ah86/nmdc:wfmgan-11-2807wf76.1/nmdc_wfmgan-11-2807wf76.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-85csec27'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-2gc1xv62/nmdc:wfmgan-11-th027892.1/nmdc_wfmgan-11-th027892.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-khtj1m81'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-31wcds89/nmdc:wfmgan-11-hxyptc52.1/nmdc_wfmgan-11-hxyptc52.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-nh95kg50'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-wb0k2775/nmdc:wfmgan-11-20hb8m67.1/nmdc_wfmgan-11-20hb8m67.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-vg2zje78'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-3xqjtv96/nmdc:wfmgan-11-dsb6zf13.1/nmdc_wfmgan-11-dsb6zf13.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-5kem0406'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-y2xr0w67/nmdc:wfmgan-11-0kd75x18.1/nmdc_wfmgan-11-0kd75x18.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-9nfp9618'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-4wqcs493/nmdc:wfmgan-11-3p8e1j62.1/nmdc_wfmgan-11-3p8e1j62.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-r8cgr506'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-09rnn664/nmdc:wfmgan-11-hj734354.1/nmdc_wfmgan-11-hj734354.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-vsmqf380'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-ekndcj87/nmdc:wfmgan-11-kvy67m30.1/nmdc_wfmgan-11-kvy67m30.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-ypbdtc09'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-hhfd9935/nmdc:wfmgan-11-men7b656.1/nmdc_wfmgan-11-men7b656.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-4909te38'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-3g4z6x82/nmdc:wfmgan-11-1n64jf54.1/nmdc_wfmgan-11-1n64jf54.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-896ftz42'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-ywydqk30/nmdc:wfmgan-11-pjmd1142.1/nmdc_wfmgan-11-pjmd1142.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-dgrngm66'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-htac6662/nmdc:wfmgan-11-vkf49q20.1/nmdc_wfmgan-11-vkf49q20.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-erxjvf31'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-5xgghs51/nmdc:wfmgan-11-x15zc073.1/nmdc_wfmgan-11-x15zc073.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-40k7j517'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-78118g42/nmdc:wfmgan-11-8nw4kw82.1/nmdc_wfmgan-11-8nw4kw82.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-cgad3453'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-jknw0051/nmdc:wfmgan-11-4ykbxr44.1/nmdc_wfmgan-11-4ykbxr44.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-kbc26j96'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-nvdmvk80/nmdc:wfmgan-11-ddaj4w08.1/nmdc_wfmgan-11-ddaj4w08.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-s8pe7t20'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-f3jgs673/nmdc:wfmgan-11-x5ej3r87.1/nmdc_wfmgan-11-x5ej3r87.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-b9sf4187'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-vvxt3623/nmdc:wfmgan-11-6ghvpf53.1/nmdc_wfmgan-11-6ghvpf53.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-bvyypm86'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-veygr030/nmdc:wfmgan-11-smtsz862.1/nmdc_wfmgan-11-smtsz862.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-mmagyt86'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-zgvjcw18/nmdc:wfmgan-11-nkf1eq87.1/nmdc_wfmgan-11-nkf1eq87.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-sc5msk37'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-mwr8jt42/nmdc:wfmgan-11-mrhr9x36.1/nmdc_wfmgan-11-mrhr9x36.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-svp9q970'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-0qh2xq44/nmdc:wfmgan-11-yczr9379.1/nmdc_wfmgan-11-yczr9379.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-5vswgr86'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-2rmrpn30/nmdc:wfmgan-11-r5d51239.1/nmdc_wfmgan-11-r5d51239.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-jaddfg44'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-kqrvtx54/nmdc:wfmgan-11-npa48c80.1/nmdc_wfmgan-11-npa48c80.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-jx7sgv21'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-gvajp749/nmdc:wfmgan-11-e2z5mw73.1/nmdc_wfmgan-11-e2z5mw73.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-rwchez75'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-8sxv2v10/nmdc:wfmgan-11-85y3n726.1/nmdc_wfmgan-11-85y3n726.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-2sg47t96'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-vdmtnk59/nmdc:wfmgan-11-s9vdff87.1/nmdc_wfmgan-11-s9vdff87.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-hj04gx30'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-qxq15411/nmdc:wfmgan-11-9v130b74.1/nmdc_wfmgan-11-9v130b74.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-wh0g6g42'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-47vkxb21/nmdc:wfmgan-11-px3wdj46.1/nmdc_wfmgan-11-px3wdj46.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-xypbre90'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-pbjwby75/nmdc:wfmgan-11-3s0p4v02.1/nmdc_wfmgan-11-3s0p4v02.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-3pzgey84'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-w5z0gt42/nmdc:wfmgan-11-81s4wc46.1/nmdc_wfmgan-11-81s4wc46.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-7hv2f692'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-xh4kh516/nmdc:wfmgan-11-qdnf2d27.1/nmdc_wfmgan-11-qdnf2d27.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-97mfj343'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-1j92pc25/nmdc:wfmgan-11-tm94dj79.1/nmdc_wfmgan-11-tm94dj79.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-9fjvjj33'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-g1n61y55/nmdc:wfmgan-11-a8vh7c47.1/nmdc_wfmgan-11-a8vh7c47.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-bxdpkq28'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-5s7vzk21/nmdc:wfmgan-11-p42n8w86.1/nmdc_wfmgan-11-p42n8w86.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-4rh52k34'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-jcyvah08/nmdc:wfmgan-11-qk9xm455.1/nmdc_wfmgan-11-qk9xm455.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-7fgf8y65'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-m39s7390/nmdc:wfmgan-11-y4y3j582.1/nmdc_wfmgan-11-y4y3j582.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-dkjvsm83'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-gmc8vw02/nmdc:wfmgan-11-5emww522.1/nmdc_wfmgan-11-5emww522.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-h3c9s913'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-b00gvb88/nmdc:wfmgan-11-esyej945.1/nmdc_wfmgan-11-esyej945.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-0kwb1y76'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-7af3as25/nmdc:wfmgan-11-k8jbbm82.1/nmdc_wfmgan-11-k8jbbm82.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-9h4ats42'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-y0ktvn63/nmdc:wfmgan-11-xn5jsw02.1/nmdc_wfmgan-11-xn5jsw02.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-gqqgah38'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-cxp40y98/nmdc:wfmgan-11-tmy3js98.1/nmdc_wfmgan-11-tmy3js98.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-k27ysp18'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-sjxfmc14/nmdc:wfmgan-11-jyn33c87.1/nmdc_wfmgan-11-jyn33c87.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-2dngwd56'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-nb17kn66/nmdc:wfmgan-11-cn5m4g76.1/nmdc_wfmgan-11-cn5m4g76.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-2x26cs19'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-z8kfwq53/nmdc:wfmgan-11-mb3rsa72.1/nmdc_wfmgan-11-mb3rsa72.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-k2anrp85'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-gjy9qr80/nmdc:wfmgan-11-0g9x4j10.1/nmdc_wfmgan-11-0g9x4j10.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-mw0fbx21'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-fab8e775/nmdc:wfmgan-11-pkk79r08.1/nmdc_wfmgan-11-pkk79r08.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-tpsfdk92'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-prd07992/nmdc:wfmgan-11-ygy92a27.1/nmdc_wfmgan-11-ygy92a27.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-1qgmdx53'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-60k8kc41/nmdc:wfmgan-11-y8rvwp25.1/nmdc_wfmgan-11-y8rvwp25.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-7tse3w31'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-qnnzbj98/nmdc:wfmgan-11-cd5qzb67.1/nmdc_wfmgan-11-cd5qzb67.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-cfczh102'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-vy4fgz48/nmdc:wfmgan-11-mr75gq77.1/nmdc_wfmgan-11-mr75gq77.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-vtgff569'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-g4zw0752/nmdc:wfmgan-11-prdvmp57.1/nmdc_wfmgan-11-prdvmp57.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-b9vefp14'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-2mveyn71/nmdc:wfmgan-11-z06y8x34.1/nmdc_wfmgan-11-z06y8x34.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-fmchrs96'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-b7jra430/nmdc:wfmgan-11-qymvpv29.1/nmdc_wfmgan-11-qymvpv29.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-tmww6c41'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-x8gwh062/nmdc:wfmgan-11-smpd0e92.1/nmdc_wfmgan-11-smpd0e92.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-wp5qbx24'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-daxdrw75/nmdc:wfmgan-11-033a9244.1/nmdc_wfmgan-11-033a9244.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-4pf60j92'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-kvthrw62/nmdc:wfmgan-11-m2ycfa37.1/nmdc_wfmgan-11-m2ycfa37.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-61yfm102'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-fmz29h69/nmdc:wfmgan-11-4t36z815.1/nmdc_wfmgan-11-4t36z815.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-khwxp428'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-21qpd693/nmdc:wfmgan-11-fz97vg28.1/nmdc_wfmgan-11-fz97vg28.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-pcfdzj53'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-5kn2zh91/nmdc:wfmgan-11-bewmab04.1/nmdc_wfmgan-11-bewmab04.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-v2hnrz96'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-r5w9js52/nmdc:wfmgan-11-k5a19412.1/nmdc_wfmgan-11-k5a19412.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-b6yhf780'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-80c4jw80/nmdc:wfmgan-11-b1nhgt16.1/nmdc_wfmgan-11-b1nhgt16.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-s4wxts45'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-7tbczg51/nmdc:wfmgan-11-aghgwe25.1/nmdc_wfmgan-11-aghgwe25.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-sbzv4z74'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-yt96hb84/nmdc:wfmgan-11-hv3nyk36.1/nmdc_wfmgan-11-hv3nyk36.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-wn5g7j41'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-83n27v52/nmdc:wfmgan-11-919m9x18.1/nmdc_wfmgan-11-919m9x18.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-5gb2rn71'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-5yawgk13/nmdc:wfmgan-11-p19b7z91.1/nmdc_wfmgan-11-p19b7z91.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-5ngg0s81'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-vdxzkj27/nmdc:wfmgan-11-bdm02t61.1/nmdc_wfmgan-11-bdm02t61.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-72mbnn39'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-bfzvq515/nmdc:wfmgan-11-ht0p8b23.1/nmdc_wfmgan-11-ht0p8b23.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-xjdptv38'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-2wjed166/nmdc:wfmgan-11-80qjzd16.1/nmdc_wfmgan-11-80qjzd16.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-0jya2n04'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-x9rmsf86/nmdc:wfmgan-11-r82dn255.1/nmdc_wfmgan-11-r82dn255.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-0wmmy665'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-dycnft20/nmdc:wfmgan-11-44swgm21.1/nmdc_wfmgan-11-44swgm21.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-kqgcme54'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-0m0x8n29/nmdc:wfmgan-11-k0xae948.1/nmdc_wfmgan-11-k0xae948.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-qzj87v56'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-22gvrx90/nmdc:wfmgan-11-3ppzvz88.1/nmdc_wfmgan-11-3ppzvz88.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-wt8wz672'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-zs3z6x34/nmdc:wfmgan-11-4yxxw746.1/nmdc_wfmgan-11-4yxxw746.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-1780sq75'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-fg7r0h25/nmdc:wfmgan-11-x6yy4129.1/nmdc_wfmgan-11-x6yy4129.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-7bwvh104'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-m9k5dd52/nmdc:wfmgan-11-d0za9s67.1/nmdc_wfmgan-11-d0za9s67.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-dn0snj80'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-v120sa54/nmdc:wfmgan-11-ngfht152.1/nmdc_wfmgan-11-ngfht152.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-st0hmr78'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-cpqbew37/nmdc:wfmgan-11-dxqxre60.1/nmdc_wfmgan-11-dxqxre60.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-1n0vjp57'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-d0ta0736/nmdc:wfmgan-11-8c2vrd14.1/nmdc_wfmgan-11-8c2vrd14.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-nt1e4d29'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-c82tqn53/nmdc:wfmgan-11-31q58f08.1/nmdc_wfmgan-11-31q58f08.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-xn58xf16'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-25dkek26/nmdc:wfmgan-11-d99g3v61.1/nmdc_wfmgan-11-d99g3v61.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-xygq6368'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-dwv6tc51/nmdc:wfmgan-11-dv7ft186.1/nmdc_wfmgan-11-dv7ft186.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-254dhh36'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-2cmvwg72/nmdc:wfmgan-11-365wd896.1/nmdc_wfmgan-11-365wd896.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-4v1ppg77'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-2yjgda67/nmdc:wfmgan-11-nh1z7n35.1/nmdc_wfmgan-11-nh1z7n35.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-8680cz98'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-qtg9bb25/nmdc:wfmgan-11-fn0vhz16.1/nmdc_wfmgan-11-fn0vhz16.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-a3zwkw87'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-x1pjk970/nmdc:wfmgan-11-wmfd0259.1/nmdc_wfmgan-11-wmfd0259.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-pkskv321'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-w2p4nc76/nmdc:wfmgan-11-hppc1019.1/nmdc_wfmgan-11-hppc1019.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-3f0b0w17'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-afejca38/nmdc:wfmgan-11-fyrz6f54.1/nmdc_wfmgan-11-fyrz6f54.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-5apjp861'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-15r5j518/nmdc:wfmgan-11-ynfp6547.1/nmdc_wfmgan-11-ynfp6547.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-jmfrp088'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-bd1eyb41/nmdc:wfmgan-11-rakcvw57.1/nmdc_wfmgan-11-rakcvw57.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-p13s3p44'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-n8nnjh10/nmdc:wfmgan-11-a41hhm59.1/nmdc_wfmgan-11-a41hhm59.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-1tn3k788'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-qy0q5q77/nmdc:wfmgan-11-k9bsgx15.1/nmdc_wfmgan-11-k9bsgx15.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-5abrtm15'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-0vmz5w53/nmdc:wfmgan-11-s3ejfg38.1/nmdc_wfmgan-11-s3ejfg38.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-5tz0y394'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-aytgf579/nmdc:wfmgan-11-xe27h078.1/nmdc_wfmgan-11-xe27h078.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-gteffa74'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-bfr3b327/nmdc:wfmgan-11-471x2k50.1/nmdc_wfmgan-11-471x2k50.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-gw038y92'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-9pe8j592/nmdc:wfmgan-11-n6ctjd23.1/nmdc_wfmgan-11-n6ctjd23.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-fhqcdp97'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-8e9ry887/nmdc:wfmgan-11-fr6cc573.1/nmdc_wfmgan-11-fr6cc573.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-ny0gdn49'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-sakwzf36/nmdc:wfmgan-11-wr0xbd55.1/nmdc_wfmgan-11-wr0xbd55.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-pkdqj374'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-f6bz1n52/nmdc:wfmgan-11-ptgvmn89.1/nmdc_wfmgan-11-ptgvmn89.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-rjrfg255'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-yx04pf55/nmdc:wfmgan-11-127vbe18.1/nmdc_wfmgan-11-127vbe18.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-6c2hmb72'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-h4nwgb07/nmdc:wfmgan-11-3ar8p249.1/nmdc_wfmgan-11-3ar8p249.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-9et8h995'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-88ndhh63/nmdc:wfmgan-11-a4egze82.1/nmdc_wfmgan-11-a4egze82.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-akmxc284'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-pqkc5p98/nmdc:wfmgan-11-0dxb2911.1/nmdc_wfmgan-11-0dxb2911.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-t9f2dc70'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-bhy7wv97/nmdc:wfmgan-11-mdzecm21.1/nmdc_wfmgan-11-mdzecm21.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-64c85z05'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-krmyy298/nmdc:wfmgan-11-f5yzte75.1/nmdc_wfmgan-11-f5yzte75.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-bkfr8e08'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-b6zknx41/nmdc:wfmgan-11-bzrkdc32.1/nmdc_wfmgan-11-bzrkdc32.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-dj3e3659'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-c43r0x68/nmdc:wfmgan-11-4atn4567.1/nmdc_wfmgan-11-4atn4567.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-htcrv787'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-617q4r95/nmdc:wfmgan-11-wsenb285.1/nmdc_wfmgan-11-wsenb285.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-nq0h2v81'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-b4pyrg82/nmdc:wfmgan-11-f5qjsj44.1/nmdc_wfmgan-11-f5qjsj44.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-1q9qat68'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-rfmhbq83/nmdc:wfmgan-11-kmffhs17.1/nmdc_wfmgan-11-kmffhs17.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-9bepjt93'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-zaf5n998/nmdc:wfmgan-11-5d9ssv57.1/nmdc_wfmgan-11-5d9ssv57.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-d3krff43'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-q2pwpg27/nmdc:wfmgan-11-evkyq056.1/nmdc_wfmgan-11-evkyq056.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-xhgf8057'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-y2abzp32/nmdc:wfmgan-11-64xpat33.1/nmdc_wfmgan-11-64xpat33.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-0ve34w93'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-2qt7nb51/nmdc:wfmgan-11-6313q932.1/nmdc_wfmgan-11-6313q932.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-v6cdbp94'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-gbc1ee66/nmdc:wfmgan-11-23cpdc27.1/nmdc_wfmgan-11-23cpdc27.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-xs0gxd33'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-97zvzq04/nmdc:wfmgan-11-p9nc7v57.1/nmdc_wfmgan-11-p9nc7v57.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-zq2ph020'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-xryz2k69/nmdc:wfmgan-11-jebyvv96.1/nmdc_wfmgan-11-jebyvv96.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-0d4mxa40'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-nesvby70/nmdc:wfmgan-11-cb2z1b70.1/nmdc_wfmgan-11-cb2z1b70.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-2netyx02'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-8ev1rj93/nmdc:wfmgan-11-pmxpry37.1/nmdc_wfmgan-11-pmxpry37.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-cfvv4s17'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-m95hm211/nmdc:wfmgan-11-egd42q75.1/nmdc_wfmgan-11-egd42q75.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-emef2j36'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-3q2xzk33/nmdc:wfmgan-11-q3bm3y68.1/nmdc_wfmgan-11-q3bm3y68.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-f5rpx963'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-8vrqxx82/nmdc:wfmgan-11-affs4241.1/nmdc_wfmgan-11-affs4241.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-4aag4222'},
# ...
#   'data_ob_id': 'nmdc:dobj-11-j3v54513'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-9d461424/nmdc:wfmgan-11-c6b5qh12.1/nmdc_wfmgan-11-c6b5qh12.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-jprr2130'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-bcg1j086/nmdc:wfmgan-11-13a9g797.1/nmdc_wfmgan-11-13a9g797.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-pg13am42'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-pg8y3y83/nmdc:wfmgan-11-pptxqp86.1/nmdc_wfmgan-11-pptxqp86.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-tmhca527'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-8b78ye85/nmdc:wfmgan-11-ha96ad87.1/nmdc_wfmgan-11-ha96ad87.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-7vc50365'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-agy1s771/nmdc:wfmgan-11-p4q3nf17.1/nmdc_wfmgan-11-p4q3nf17.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-emh6hj22'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-p83h5y28/nmdc:wfmgan-11-aj4e8e76.1/nmdc_wfmgan-11-aj4e8e76.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-n0bd3849'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-s1bh2q40/nmdc:wfmgan-11-pcf9bn90.1/nmdc_wfmgan-11-pcf9bn90.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-pbfxqy54'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-q3pdkz63/nmdc:wfmgan-11-mj2vgg58.1/nmdc_wfmgan-11-mj2vgg58.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-0ssgc358'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-zrf11404/nmdc:wfmgan-11-bzw1k684.1/nmdc_wfmgan-11-bzw1k684.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-28c6d722'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-znmnkn62/nmdc:wfmgan-11-8fcx5f54.1/nmdc_wfmgan-11-8fcx5f54.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-2ch8tr52'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-pq1z5d52/nmdc:wfmgan-11-vvyfg047.1/nmdc_wfmgan-11-vvyfg047.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-ra4men93'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-mejqs923/nmdc:wfmgan-11-mek8sm49.1/nmdc_wfmgan-11-mek8sm49.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-vpjkkp39'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-dwv6tc51/nmdc:wfmgan-11-dv7ft186.1/nmdc_wfmgan-11-dv7ft186.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-254dhh36'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-6yffsq64/nmdc:wfmgan-11-0pgbdd19.1/nmdc_wfmgan-11-0pgbdd19.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-bey38181'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-26gxr848/nmdc:wfmgan-11-0sek4n80.1/nmdc_wfmgan-11-0sek4n80.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-cbznkz13'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-nt0rye27/nmdc:wfmgan-11-1jepys31.1/nmdc_wfmgan-11-1jepys31.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-sx3w6a81'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-1d59xy76/nmdc:wfmgan-11-c6vgde63.1/nmdc_wfmgan-11-c6vgde63.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-6gq89771'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-1qamr118/nmdc:wfmgan-11-x1rt8n96.1/nmdc_wfmgan-11-x1rt8n96.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-82r1n392'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-pj9x9747/nmdc:wfmgan-11-8nbges37.1/nmdc_wfmgan-11-8nbges37.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-ex2a3w07'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-ey7qx203/nmdc:wfmgan-11-rh4rvf29.1/nmdc_wfmgan-11-rh4rvf29.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-szsa7397'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-cegmwy02/nmdc:wfmgan-11-6x59p192.1/nmdc_wfmgan-11-6x59p192.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-12c5en51'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-z8q3g912/nmdc:wfmgan-11-ykb8p905.1/nmdc_wfmgan-11-ykb8p905.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-1weq3319'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-6vtfac51/nmdc:wfmgan-11-gpc4ms34.1/nmdc_wfmgan-11-gpc4ms34.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-jypt5s64'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-1hm7np87/nmdc:wfmgan-11-4g128f12.1/nmdc_wfmgan-11-4g128f12.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-m6tegs60'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-t3k75h46/nmdc:wfmgan-11-3fp1x319.1/nmdc_wfmgan-11-3fp1x319.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-rzsgkp44'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-w2p4nc76/nmdc:wfmgan-11-hppc1019.1/nmdc_wfmgan-11-hppc1019.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-3f0b0w17'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-15r5j518/nmdc:wfmgan-11-ynfp6547.1/nmdc_wfmgan-11-ynfp6547.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-jmfrp088'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-w7xxkd92/nmdc:wfmgan-11-m1m0mp70.1/nmdc_wfmgan-11-m1m0mp70.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-mjk8t717'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-28hrvs52/nmdc:wfmgan-11-b5tx0d39.1/nmdc_wfmgan-11-b5tx0d39.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-yjc1se35'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-s3tknr21/nmdc:wfmgan-11-6ehd2h03.1/nmdc_wfmgan-11-6ehd2h03.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-b15brt35'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-5x4z1d97/nmdc:wfmgan-11-fag6k113.1/nmdc_wfmgan-11-fag6k113.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-v9sp6h70'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-63xwbh77/nmdc:wfmgan-11-66t92750.1/nmdc_wfmgan-11-66t92750.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-xaz9t625'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-220jhv04/nmdc:wfmgan-11-by3amz33.1/nmdc_wfmgan-11-by3amz33.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-xhfp2f79'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-p0mfyx84/nmdc:wfmgan-11-bkkfc176.1/nmdc_wfmgan-11-bkkfc176.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-9gjd5x06'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-acpj2y66/nmdc:wfmgan-11-pqzs4839.1/nmdc_wfmgan-11-pqzs4839.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-g8xtkd03'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-3he9pk43/nmdc:wfmgan-11-r2mjpv57.1/nmdc_wfmgan-11-r2mjpv57.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-m14x5w04'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-jzp8b133/nmdc:wfmgan-11-rndrjd52.1/nmdc_wfmgan-11-rndrjd52.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-q23jn377'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-f9qygr38/nmdc:wfmgan-11-cmq0x402.1/nmdc_wfmgan-11-cmq0x402.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-wawbx330'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-1tc66q25/nmdc:wfmgan-11-7p9szh40.1/nmdc_wfmgan-11-7p9szh40.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-1r9h3123'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-grz9y881/nmdc:wfmgan-11-46nybs07.1/nmdc_wfmgan-11-46nybs07.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-4cf8dx25'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-hhgbvw83/nmdc:wfmgan-11-g9xw7k19.1/nmdc_wfmgan-11-g9xw7k19.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-asd85962'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-tppjmj36/nmdc:wfmgan-11-qfvvh171.1/nmdc_wfmgan-11-qfvvh171.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-xnt4vg47'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-hb3c1f19/nmdc:wfmgan-11-8enm7z30.1/nmdc_wfmgan-11-8enm7z30.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-ew2egt75'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-4yegje50/nmdc:wfmgan-11-vffgvv94.1/nmdc_wfmgan-11-vffgvv94.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-p4149x68'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-nvdmvk80/nmdc:wfmgan-11-ddaj4w08.1/nmdc_wfmgan-11-ddaj4w08.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-s8pe7t20'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-w5pew967/nmdc:wfmgan-11-ffvep682.1/nmdc_wfmgan-11-ffvep682.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-tk4w0h03'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-7v3p5n74/nmdc:wfmgan-11-jrwfpk82.1/nmdc_wfmgan-11-jrwfpk82.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-z4mc6227'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-50ms8c40/nmdc:wfmgan-11-qpf18884.1/nmdc_wfmgan-11-qpf18884.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-0856eg91'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-pxzk3z57/nmdc:wfmgan-11-nqaffn06.1/nmdc_wfmgan-11-nqaffn06.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-b2h43k53'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-g4j6t827/nmdc:wfmgan-11-982d6v69.1/nmdc_wfmgan-11-982d6v69.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-pvy5jf42'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-4cwyd645/nmdc:wfmgan-11-h426ka29.1/nmdc_wfmgan-11-h426ka29.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-rxq18711'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-a8vgz366/nmdc:wfmgan-11-baxznx51.1/nmdc_wfmgan-11-baxznx51.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-0x9p4m31'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-62y3k087/nmdc:wfmgan-11-brk8pz70.1/nmdc_wfmgan-11-brk8pz70.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-nyv5rh14'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-gc9kdm55/nmdc:wfmgan-11-s7zb8a89.1/nmdc_wfmgan-11-s7zb8a89.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-pjpg3j03'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-j5zf8629/nmdc:wfmgan-11-cwakvp96.1/nmdc_wfmgan-11-cwakvp96.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-r8nbyd23'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-m49d9z91/nmdc:wfmgan-11-rf1skb36.1/nmdc_wfmgan-11-rf1skb36.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-6akksh10'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-nr7m8f94/nmdc:wfmgan-11-xm5jqn39.1/nmdc_wfmgan-11-xm5jqn39.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-7qxt8k38'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-q5vqjj73/nmdc:wfmgan-11-58dfda82.1/nmdc_wfmgan-11-58dfda82.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-8fgnsx89'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-j2tnaj68/nmdc:wfmgan-11-r6n8m380.1/nmdc_wfmgan-11-r6n8m380.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-hgt1vm54'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-pp00bw52/nmdc:wfmgan-11-dc68pc41.1/nmdc_wfmgan-11-dc68pc41.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-ntdeah89'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-4b6r5h97/nmdc:wfmgan-11-k2ejwc45.1/nmdc_wfmgan-11-k2ejwc45.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-1zgx2758'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-tymmbp21/nmdc:wfmgan-11-w10bzq77.1/nmdc_wfmgan-11-w10bzq77.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-5bfgvf70'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-2ax0rb32/nmdc:wfmgan-11-5680m666.1/nmdc_wfmgan-11-5680m666.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-ghmcy606'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-dtjzm916/nmdc:wfmgan-11-je110n74.1/nmdc_wfmgan-11-je110n74.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-tzhg6q93'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-j2g5gg95/nmdc:wfmgan-11-60k2be29.1/nmdc_wfmgan-11-60k2be29.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-395q3187'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-kya07x35/nmdc:wfmgan-11-tj9pd551.1/nmdc_wfmgan-11-tj9pd551.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-bqempa71'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-nq2bdm29/nmdc:wfmgan-11-thx9w472.1/nmdc_wfmgan-11-thx9w472.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-jdz72b93'},
#  {'data_object_type': 'Scaffold Lineage tsv',
#   'url': 'https://data.microbiomedata.org/data/nmdc:omprc-11-4tekbg11/nmdc:wfmgan-11-m52scw91.1/nmdc_wfmgan-11-m52scw91.1_scaffold_lineage.tsv',
#   'data_ob_id': 'nmdc:dobj-11-zk4f3q87'},
#  ...]

# %%
# Merge data_object_set with merged_list on id
merged_df9 = merge_items(do_df, merged_df8, "data_ob_id", "mga_has_output", False, False)
merged_df9
# Out:
#               data_object_type  \
# 0         Scaffold Lineage tsv
# 1         Scaffold Lineage tsv
# 2         Scaffold Lineage tsv
# 3         Scaffold Lineage tsv
# 4         Scaffold Lineage tsv
# ...                        ...
# 66467911  Scaffold Lineage tsv
# 66467912  Scaffold Lineage tsv
# 66467913  Scaffold Lineage tsv
# 66467914  Scaffold Lineage tsv
# 66467915  Scaffold Lineage tsv
#
#                                                         url  \
# 0         https://data.microbiomedata.org/data/nmdc:ompr...
# 1         https://data.microbiomedata.org/data/nmdc:ompr...
# 2         https://data.microbiomedata.org/data/nmdc:ompr...
# 3         https://data.microbiomedata.org/data/nmdc:ompr...
# 4         https://data.microbiomedata.org/data/nmdc:ompr...
# ...                                                     ...
# 66467911  https://data.microbiomedata.org/data/nmdc:ompr...
# 66467912  https://data.microbiomedata.org/data/nmdc:ompr...
# 66467913  https://data.microbiomedata.org/data/nmdc:ompr...
# 66467914  https://data.microbiomedata.org/data/nmdc:ompr...
# 66467915  https://data.microbiomedata.org/data/nmdc:ompr...
#
#                      data_ob_id             op_has_input  \
# 0         nmdc:dobj-11-1txpq765  nmdc:procsm-11-je3jg029
# 1         nmdc:dobj-11-1txpq765  nmdc:procsm-11-je3jg029
# 2         nmdc:dobj-11-1txpq765  nmdc:procsm-11-je3jg029
# 3         nmdc:dobj-11-1txpq765  nmdc:procsm-11-je3jg029
# 4         nmdc:dobj-11-1txpq765  nmdc:procsm-11-je3jg029
# ...                         ...                      ...
# 66467911  nmdc:dobj-11-5wyv2j19  nmdc:procsm-11-h6y3cf29
# 66467912  nmdc:dobj-11-5wyv2j19  nmdc:procsm-11-h6y3cf29
# 66467913  nmdc:dobj-11-5wyv2j19  nmdc:procsm-11-h6y3cf29
# 66467914  nmdc:dobj-11-5wyv2j19  nmdc:procsm-11-h6y3cf29
# 66467915  nmdc:dobj-11-5wyv2j19  nmdc:procsm-11-h6y3cf29
#
#                            op_id             lp_has_input  \
# 0         nmdc:omprc-11-897qak81  nmdc:procsm-11-4508yv43
# 1         nmdc:omprc-11-897qak81  nmdc:procsm-11-4508yv43
# 2         nmdc:omprc-11-897qak81  nmdc:procsm-11-4508yv43
# 3         nmdc:omprc-11-897qak81  nmdc:procsm-11-4508yv43
# 4         nmdc:omprc-11-897qak81  nmdc:procsm-11-4508yv43
# ...                          ...                      ...
# 66467911  nmdc:omprc-11-bj2afq20  nmdc:procsm-11-3rfvyd88
# 66467912  nmdc:omprc-11-bj2afq20  nmdc:procsm-11-3rfvyd88
# 66467913  nmdc:omprc-11-bj2afq20  nmdc:procsm-11-3rfvyd88
# 66467914  nmdc:omprc-11-bj2afq20  nmdc:procsm-11-3rfvyd88
# 66467915  nmdc:omprc-11-bj2afq20  nmdc:procsm-11-3rfvyd88
#
#                     lp_has_output                    lp_id  \
# 0         nmdc:procsm-11-je3jg029  nmdc:libprp-11-7ffq2g12
# 1         nmdc:procsm-11-je3jg029  nmdc:libprp-11-7ffq2g12
# 2         nmdc:procsm-11-je3jg029  nmdc:libprp-11-7ffq2g12
# 3         nmdc:procsm-11-je3jg029  nmdc:libprp-11-7ffq2g12
# 4         nmdc:procsm-11-je3jg029  nmdc:libprp-11-7ffq2g12
# ...                           ...                      ...
# 66467911  nmdc:procsm-11-h6y3cf29  nmdc:libprp-11-86c4n641
# 66467912  nmdc:procsm-11-h6y3cf29  nmdc:libprp-11-86c4n641
# 66467913  nmdc:procsm-11-h6y3cf29  nmdc:libprp-11-86c4n641
# 66467914  nmdc:procsm-11-h6y3cf29  nmdc:libprp-11-86c4n641
# 66467915  nmdc:procsm-11-h6y3cf29  nmdc:libprp-11-86c4n641
#
#                 extract_has_input       extract_has_output  ...  \
# 0         nmdc:procsm-11-xdbhma02  nmdc:procsm-11-4508yv43  ...
# 1         nmdc:procsm-11-xdbhma02  nmdc:procsm-11-4508yv43  ...
# 2         nmdc:procsm-11-xdbhma02  nmdc:procsm-11-4508yv43  ...
# 3         nmdc:procsm-11-xdbhma02  nmdc:procsm-11-4508yv43  ...
# 4         nmdc:procsm-11-xdbhma02  nmdc:procsm-11-4508yv43  ...
# ...                           ...                      ...  ...
# 66467911  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88  ...
# 66467912  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88  ...
# 66467913  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88  ...
# 66467914  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88  ...
# 66467915  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88  ...
#
#                pooling_has_output              pooling_id soil_horizon  \
# 0         nmdc:procsm-11-xdbhma02  nmdc:poolp-11-5p6tjm70    M horizon
# 1         nmdc:procsm-11-xdbhma02  nmdc:poolp-11-5p6tjm70    M horizon
# 2         nmdc:procsm-11-xdbhma02  nmdc:poolp-11-5p6tjm70    M horizon
# 3         nmdc:procsm-11-xdbhma02  nmdc:poolp-11-5p6tjm70    M horizon
# 4         nmdc:procsm-11-xdbhma02  nmdc:poolp-11-5p6tjm70    M horizon
# ...                           ...                     ...          ...
# 66467911  nmdc:procsm-11-qpqz4w54  nmdc:poolp-11-evtggs98    O horizon
# 66467912  nmdc:procsm-11-qpqz4w54  nmdc:poolp-11-evtggs98    O horizon
# 66467913  nmdc:procsm-11-qpqz4w54  nmdc:poolp-11-evtggs98    O horizon
# 66467914  nmdc:procsm-11-qpqz4w54  nmdc:poolp-11-evtggs98    O horizon
# 66467915  nmdc:procsm-11-qpqz4w54  nmdc:poolp-11-evtggs98    O horizon
#
#                   biosample_id        processed_sample1  \
# 0         nmdc:bsm-11-158pa966  nmdc:procsm-11-xdbhma02
# 1         nmdc:bsm-11-158pa966  nmdc:procsm-11-xdbhma02
# 2         nmdc:bsm-11-158pa966  nmdc:procsm-11-xdbhma02
# 3         nmdc:bsm-11-158pa966  nmdc:procsm-11-xdbhma02
# 4         nmdc:bsm-11-158pa966  nmdc:procsm-11-xdbhma02
# ...                        ...                      ...
# 66467911  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54
# 66467912  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54
# 66467913  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54
# 66467914  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54
# 66467915  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54
#
#                 processed_sample2        processed_sample3  \
# 0         nmdc:procsm-11-4508yv43  nmdc:procsm-11-je3jg029
# 1         nmdc:procsm-11-4508yv43  nmdc:procsm-11-je3jg029
# 2         nmdc:procsm-11-4508yv43  nmdc:procsm-11-je3jg029
# 3         nmdc:procsm-11-4508yv43  nmdc:procsm-11-je3jg029
# 4         nmdc:procsm-11-4508yv43  nmdc:procsm-11-je3jg029
# ...                           ...                      ...
# 66467911  nmdc:procsm-11-3rfvyd88  nmdc:procsm-11-h6y3cf29
# 66467912  nmdc:procsm-11-3rfvyd88  nmdc:procsm-11-h6y3cf29
# 66467913  nmdc:procsm-11-3rfvyd88  nmdc:procsm-11-h6y3cf29
# 66467914  nmdc:procsm-11-3rfvyd88  nmdc:procsm-11-h6y3cf29
# 66467915  nmdc:procsm-11-3rfvyd88  nmdc:procsm-11-h6y3cf29
#
#                              mga_id     mga_was_informed_by  \
# 0         nmdc:wfmgan-11-0w0rnd53.1  nmdc:omprc-11-897qak81
# 1         nmdc:wfmgan-11-0w0rnd53.1  nmdc:omprc-11-897qak81
# 2         nmdc:wfmgan-11-0w0rnd53.1  nmdc:omprc-11-897qak81
# 3         nmdc:wfmgan-11-0w0rnd53.1  nmdc:omprc-11-897qak81
# 4         nmdc:wfmgan-11-0w0rnd53.1  nmdc:omprc-11-897qak81
# ...                             ...                     ...
# 66467911  nmdc:wfmgan-11-wcy28p27.1  nmdc:omprc-11-bj2afq20
# 66467912  nmdc:wfmgan-11-wcy28p27.1  nmdc:omprc-11-bj2afq20
# 66467913  nmdc:wfmgan-11-wcy28p27.1  nmdc:omprc-11-bj2afq20
# 66467914  nmdc:wfmgan-11-wcy28p27.1  nmdc:omprc-11-bj2afq20
# 66467915  nmdc:wfmgan-11-wcy28p27.1  nmdc:omprc-11-bj2afq20
#
#                  mga_has_output
# 0         nmdc:dobj-11-1txpq765
# 1         nmdc:dobj-11-1txpq765
# 2         nmdc:dobj-11-1txpq765
# 3         nmdc:dobj-11-1txpq765
# 4         nmdc:dobj-11-1txpq765
# ...                         ...
# 66467911  nmdc:dobj-11-5wyv2j19
# 66467912  nmdc:dobj-11-5wyv2j19
# 66467913  nmdc:dobj-11-5wyv2j19
# 66467914  nmdc:dobj-11-5wyv2j19
# 66467915  nmdc:dobj-11-5wyv2j19
#
# [66467916 rows x 22 columns]

# %%
# clean up data frame - remove all middle "joining columns" because the merge is getting slow\
column_list = merged_df9.columns.tolist()
columns_to_keep = ["soil_horizon", "biosample_id", "url"]
columns_to_remove = list(set(column_list).difference(columns_to_keep))
# Drop unnecessary rows
df9_cleaned = merged_df9.drop(columns=columns_to_remove)
df9_cleaned
# Out:
#                                                         url soil_horizon  \
# 0         https://data.microbiomedata.org/data/nmdc:ompr...    M horizon
# 1         https://data.microbiomedata.org/data/nmdc:ompr...    M horizon
# 2         https://data.microbiomedata.org/data/nmdc:ompr...    M horizon
# 3         https://data.microbiomedata.org/data/nmdc:ompr...    M horizon
# 4         https://data.microbiomedata.org/data/nmdc:ompr...    M horizon
# ...                                                     ...          ...
# 66467911  https://data.microbiomedata.org/data/nmdc:ompr...    O horizon
# 66467912  https://data.microbiomedata.org/data/nmdc:ompr...    O horizon
# 66467913  https://data.microbiomedata.org/data/nmdc:ompr...    O horizon
# 66467914  https://data.microbiomedata.org/data/nmdc:ompr...    O horizon
# 66467915  https://data.microbiomedata.org/data/nmdc:ompr...    O horizon
#
#                   biosample_id
# 0         nmdc:bsm-11-158pa966
# 1         nmdc:bsm-11-158pa966
# 2         nmdc:bsm-11-158pa966
# 3         nmdc:bsm-11-158pa966
# 4         nmdc:bsm-11-158pa966
# ...                        ...
# 66467911  nmdc:bsm-11-xhzk6v39
# 66467912  nmdc:bsm-11-xhzk6v39
# 66467913  nmdc:bsm-11-xhzk6v39
# 66467914  nmdc:bsm-11-xhzk6v39
# 66467915  nmdc:bsm-11-xhzk6v39
#
# [66467916 rows x 3 columns]

# %%
# check rows when we reagrregate/implode, 
# imploded_df = df9_cleaned.groupby(["soil_horizon", "biosample_id"]).agg({"url": list}).reset_index()
imploded_df = df9_cleaned.groupby(["soil_horizon", "biosample_id"]).agg({"url": str}).reset_index()
imploded_df
# Out:
#      soil_horizon          biosample_id  \
# 0       M horizon  nmdc:bsm-11-00dkyf35
# 1       M horizon  nmdc:bsm-11-02kcw433
# 2       M horizon  nmdc:bsm-11-02n85875
# 3       M horizon  nmdc:bsm-11-034x5t48
# 4       M horizon  nmdc:bsm-11-043hgn06
# ...           ...                   ...
# 3858    O horizon  nmdc:bsm-11-zv1dn095
# 3859    O horizon  nmdc:bsm-11-zvepbm45
# 3860    O horizon  nmdc:bsm-11-zw5rb344
# 3861    O horizon  nmdc:bsm-11-zx7j9919
# 3862    O horizon  nmdc:bsm-11-zxvtgn65
#
#                                                     url
# 0     2604556    https://data.microbiomedata.org/dat...
# 1     2073358    https://data.microbiomedata.org/dat...
# 2     4034224    https://data.microbiomedata.org/dat...
# 3     590976    https://data.microbiomedata.org/data...
# 4     2368603    https://data.microbiomedata.org/dat...
# ...                                                 ...
# 3858  45987595    https://data.microbiomedata.org/da...
# 3859  65831534    https://data.microbiomedata.org/da...
# 3860  1183527    https://data.microbiomedata.org/dat...
# 3861  61723476    https://data.microbiomedata.org/da...
# 3862  3500115    https://data.microbiomedata.org/dat...
#
# [3863 rows x 3 columns]

# %%
# Test df
df_test = df9_cleaned[:1]
df_test
# url_value = df_test.iloc[0]["url"]
# print(url_value)
# Out:
#                                                  url soil_horizon  \
# 0  https://data.microbiomedata.org/data/nmdc:ompr...    M horizon
#
#            biosample_id
# 0  nmdc:bsm-11-158pa966

# %%
for index, row in df_test.iterrows():
    url = row["url"]

    response = requests.get(url)
    if response.status_code == 200:
        tsv_data = StringIO(response.text)

        tsv_df = pd.read_csv(tsv_data, delimiter="\t")

        # Give columns names
        tsv_df.columns = ["id", "taxa", "percent"]

        # split taxa column into a list where a semicolon (;) is the delimeter
        tsv_df["taxa"] = tsv_df["taxa"].str.split(";")
        

        # explode to find taxa distribution by creating a series object (taxa_percent)
        tsv_df_exploded = tsv_df["taxa"].explode().reset_index(drop=True)
        taxa_percent = tsv_df_exploded.value_counts(normalize=True)*100

        # taxa_percent.columns = ["taxa", "percent"]
        # taxa_dict = dict(zip(taxa_percent["taxa"], taxa_percent["percent"]))
        # print(taxa_dict)
        # Add series object back to original data frame 
        # df_test.at[index, "taxa_dist"] = taxa_percent
    

    else:
        print("error")

# df_test
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/development/nmdc/notebook_hackathons/venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'taxa'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[96], line 22
#      19     taxa_percent = tsv_df_exploded.value_counts(normalize=True)*100
#      21     taxa_percent.columns = ["taxa", "percent"]
# ---> 22     taxa_dict = dict(zip(taxa_percent["taxa"], taxa_percent["percent"]))
#      23     print(taxa_dict)
#      24     # Add series object back to original data frame
#      25     # df_test.at[index, "taxa_dist"] = taxa_percent
#      26
#      27
#      28 else:
#
# File ~/development/nmdc/notebook_hackathons/venv/lib/python3.10/site-packages/pandas/core/series.py:1040, in Series.__getitem__(self, key)
#    1037     return self._values[key]
#    1039 elif key_is_scalar:
# -> 1040     return self._get_value(key)
#    1042 # Convert generator to list before going through hashable part
#    1043 # (We will iterate through the generator there to check for slices)
#    1044 if is_iterator(key):
#
# File ~/development/nmdc/notebook_hackathons/venv/lib/python3.10/site-packages/pandas/core/series.py:1156, in Series._get_value(self, label, takeable)
#    1153     return self._values[label]
#    1155 # Similar to Index.get_value, but we do not fall back to positional
# -> 1156 loc = self.index.get_loc(label)
#    1158 if is_integer(loc):
#    1159     return self._values[loc]
#
# File ~/development/nmdc/notebook_hackathons/venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'taxa'
