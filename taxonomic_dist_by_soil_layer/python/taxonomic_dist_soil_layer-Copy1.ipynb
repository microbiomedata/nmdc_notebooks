# %%
# How does the taxonomic distribution of contigs differ by soil layer (mineral vs organic)?

# %%
import requests
import pandas as pd
from io import StringIO
import numpy as np
import gc

gc.collect()
# Out:
# 6614

# %%
# Define a function to get first page of results (we will use again for other requests, which is why we are defining a function)
def get_first_page_results(collection: str, filter: str, max_page_size: int, fields: str):
    og_url = f'https://api.microbiomedata.org/nmdcschema/{collection}?&filter={filter}&max_page_size={max_page_size}&projection={fields}'
    resp = requests.get(og_url)
    data = resp.json()
    
    return data

# %%
# Define another function to get the rest of the results using the next_page_token by calling the first funtion to get
# the initial results and then using the next_page_token to get the other results. This function returns a list of the results

def get_next_results(collection: str, filter: str, max_page_size: int, fields: str):

    # Get initial results (before next_page_token is given in results)
    initial_data = get_first_page_results(collection, filter, max_page_size, fields)
    results = initial_data["resources"]
    next_page_token = initial_data["next_page_token"]
    result_list = []

    # append first page of results to an empty list
    for result in results:
        result_list.append(result)
    
    while True:
        url = f'https://api.microbiomedata.org/nmdcschema/{collection}?&filter={filter}&max_page_size={max_page_size}&page_token={next_page_token}&projection={fields}'
        response = requests.get(url)
        data_next = response.json()
        
        results = data_next.get("resources", [])
        result_list.extend(results)
        next_page_token = data_next.get("next_page_token")
    
        if not next_page_token:
            break

    return result_list

# %%
def convert_df(results_list: list):

    df = pd.DataFrame(results_list)

    return df

# %%
# Get biosamples using functions
biosamples = get_next_results("biosample_set", '{"soil_horizon":{"$exists": true}}', 100, "id,soil_horizon")

# clarify names
for biosample in biosamples:
    biosample["biosample_id"] = biosample.pop("id")

# convert to df
biosample_df = convert_df(biosamples)
biosample_df
# Out:
#      soil_horizon          biosample_id
# 0       O horizon  nmdc:bsm-11-002vgm56
# 1       M horizon  nmdc:bsm-11-00dkyf35
# 2       O horizon  nmdc:bsm-11-00hrxp98
# 3       M horizon  nmdc:bsm-11-00m15h97
# 4       M horizon  nmdc:bsm-11-00yhef97
# ...           ...                   ...
# 4645    M horizon  nmdc:bsm-11-zyhk8g66
# 4646    B horizon  nmdc:bsm-11-zz9hq391
# 4647    A horizon  nmdc:bsm-11-zzahyk07
# 4648    M horizon  nmdc:bsm-11-zzdpcm17
# 4649    M horizon  nmdc:bsm-11-zzrx6210
#
# [4650 rows x 2 columns]

# %%
# Define a function to split ids into chunks
def split_list(input_list, chunk_size=100):
    result = []
    
    for i in range(0, len(input_list), chunk_size):
        result.append(input_list[i:i + chunk_size])
        
    return result

# %%
# Adjust filter list for double quote string - important for mongo queries
def string_mongo_list(a_list: list):
    
    string_with_double_quotes = str(a_list).replace("'", '"')

    return string_with_double_quotes

# %%
# Get list of ids (to eventually feed into query)
def get_id_list(result_list, id_name):
    id_list = []
    for item in result_list:
        if type(item[id_name]) == str:
            id_list.append(item[id_name])
        elif type(item[id_name]) == list:
            for another_item in item[id_name]:
                id_list.append(another_item)

    return id_list

# %%
# Define function to request NMDC metadata based on list of identifiers
def get_id_results(newest_results: list, id_field: str, query_collection: str, match_id_field: str, query_fields: str):

    # split old results into list
    result_ids = get_id_list(newest_results, id_field)

    # # make sure match_id_field has double quotes (important for mongo query)
    match_id_field.replace("'", "\"")

    # chunk up the results into sets of 100 using the split_list function and call the get_first_page_results function and append
    # results to list
    chunked_list = split_list(result_ids)
    next_results = []
    for chunk in chunked_list:
        filter_string = string_mongo_list(chunk)
        # quotes around match_id_field need to look a lot different for the final data object query
        if "data_object_type" in match_id_field:
            data = get_first_page_results(query_collection, f'{{{match_id_field}: {{"$in": {filter_string}}}}}', 100, query_fields)
        else: 
            data = get_first_page_results(query_collection, f'{{"{match_id_field}": {{"$in": {filter_string}}}}}', 100, query_fields)
        next_results.extend(data["resources"])

    return next_results

# %%
# Get pooling results where biosample identifiers are "has_input" in the pooling_set collection
pooling = get_id_results(biosamples, "biosample_id", "pooling_set", "has_input", "id,has_input,has_output")

# clarify names/keys/identifiers
for pool in pooling:
    pool["pooling_has_input"] = pool.pop("has_input")
    pool["pooling_has_output"] = pool.pop("has_output")
    pool["pooling_id"] = pool.pop("id")

# convert to data frame
pooling_df = convert_df(pooling)
pooling_df
# Out:
#                                       pooling_has_input  \
# 0     [nmdc:bsm-11-zw0jr671, nmdc:bsm-11-ftr88019, n...
# 1     [nmdc:bsm-11-pgpaf592, nmdc:bsm-11-07qq9z23, n...
# 2     [nmdc:bsm-11-01g9wf51, nmdc:bsm-11-d8mzds05, n...
# 3     [nmdc:bsm-11-t21kbh64, nmdc:bsm-11-0d4a3v31, n...
# 4     [nmdc:bsm-11-32fzkb25, nmdc:bsm-11-0earmn44, n...
# ...                                                 ...
# 4284  [nmdc:bsm-11-d8254g62, nmdc:bsm-11-zr06ct75, n...
# 4285  [nmdc:bsm-11-zx7j9919, nmdc:bsm-11-ywmc3x87, n...
# 4286       [nmdc:bsm-11-1kzrnd52, nmdc:bsm-11-zx0m7409]
# 4287  [nmdc:bsm-11-r0nqvg54, nmdc:bsm-11-3w0vf491, n...
# 4288  [nmdc:bsm-11-rce9y809, nmdc:bsm-11-104brf69, n...
#
#              pooling_has_output              pooling_id
# 0     [nmdc:procsm-11-m6cgda89]  nmdc:poolp-11-myygnt07
# 1     [nmdc:procsm-11-4x35gd93]  nmdc:poolp-11-fg19qm11
# 2     [nmdc:procsm-11-z19p2488]  nmdc:poolp-11-phdxxg80
# 3     [nmdc:procsm-11-f6fy8y22]  nmdc:poolp-11-d51jda20
# 4     [nmdc:procsm-11-qkhd3y74]  nmdc:poolp-11-5q9ye786
# ...                         ...                     ...
# 4284  [nmdc:procsm-11-wy01d353]  nmdc:poolp-11-zqwvqd96
# 4285  [nmdc:procsm-11-1dyvaw49]  nmdc:poolp-11-h8hehp15
# 4286  [nmdc:procsm-11-qs5tn036]  nmdc:poolp-11-59743d48
# 4287  [nmdc:procsm-11-33n43s88]  nmdc:poolp-11-dzhbts63
# 4288  [nmdc:procsm-11-rd048144]  nmdc:poolp-11-88afda35
#
# [4289 rows x 3 columns]

# %%
# Function to merge new results with old results (mapping keys together that match). df1 is the data frame with the 
# list where key1 is a list. If key_explode == True, then it means to explode the matching list key (in df1). next_key_explode == True
# then explode the next key given from the new results that will be used in the next merge.
def merge_items(df1, df2, key1: str, key2: str, key_explode: bool, next_key_explode: bool, next_key = None):

    if key_explode == True:
        if next_key_explode == True:
            
            # explode the data frame with the matching key that is a list. Df1 is dataframe with key1 that is a list
            df1_exploded = df1.explode(key1)
            merged_df = pd.merge(df1_exploded, df2, left_on=key1, right_on=key2)
        
            # explode next key:
            merged_df_exploded = merged_df.explode(next_key)

            # Drop any duplicated rows
            merged_df_exploded.drop_duplicates(keep="first", inplace=True)

            return merged_df_exploded

        elif next_key_explode == False:
            # explode the data frame with the matching key that is a list. Df1 is dataframe with key1 that is a list
            df1_exploded = df1.explode(key1)
            merged_df = pd.merge(df1_exploded, df2, left_on=key1, right_on=key2)

            # Drop any duplicated rows
            merged_df.drop_duplicates(keep="first", inplace=True)

            return merged_df

    elif key_explode == False:
        if next_key:
            
            # Merge the dfs and return the next key expldoed
            merged_df = pd.merge(df1, df2, left_on=key1, right_on=key2)
            merged_df_exploded = merged_df.explode(next_key)

            # Drop any duplicated rows
            merged_df_exploded.drop_duplicates(keep="first", inplace=True)

            return merged_df_exploded

        elif not next_key:

            merged_df = pd.merge(df1, df2, left_on=key1, right_on=key2)

            # Drop any duplicated rows
            merged_df.drop_duplicates(keep="first", inplace=True)

            return merged_df

# %%
# Merge the initial biosample results with the pooling results
merged_df1 = merge_items(pooling_df, biosample_df, "pooling_has_input", "biosample_id", True, True, "pooling_has_output")
merged_df1
# Out:
#           pooling_has_input       pooling_has_output              pooling_id  \
# 0      nmdc:bsm-11-zw0jr671  nmdc:procsm-11-m6cgda89  nmdc:poolp-11-myygnt07
# 1      nmdc:bsm-11-zw0jr671  nmdc:procsm-11-m6cgda89  nmdc:poolp-11-myygnt07
# 2      nmdc:bsm-11-zw0jr671  nmdc:procsm-11-m6cgda89  nmdc:poolp-11-myygnt07
# 3      nmdc:bsm-11-ftr88019  nmdc:procsm-11-m6cgda89  nmdc:poolp-11-myygnt07
# 4      nmdc:bsm-11-ftr88019  nmdc:procsm-11-m6cgda89  nmdc:poolp-11-myygnt07
# ...                     ...                      ...                     ...
# 12672  nmdc:bsm-11-zr7b5t24  nmdc:procsm-11-qpqz4w54  nmdc:poolp-11-evtggs98
# 12673  nmdc:bsm-11-zr7b5t24  nmdc:procsm-11-qpqz4w54  nmdc:poolp-11-evtggs98
# 12674  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54  nmdc:poolp-11-evtggs98
# 12675  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54  nmdc:poolp-11-evtggs98
# 12676  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54  nmdc:poolp-11-evtggs98
#
#       soil_horizon          biosample_id
# 0        M horizon  nmdc:bsm-11-zw0jr671
# 1        M horizon  nmdc:bsm-11-zw0jr671
# 2        M horizon  nmdc:bsm-11-zw0jr671
# 3        M horizon  nmdc:bsm-11-ftr88019
# 4        M horizon  nmdc:bsm-11-ftr88019
# ...            ...                   ...
# 12672    O horizon  nmdc:bsm-11-zr7b5t24
# 12673    O horizon  nmdc:bsm-11-zr7b5t24
# 12674    O horizon  nmdc:bsm-11-xhzk6v39
# 12675    O horizon  nmdc:bsm-11-xhzk6v39
# 12676    O horizon  nmdc:bsm-11-xhzk6v39
#
# [12677 rows x 5 columns]

# %%
# Get processed sample results from pooling_has_ouput identifiers
# We use the pooling results and the identifier "pooling_has_output" to query the "processed_sample_set" matching the "id" field, and
# we only need the "id" field returned
process_set1 = get_id_results(pooling, "pooling_has_output", "processed_sample_set", "id", "id")

# clarify names
for processed_sample in process_set1:
    processed_sample["processed_sample1"] = processed_sample.pop("id")

# convert to data frame
ps1_df = convert_df(process_set1)
ps1_df
# Out:
#             processed_sample1
# 0     nmdc:procsm-11-07kg2w70
# 1     nmdc:procsm-11-09rv7c30
# 2     nmdc:procsm-11-0rn9p334
# 3     nmdc:procsm-11-22s7xc89
# 4     nmdc:procsm-11-258vbz70
# ...                       ...
# 4262  nmdc:procsm-11-vqe1dh14
# 4263  nmdc:procsm-11-wm0mqq15
# 4264  nmdc:procsm-11-wy01d353
# 4265  nmdc:procsm-11-x0gpxh72
# 4266  nmdc:procsm-11-xkxtzg80
#
# [4267 rows x 1 columns]

# %%
# Merge the process_set1 with the merged_list based on "id" in process_set1 with "pooling_has_output" from the merged_list
# merged_list = merge_items(process_set1, merged_list, "processed_sample1", "pooling_has_output")
merged_df2 = merge_items(merged_df1, ps1_df, "pooling_has_output", "processed_sample1", False, False)
merged_df2
# Out:
#           pooling_has_input       pooling_has_output              pooling_id  \
# 0      nmdc:bsm-11-zw0jr671  nmdc:procsm-11-m6cgda89  nmdc:poolp-11-myygnt07
# 9      nmdc:bsm-11-ftr88019  nmdc:procsm-11-m6cgda89  nmdc:poolp-11-myygnt07
# 18     nmdc:bsm-11-06qrej20  nmdc:procsm-11-m6cgda89  nmdc:poolp-11-myygnt07
# 27     nmdc:bsm-11-pgpaf592  nmdc:procsm-11-4x35gd93  nmdc:poolp-11-fg19qm11
# 36     nmdc:bsm-11-07qq9z23  nmdc:procsm-11-4x35gd93  nmdc:poolp-11-fg19qm11
# ...                     ...                      ...                     ...
# 36903  nmdc:bsm-11-yhmy3172  nmdc:procsm-11-e273jx66  nmdc:poolp-11-marzp505
# 36912  nmdc:bsm-11-xedk6s97  nmdc:procsm-11-e273jx66  nmdc:poolp-11-marzp505
# 36921  nmdc:bsm-11-wbaszj27  nmdc:procsm-11-qpqz4w54  nmdc:poolp-11-evtggs98
# 36930  nmdc:bsm-11-zr7b5t24  nmdc:procsm-11-qpqz4w54  nmdc:poolp-11-evtggs98
# 36939  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54  nmdc:poolp-11-evtggs98
#
#       soil_horizon          biosample_id        processed_sample1
# 0        M horizon  nmdc:bsm-11-zw0jr671  nmdc:procsm-11-m6cgda89
# 9        M horizon  nmdc:bsm-11-ftr88019  nmdc:procsm-11-m6cgda89
# 18       M horizon  nmdc:bsm-11-06qrej20  nmdc:procsm-11-m6cgda89
# 27       O horizon  nmdc:bsm-11-pgpaf592  nmdc:procsm-11-4x35gd93
# 36       O horizon  nmdc:bsm-11-07qq9z23  nmdc:procsm-11-4x35gd93
# ...            ...                   ...                      ...
# 36903    M horizon  nmdc:bsm-11-yhmy3172  nmdc:procsm-11-e273jx66
# 36912    M horizon  nmdc:bsm-11-xedk6s97  nmdc:procsm-11-e273jx66
# 36921    O horizon  nmdc:bsm-11-wbaszj27  nmdc:procsm-11-qpqz4w54
# 36930    O horizon  nmdc:bsm-11-zr7b5t24  nmdc:procsm-11-qpqz4w54
# 36939    O horizon  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54
#
# [4377 rows x 6 columns]

# %%
# Get extraction results from "processed_sample1" identifiers
# We use the process_set1 results and the identifier "processed_sample1" to query the "extraction_set" collection matching the 
# "has_input" field. We need three fields returned from the extraction set: "id", "has_input", and "has_output"
extraction_set = get_id_results(process_set1, "processed_sample1", "extraction_set", "has_input", "id,has_input,has_output")

# clarify names
for extraction in extraction_set:
    extraction["extract_has_input"] = extraction.pop("has_input")
    extraction["extract_has_output"] = extraction.pop("has_output")
    extraction["extract_id"] = extraction.pop("id")

# convert to data frame
extract_df = convert_df(extraction_set)
extract_df
# Out:
#               extract_has_input         extract_has_output  \
# 0     [nmdc:procsm-11-m6cgda89]  [nmdc:procsm-11-e3m9am88]
# 1     [nmdc:procsm-11-zxr4eq64]  [nmdc:procsm-11-69w7d751]
# 2     [nmdc:procsm-11-50046m08]  [nmdc:procsm-11-wfr9gq72]
# 3     [nmdc:procsm-11-4x35gd93]  [nmdc:procsm-11-r8c2df02]
# 4     [nmdc:procsm-11-z19p2488]  [nmdc:procsm-11-6p7xet10]
# ...                         ...                        ...
# 4245  [nmdc:procsm-11-g4shfj37]  [nmdc:procsm-11-tbzk2q40]
# 4246  [nmdc:procsm-11-f4ec8e58]  [nmdc:procsm-11-pce7pn80]
# 4247  [nmdc:procsm-11-en24rw77]  [nmdc:procsm-11-6ca4kh69]
# 4248  [nmdc:procsm-11-j5t8v154]  [nmdc:procsm-11-e88p7q45]
# 4249  [nmdc:procsm-11-apjqzn80]  [nmdc:procsm-11-n6ca7j67]
#
#                   extract_id
# 0     nmdc:extrp-11-2hbzth07
# 1     nmdc:extrp-11-8aaf5q49
# 2     nmdc:extrp-11-7v16d010
# 3     nmdc:extrp-11-7mhth480
# 4     nmdc:extrp-11-1w7rz874
# ...                      ...
# 4245  nmdc:extrp-11-c07fy379
# 4246  nmdc:extrp-11-v53rv933
# 4247  nmdc:extrp-11-b89p0n80
# 4248  nmdc:extrp-11-9exgqh10
# 4249  nmdc:extrp-11-brrz8w04
#
# [4250 rows x 3 columns]

# %%
# Merge the extraction_set with the merged_list based on the extract_has_input of extraction_set with processed_sample1
# from the merged list
merged_df3 = merge_items(extract_df, merged_df2, "extract_has_input", "processed_sample1", True, True, "extract_has_output") 
merged_df3
# Out:
#              extract_has_input       extract_has_output  \
# 0      nmdc:procsm-11-m6cgda89  nmdc:procsm-11-e3m9am88
# 1      nmdc:procsm-11-m6cgda89  nmdc:procsm-11-e3m9am88
# 2      nmdc:procsm-11-m6cgda89  nmdc:procsm-11-e3m9am88
# 9      nmdc:procsm-11-zxr4eq64  nmdc:procsm-11-69w7d751
# 10     nmdc:procsm-11-zxr4eq64  nmdc:procsm-11-69w7d751
# ...                        ...                      ...
# 12543  nmdc:procsm-11-e273jx66  nmdc:procsm-11-tn3was93
# 12544  nmdc:procsm-11-e273jx66  nmdc:procsm-11-tn3was93
# 12551  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 12552  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 12553  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
#
#                    extract_id     pooling_has_input       pooling_has_output  \
# 0      nmdc:extrp-11-2hbzth07  nmdc:bsm-11-zw0jr671  nmdc:procsm-11-m6cgda89
# 1      nmdc:extrp-11-2hbzth07  nmdc:bsm-11-ftr88019  nmdc:procsm-11-m6cgda89
# 2      nmdc:extrp-11-2hbzth07  nmdc:bsm-11-06qrej20  nmdc:procsm-11-m6cgda89
# 9      nmdc:extrp-11-8aaf5q49  nmdc:bsm-11-g46hws70  nmdc:procsm-11-zxr4eq64
# 10     nmdc:extrp-11-8aaf5q49  nmdc:bsm-11-7gdzz704  nmdc:procsm-11-zxr4eq64
# ...                       ...                   ...                      ...
# 12543  nmdc:extrp-11-wfzqt783  nmdc:bsm-11-yhmy3172  nmdc:procsm-11-e273jx66
# 12544  nmdc:extrp-11-wfzqt783  nmdc:bsm-11-xedk6s97  nmdc:procsm-11-e273jx66
# 12551  nmdc:extrp-11-qw3ca676  nmdc:bsm-11-wbaszj27  nmdc:procsm-11-qpqz4w54
# 12552  nmdc:extrp-11-qw3ca676  nmdc:bsm-11-zr7b5t24  nmdc:procsm-11-qpqz4w54
# 12553  nmdc:extrp-11-qw3ca676  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54
#
#                    pooling_id soil_horizon          biosample_id  \
# 0      nmdc:poolp-11-myygnt07    M horizon  nmdc:bsm-11-zw0jr671
# 1      nmdc:poolp-11-myygnt07    M horizon  nmdc:bsm-11-ftr88019
# 2      nmdc:poolp-11-myygnt07    M horizon  nmdc:bsm-11-06qrej20
# 9      nmdc:poolp-11-hdyzxk28    M horizon  nmdc:bsm-11-g46hws70
# 10     nmdc:poolp-11-hdyzxk28    M horizon  nmdc:bsm-11-7gdzz704
# ...                       ...          ...                   ...
# 12543  nmdc:poolp-11-marzp505    M horizon  nmdc:bsm-11-yhmy3172
# 12544  nmdc:poolp-11-marzp505    M horizon  nmdc:bsm-11-xedk6s97
# 12551  nmdc:poolp-11-evtggs98    O horizon  nmdc:bsm-11-wbaszj27
# 12552  nmdc:poolp-11-evtggs98    O horizon  nmdc:bsm-11-zr7b5t24
# 12553  nmdc:poolp-11-evtggs98    O horizon  nmdc:bsm-11-xhzk6v39
#
#              processed_sample1
# 0      nmdc:procsm-11-m6cgda89
# 1      nmdc:procsm-11-m6cgda89
# 2      nmdc:procsm-11-m6cgda89
# 9      nmdc:procsm-11-zxr4eq64
# 10     nmdc:procsm-11-zxr4eq64
# ...                        ...
# 12543  nmdc:procsm-11-e273jx66
# 12544  nmdc:procsm-11-e273jx66
# 12551  nmdc:procsm-11-qpqz4w54
# 12552  nmdc:procsm-11-qpqz4w54
# 12553  nmdc:procsm-11-qpqz4w54
#
# [4362 rows x 9 columns]

# %%
# Get processed_sample_set results again from "extract_has_output"
# We use the extraction_set results and identifier "extract_has_output" to query the "processed_sample_set" collection matching the
# "id". We return only the id of the processed_sample_set
process_set2 = get_id_results(extraction_set, "extract_has_output", "processed_sample_set", "id", "id")

# clarify names
for samp in process_set2:
    samp["processed_sample2"] = samp.pop("id")

# convert to data frame
ps2_df = convert_df(process_set2)
ps2_df
# Out:
#             processed_sample2
# 0     nmdc:procsm-11-06bnpy24
# 1     nmdc:procsm-11-0q8aqj17
# 2     nmdc:procsm-11-0sva2t89
# 3     nmdc:procsm-11-18j5nz50
# 4     nmdc:procsm-11-1rzdbe82
# ...                       ...
# 4241  nmdc:procsm-11-xf9ka912
# 4242  nmdc:procsm-11-xwhjh309
# 4243  nmdc:procsm-11-xwpjt103
# 4244  nmdc:procsm-11-yrmwcm28
# 4245  nmdc:procsm-11-zg63ac02
#
# [4246 rows x 1 columns]

# %%
# Merge the process_set2 with the merged_list based on the proccessed_sample2 of process_set2 with extract_has_output
#from merged list
merged_df4 = merge_items(merged_df3, ps2_df, "extract_has_output", "processed_sample2", False, False)
merged_df4
# Out:
#              extract_has_input       extract_has_output  \
# 0      nmdc:procsm-11-m6cgda89  nmdc:procsm-11-e3m9am88
# 3      nmdc:procsm-11-m6cgda89  nmdc:procsm-11-e3m9am88
# 6      nmdc:procsm-11-m6cgda89  nmdc:procsm-11-e3m9am88
# 9      nmdc:procsm-11-zxr4eq64  nmdc:procsm-11-69w7d751
# 12     nmdc:procsm-11-zxr4eq64  nmdc:procsm-11-69w7d751
# ...                        ...                      ...
# 12533  nmdc:procsm-11-e273jx66  nmdc:procsm-11-tn3was93
# 12536  nmdc:procsm-11-e273jx66  nmdc:procsm-11-tn3was93
# 12539  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 12542  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 12545  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
#
#                    extract_id     pooling_has_input       pooling_has_output  \
# 0      nmdc:extrp-11-2hbzth07  nmdc:bsm-11-zw0jr671  nmdc:procsm-11-m6cgda89
# 3      nmdc:extrp-11-2hbzth07  nmdc:bsm-11-ftr88019  nmdc:procsm-11-m6cgda89
# 6      nmdc:extrp-11-2hbzth07  nmdc:bsm-11-06qrej20  nmdc:procsm-11-m6cgda89
# 9      nmdc:extrp-11-8aaf5q49  nmdc:bsm-11-g46hws70  nmdc:procsm-11-zxr4eq64
# 12     nmdc:extrp-11-8aaf5q49  nmdc:bsm-11-7gdzz704  nmdc:procsm-11-zxr4eq64
# ...                       ...                   ...                      ...
# 12533  nmdc:extrp-11-wfzqt783  nmdc:bsm-11-yhmy3172  nmdc:procsm-11-e273jx66
# 12536  nmdc:extrp-11-wfzqt783  nmdc:bsm-11-xedk6s97  nmdc:procsm-11-e273jx66
# 12539  nmdc:extrp-11-qw3ca676  nmdc:bsm-11-wbaszj27  nmdc:procsm-11-qpqz4w54
# 12542  nmdc:extrp-11-qw3ca676  nmdc:bsm-11-zr7b5t24  nmdc:procsm-11-qpqz4w54
# 12545  nmdc:extrp-11-qw3ca676  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54
#
#                    pooling_id soil_horizon          biosample_id  \
# 0      nmdc:poolp-11-myygnt07    M horizon  nmdc:bsm-11-zw0jr671
# 3      nmdc:poolp-11-myygnt07    M horizon  nmdc:bsm-11-ftr88019
# 6      nmdc:poolp-11-myygnt07    M horizon  nmdc:bsm-11-06qrej20
# 9      nmdc:poolp-11-hdyzxk28    M horizon  nmdc:bsm-11-g46hws70
# 12     nmdc:poolp-11-hdyzxk28    M horizon  nmdc:bsm-11-7gdzz704
# ...                       ...          ...                   ...
# 12533  nmdc:poolp-11-marzp505    M horizon  nmdc:bsm-11-yhmy3172
# 12536  nmdc:poolp-11-marzp505    M horizon  nmdc:bsm-11-xedk6s97
# 12539  nmdc:poolp-11-evtggs98    O horizon  nmdc:bsm-11-wbaszj27
# 12542  nmdc:poolp-11-evtggs98    O horizon  nmdc:bsm-11-zr7b5t24
# 12545  nmdc:poolp-11-evtggs98    O horizon  nmdc:bsm-11-xhzk6v39
#
#              processed_sample1        processed_sample2
# 0      nmdc:procsm-11-m6cgda89  nmdc:procsm-11-e3m9am88
# 3      nmdc:procsm-11-m6cgda89  nmdc:procsm-11-e3m9am88
# 6      nmdc:procsm-11-m6cgda89  nmdc:procsm-11-e3m9am88
# 9      nmdc:procsm-11-zxr4eq64  nmdc:procsm-11-69w7d751
# 12     nmdc:procsm-11-zxr4eq64  nmdc:procsm-11-69w7d751
# ...                        ...                      ...
# 12533  nmdc:procsm-11-e273jx66  nmdc:procsm-11-tn3was93
# 12536  nmdc:procsm-11-e273jx66  nmdc:procsm-11-tn3was93
# 12539  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 12542  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 12545  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
#
# [4362 rows x 10 columns]

# %%
# Get library_preparation_set results from "processed_sample2" 
# We use the process_set2 results and identifier "processed_sample2" to query the library_preparation_set collection matching the 
# "has_input" field. We return the "has_input", "has_output", and "id" fields.
library_prep_set = get_id_results(process_set2, "processed_sample2", "library_preparation_set", "has_input", "id,has_input,has_output")

# clarify names
for prep in library_prep_set:
    prep["lp_has_input"] = prep.pop("has_input")
    prep["lp_has_output"] = prep.pop("has_output")
    prep["lp_id"] = prep.pop("id")

# convert to data frame
lp_df = convert_df(library_prep_set)
lp_df
# Out:
#                    lp_has_input              lp_has_output  \
# 0     [nmdc:procsm-11-e3m9am88]  [nmdc:procsm-11-s71h1s64]
# 1     [nmdc:procsm-11-69w7d751]  [nmdc:procsm-11-pvq3cw40]
# 2     [nmdc:procsm-11-wfr9gq72]  [nmdc:procsm-11-g7btv939]
# 3     [nmdc:procsm-11-r8c2df02]  [nmdc:procsm-11-vvhhwt22]
# 4     [nmdc:procsm-11-6p7xet10]  [nmdc:procsm-11-062rbk44]
# ...                         ...                        ...
# 4240  [nmdc:procsm-11-tbzk2q40]  [nmdc:procsm-11-xpfxk275]
# 4241  [nmdc:procsm-11-pce7pn80]  [nmdc:procsm-11-z1jy1841]
# 4242  [nmdc:procsm-11-6ca4kh69]  [nmdc:procsm-11-241nns31]
# 4243  [nmdc:procsm-11-e88p7q45]  [nmdc:procsm-11-en1yqa35]
# 4244  [nmdc:procsm-11-n6ca7j67]  [nmdc:procsm-11-5ggf9w42]
#
#                         lp_id
# 0     nmdc:libprp-11-acbfh839
# 1     nmdc:libprp-11-e39ky379
# 2     nmdc:libprp-11-7v2sqk43
# 3     nmdc:libprp-11-7y2d1222
# 4     nmdc:libprp-11-2cy94060
# ...                       ...
# 4240  nmdc:libprp-11-m33s2x71
# 4241  nmdc:libprp-11-vwd3tn32
# 4242  nmdc:libprp-11-ftccjg43
# 4243  nmdc:libprp-11-46m5k206
# 4244  nmdc:libprp-11-ejr9ap28
#
# [4245 rows x 3 columns]

# %%
# Merge library preparation with merged_list on "processed_sample2" and "lp_has_input"
merged_df5 = merge_items(lp_df, merged_df4, "lp_has_input", "processed_sample2", True, True, "lp_has_output")
merged_df5
# Out:
#                   lp_has_input            lp_has_output  \
# 0      nmdc:procsm-11-e3m9am88  nmdc:procsm-11-s71h1s64
# 1      nmdc:procsm-11-e3m9am88  nmdc:procsm-11-s71h1s64
# 2      nmdc:procsm-11-e3m9am88  nmdc:procsm-11-s71h1s64
# 9      nmdc:procsm-11-69w7d751  nmdc:procsm-11-pvq3cw40
# 10     nmdc:procsm-11-69w7d751  nmdc:procsm-11-pvq3cw40
# ...                        ...                      ...
# 12528  nmdc:procsm-11-tn3was93  nmdc:procsm-11-69fjnv37
# 12529  nmdc:procsm-11-tn3was93  nmdc:procsm-11-69fjnv37
# 12536  nmdc:procsm-11-3rfvyd88  nmdc:procsm-11-h6y3cf29
# 12537  nmdc:procsm-11-3rfvyd88  nmdc:procsm-11-h6y3cf29
# 12538  nmdc:procsm-11-3rfvyd88  nmdc:procsm-11-h6y3cf29
#
#                          lp_id        extract_has_input  \
# 0      nmdc:libprp-11-acbfh839  nmdc:procsm-11-m6cgda89
# 1      nmdc:libprp-11-acbfh839  nmdc:procsm-11-m6cgda89
# 2      nmdc:libprp-11-acbfh839  nmdc:procsm-11-m6cgda89
# 9      nmdc:libprp-11-e39ky379  nmdc:procsm-11-zxr4eq64
# 10     nmdc:libprp-11-e39ky379  nmdc:procsm-11-zxr4eq64
# ...                        ...                      ...
# 12528  nmdc:libprp-11-wz8cmz63  nmdc:procsm-11-e273jx66
# 12529  nmdc:libprp-11-wz8cmz63  nmdc:procsm-11-e273jx66
# 12536  nmdc:libprp-11-86c4n641  nmdc:procsm-11-qpqz4w54
# 12537  nmdc:libprp-11-86c4n641  nmdc:procsm-11-qpqz4w54
# 12538  nmdc:libprp-11-86c4n641  nmdc:procsm-11-qpqz4w54
#
#             extract_has_output              extract_id     pooling_has_input  \
# 0      nmdc:procsm-11-e3m9am88  nmdc:extrp-11-2hbzth07  nmdc:bsm-11-zw0jr671
# 1      nmdc:procsm-11-e3m9am88  nmdc:extrp-11-2hbzth07  nmdc:bsm-11-ftr88019
# 2      nmdc:procsm-11-e3m9am88  nmdc:extrp-11-2hbzth07  nmdc:bsm-11-06qrej20
# 9      nmdc:procsm-11-69w7d751  nmdc:extrp-11-8aaf5q49  nmdc:bsm-11-g46hws70
# 10     nmdc:procsm-11-69w7d751  nmdc:extrp-11-8aaf5q49  nmdc:bsm-11-7gdzz704
# ...                        ...                     ...                   ...
# 12528  nmdc:procsm-11-tn3was93  nmdc:extrp-11-wfzqt783  nmdc:bsm-11-yhmy3172
# 12529  nmdc:procsm-11-tn3was93  nmdc:extrp-11-wfzqt783  nmdc:bsm-11-xedk6s97
# 12536  nmdc:procsm-11-3rfvyd88  nmdc:extrp-11-qw3ca676  nmdc:bsm-11-wbaszj27
# 12537  nmdc:procsm-11-3rfvyd88  nmdc:extrp-11-qw3ca676  nmdc:bsm-11-zr7b5t24
# 12538  nmdc:procsm-11-3rfvyd88  nmdc:extrp-11-qw3ca676  nmdc:bsm-11-xhzk6v39
#
#             pooling_has_output              pooling_id soil_horizon  \
# 0      nmdc:procsm-11-m6cgda89  nmdc:poolp-11-myygnt07    M horizon
# 1      nmdc:procsm-11-m6cgda89  nmdc:poolp-11-myygnt07    M horizon
# 2      nmdc:procsm-11-m6cgda89  nmdc:poolp-11-myygnt07    M horizon
# 9      nmdc:procsm-11-zxr4eq64  nmdc:poolp-11-hdyzxk28    M horizon
# 10     nmdc:procsm-11-zxr4eq64  nmdc:poolp-11-hdyzxk28    M horizon
# ...                        ...                     ...          ...
# 12528  nmdc:procsm-11-e273jx66  nmdc:poolp-11-marzp505    M horizon
# 12529  nmdc:procsm-11-e273jx66  nmdc:poolp-11-marzp505    M horizon
# 12536  nmdc:procsm-11-qpqz4w54  nmdc:poolp-11-evtggs98    O horizon
# 12537  nmdc:procsm-11-qpqz4w54  nmdc:poolp-11-evtggs98    O horizon
# 12538  nmdc:procsm-11-qpqz4w54  nmdc:poolp-11-evtggs98    O horizon
#
#                biosample_id        processed_sample1        processed_sample2
# 0      nmdc:bsm-11-zw0jr671  nmdc:procsm-11-m6cgda89  nmdc:procsm-11-e3m9am88
# 1      nmdc:bsm-11-ftr88019  nmdc:procsm-11-m6cgda89  nmdc:procsm-11-e3m9am88
# 2      nmdc:bsm-11-06qrej20  nmdc:procsm-11-m6cgda89  nmdc:procsm-11-e3m9am88
# 9      nmdc:bsm-11-g46hws70  nmdc:procsm-11-zxr4eq64  nmdc:procsm-11-69w7d751
# 10     nmdc:bsm-11-7gdzz704  nmdc:procsm-11-zxr4eq64  nmdc:procsm-11-69w7d751
# ...                     ...                      ...                      ...
# 12528  nmdc:bsm-11-yhmy3172  nmdc:procsm-11-e273jx66  nmdc:procsm-11-tn3was93
# 12529  nmdc:bsm-11-xedk6s97  nmdc:procsm-11-e273jx66  nmdc:procsm-11-tn3was93
# 12536  nmdc:bsm-11-wbaszj27  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 12537  nmdc:bsm-11-zr7b5t24  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 12538  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
#
# [4374 rows x 13 columns]

# %%
# Get process_set3 results from "lp_has_output"
# Use the library_prep_set results and identifier "lp_has_output" to query the processed_sample_set collection matching the
# "id" field. We return only the "id" field
process_set3 = get_id_results(library_prep_set, "lp_has_output", "processed_sample_set", "id", "id")

# clarify keys
for samp in process_set3:
    samp["processed_sample3"] = samp.pop("id")

# convert to data frame
ps3_df = convert_df(process_set3)
ps3_df
# Out:
#             processed_sample3
# 0     nmdc:procsm-11-062rbk44
# 1     nmdc:procsm-11-0tkbt064
# 2     nmdc:procsm-11-1cmwcb97
# 3     nmdc:procsm-11-211dc865
# 4     nmdc:procsm-11-21q8jj02
# ...                       ...
# 4239  nmdc:procsm-11-xpfxk275
# 4240  nmdc:procsm-11-yzae4f85
# 4241  nmdc:procsm-11-z1jy1841
# 4242  nmdc:procsm-11-z3476h43
# 4243  nmdc:procsm-11-zkkmtr10
#
# [4244 rows x 1 columns]

# %%
# Merge proces_set3 results with merged_list on "lp_has_output" with "processed_sample3" Takes 7+ minutes??
merged_df6 = merge_items(merged_df5, ps3_df, "lp_has_output", "processed_sample3", False, False)
merged_df6
# Out:
#                   lp_has_input            lp_has_output  \
# 0      nmdc:procsm-11-e3m9am88  nmdc:procsm-11-s71h1s64
# 3      nmdc:procsm-11-e3m9am88  nmdc:procsm-11-s71h1s64
# 6      nmdc:procsm-11-e3m9am88  nmdc:procsm-11-s71h1s64
# 9      nmdc:procsm-11-69w7d751  nmdc:procsm-11-pvq3cw40
# 12     nmdc:procsm-11-69w7d751  nmdc:procsm-11-pvq3cw40
# ...                        ...                      ...
# 12527  nmdc:procsm-11-tn3was93  nmdc:procsm-11-69fjnv37
# 12530  nmdc:procsm-11-tn3was93  nmdc:procsm-11-69fjnv37
# 12533  nmdc:procsm-11-3rfvyd88  nmdc:procsm-11-h6y3cf29
# 12536  nmdc:procsm-11-3rfvyd88  nmdc:procsm-11-h6y3cf29
# 12539  nmdc:procsm-11-3rfvyd88  nmdc:procsm-11-h6y3cf29
#
#                          lp_id        extract_has_input  \
# 0      nmdc:libprp-11-acbfh839  nmdc:procsm-11-m6cgda89
# 3      nmdc:libprp-11-acbfh839  nmdc:procsm-11-m6cgda89
# 6      nmdc:libprp-11-acbfh839  nmdc:procsm-11-m6cgda89
# 9      nmdc:libprp-11-e39ky379  nmdc:procsm-11-zxr4eq64
# 12     nmdc:libprp-11-e39ky379  nmdc:procsm-11-zxr4eq64
# ...                        ...                      ...
# 12527  nmdc:libprp-11-wz8cmz63  nmdc:procsm-11-e273jx66
# 12530  nmdc:libprp-11-wz8cmz63  nmdc:procsm-11-e273jx66
# 12533  nmdc:libprp-11-86c4n641  nmdc:procsm-11-qpqz4w54
# 12536  nmdc:libprp-11-86c4n641  nmdc:procsm-11-qpqz4w54
# 12539  nmdc:libprp-11-86c4n641  nmdc:procsm-11-qpqz4w54
#
#             extract_has_output              extract_id     pooling_has_input  \
# 0      nmdc:procsm-11-e3m9am88  nmdc:extrp-11-2hbzth07  nmdc:bsm-11-zw0jr671
# 3      nmdc:procsm-11-e3m9am88  nmdc:extrp-11-2hbzth07  nmdc:bsm-11-ftr88019
# 6      nmdc:procsm-11-e3m9am88  nmdc:extrp-11-2hbzth07  nmdc:bsm-11-06qrej20
# 9      nmdc:procsm-11-69w7d751  nmdc:extrp-11-8aaf5q49  nmdc:bsm-11-g46hws70
# 12     nmdc:procsm-11-69w7d751  nmdc:extrp-11-8aaf5q49  nmdc:bsm-11-7gdzz704
# ...                        ...                     ...                   ...
# 12527  nmdc:procsm-11-tn3was93  nmdc:extrp-11-wfzqt783  nmdc:bsm-11-yhmy3172
# 12530  nmdc:procsm-11-tn3was93  nmdc:extrp-11-wfzqt783  nmdc:bsm-11-xedk6s97
# 12533  nmdc:procsm-11-3rfvyd88  nmdc:extrp-11-qw3ca676  nmdc:bsm-11-wbaszj27
# 12536  nmdc:procsm-11-3rfvyd88  nmdc:extrp-11-qw3ca676  nmdc:bsm-11-zr7b5t24
# 12539  nmdc:procsm-11-3rfvyd88  nmdc:extrp-11-qw3ca676  nmdc:bsm-11-xhzk6v39
#
#             pooling_has_output              pooling_id soil_horizon  \
# 0      nmdc:procsm-11-m6cgda89  nmdc:poolp-11-myygnt07    M horizon
# 3      nmdc:procsm-11-m6cgda89  nmdc:poolp-11-myygnt07    M horizon
# 6      nmdc:procsm-11-m6cgda89  nmdc:poolp-11-myygnt07    M horizon
# 9      nmdc:procsm-11-zxr4eq64  nmdc:poolp-11-hdyzxk28    M horizon
# 12     nmdc:procsm-11-zxr4eq64  nmdc:poolp-11-hdyzxk28    M horizon
# ...                        ...                     ...          ...
# 12527  nmdc:procsm-11-e273jx66  nmdc:poolp-11-marzp505    M horizon
# 12530  nmdc:procsm-11-e273jx66  nmdc:poolp-11-marzp505    M horizon
# 12533  nmdc:procsm-11-qpqz4w54  nmdc:poolp-11-evtggs98    O horizon
# 12536  nmdc:procsm-11-qpqz4w54  nmdc:poolp-11-evtggs98    O horizon
# 12539  nmdc:procsm-11-qpqz4w54  nmdc:poolp-11-evtggs98    O horizon
#
#                biosample_id        processed_sample1        processed_sample2  \
# 0      nmdc:bsm-11-zw0jr671  nmdc:procsm-11-m6cgda89  nmdc:procsm-11-e3m9am88
# 3      nmdc:bsm-11-ftr88019  nmdc:procsm-11-m6cgda89  nmdc:procsm-11-e3m9am88
# 6      nmdc:bsm-11-06qrej20  nmdc:procsm-11-m6cgda89  nmdc:procsm-11-e3m9am88
# 9      nmdc:bsm-11-g46hws70  nmdc:procsm-11-zxr4eq64  nmdc:procsm-11-69w7d751
# 12     nmdc:bsm-11-7gdzz704  nmdc:procsm-11-zxr4eq64  nmdc:procsm-11-69w7d751
# ...                     ...                      ...                      ...
# 12527  nmdc:bsm-11-yhmy3172  nmdc:procsm-11-e273jx66  nmdc:procsm-11-tn3was93
# 12530  nmdc:bsm-11-xedk6s97  nmdc:procsm-11-e273jx66  nmdc:procsm-11-tn3was93
# 12533  nmdc:bsm-11-wbaszj27  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 12536  nmdc:bsm-11-zr7b5t24  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 12539  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
#
#              processed_sample3
# 0      nmdc:procsm-11-s71h1s64
# 3      nmdc:procsm-11-s71h1s64
# 6      nmdc:procsm-11-s71h1s64
# 9      nmdc:procsm-11-pvq3cw40
# 12     nmdc:procsm-11-pvq3cw40
# ...                        ...
# 12527  nmdc:procsm-11-69fjnv37
# 12530  nmdc:procsm-11-69fjnv37
# 12533  nmdc:procsm-11-h6y3cf29
# 12536  nmdc:procsm-11-h6y3cf29
# 12539  nmdc:procsm-11-h6y3cf29
#
# [4374 rows x 14 columns]

# %%
# Get omics_processing results from "processed_sample3"
# Use the process_set3 results identifier "processed_sample3" to query the omics_processing_set collection matching the
# "has_input" field. Return "has_input" and "id"
omics_process_set = get_id_results(process_set3, "processed_sample3", "omics_processing_set", "has_input", "has_input,id")

# clarify keys
for op in omics_process_set:
    op["op_has_input"] = op.pop("has_input")
    op["op_id"] = op.pop("id")

# convert to data frame
op_df = convert_df(omics_process_set)
op_df
# Out:
#                    op_has_input                   op_id
# 0     [nmdc:procsm-11-062rbk44]  nmdc:omprc-11-bn309345
# 1     [nmdc:procsm-11-0tkbt064]  nmdc:omprc-11-db9g5v27
# 2     [nmdc:procsm-11-1cmwcb97]  nmdc:omprc-11-83e9ph40
# 3     [nmdc:procsm-11-211dc865]  nmdc:omprc-11-kfxafd58
# 4     [nmdc:procsm-11-21q8jj02]  nmdc:omprc-11-pwveft17
# ...                         ...                     ...
# 4205  [nmdc:procsm-11-xpfxk275]  nmdc:omprc-11-f9x2k996
# 4206  [nmdc:procsm-11-yzae4f85]  nmdc:omprc-11-9n5fc730
# 4207  [nmdc:procsm-11-z1jy1841]  nmdc:omprc-11-cv9ymw96
# 4208  [nmdc:procsm-11-z3476h43]  nmdc:omprc-11-4wq97r16
# 4209  [nmdc:procsm-11-zkkmtr10]  nmdc:omprc-11-wb44ve09
#
# [4210 rows x 2 columns]

# %%
# Merge omics_process_set with merged_list on processed "processed_sample3"
merged_df7 = merge_items(op_df, merged_df6, "op_has_input", "processed_sample3", True, False, "op_id")
merged_df7
# Out:
#                   op_has_input                   op_id  \
# 0      nmdc:procsm-11-062rbk44  nmdc:omprc-11-bn309345
# 1      nmdc:procsm-11-062rbk44  nmdc:omprc-11-bn309345
# 2      nmdc:procsm-11-062rbk44  nmdc:omprc-11-bn309345
# 9      nmdc:procsm-11-0tkbt064  nmdc:omprc-11-db9g5v27
# 10     nmdc:procsm-11-0tkbt064  nmdc:omprc-11-db9g5v27
# ...                        ...                     ...
# 12425  nmdc:procsm-11-69fjnv37  nmdc:omprc-11-fm395k32
# 12426  nmdc:procsm-11-69fjnv37  nmdc:omprc-11-fm395k32
# 12433  nmdc:procsm-11-h6y3cf29  nmdc:omprc-11-bj2afq20
# 12434  nmdc:procsm-11-h6y3cf29  nmdc:omprc-11-bj2afq20
# 12435  nmdc:procsm-11-h6y3cf29  nmdc:omprc-11-bj2afq20
#
#                   lp_has_input            lp_has_output  \
# 0      nmdc:procsm-11-6p7xet10  nmdc:procsm-11-062rbk44
# 1      nmdc:procsm-11-6p7xet10  nmdc:procsm-11-062rbk44
# 2      nmdc:procsm-11-6p7xet10  nmdc:procsm-11-062rbk44
# 9      nmdc:procsm-11-e3pwqj47  nmdc:procsm-11-0tkbt064
# 10     nmdc:procsm-11-e3pwqj47  nmdc:procsm-11-0tkbt064
# ...                        ...                      ...
# 12425  nmdc:procsm-11-tn3was93  nmdc:procsm-11-69fjnv37
# 12426  nmdc:procsm-11-tn3was93  nmdc:procsm-11-69fjnv37
# 12433  nmdc:procsm-11-3rfvyd88  nmdc:procsm-11-h6y3cf29
# 12434  nmdc:procsm-11-3rfvyd88  nmdc:procsm-11-h6y3cf29
# 12435  nmdc:procsm-11-3rfvyd88  nmdc:procsm-11-h6y3cf29
#
#                          lp_id        extract_has_input  \
# 0      nmdc:libprp-11-2cy94060  nmdc:procsm-11-z19p2488
# 1      nmdc:libprp-11-2cy94060  nmdc:procsm-11-z19p2488
# 2      nmdc:libprp-11-2cy94060  nmdc:procsm-11-z19p2488
# 9      nmdc:libprp-11-6yxpe617  nmdc:procsm-11-22s7xc89
# 10     nmdc:libprp-11-6yxpe617  nmdc:procsm-11-22s7xc89
# ...                        ...                      ...
# 12425  nmdc:libprp-11-wz8cmz63  nmdc:procsm-11-e273jx66
# 12426  nmdc:libprp-11-wz8cmz63  nmdc:procsm-11-e273jx66
# 12433  nmdc:libprp-11-86c4n641  nmdc:procsm-11-qpqz4w54
# 12434  nmdc:libprp-11-86c4n641  nmdc:procsm-11-qpqz4w54
# 12435  nmdc:libprp-11-86c4n641  nmdc:procsm-11-qpqz4w54
#
#             extract_has_output              extract_id     pooling_has_input  \
# 0      nmdc:procsm-11-6p7xet10  nmdc:extrp-11-1w7rz874  nmdc:bsm-11-01g9wf51
# 1      nmdc:procsm-11-6p7xet10  nmdc:extrp-11-1w7rz874  nmdc:bsm-11-d8mzds05
# 2      nmdc:procsm-11-6p7xet10  nmdc:extrp-11-1w7rz874  nmdc:bsm-11-qf98ze18
# 9      nmdc:procsm-11-e3pwqj47  nmdc:extrp-11-bx6tsd08  nmdc:bsm-11-rry3a275
# 10     nmdc:procsm-11-e3pwqj47  nmdc:extrp-11-bx6tsd08  nmdc:bsm-11-0g28x785
# ...                        ...                     ...                   ...
# 12425  nmdc:procsm-11-tn3was93  nmdc:extrp-11-wfzqt783  nmdc:bsm-11-yhmy3172
# 12426  nmdc:procsm-11-tn3was93  nmdc:extrp-11-wfzqt783  nmdc:bsm-11-xedk6s97
# 12433  nmdc:procsm-11-3rfvyd88  nmdc:extrp-11-qw3ca676  nmdc:bsm-11-wbaszj27
# 12434  nmdc:procsm-11-3rfvyd88  nmdc:extrp-11-qw3ca676  nmdc:bsm-11-zr7b5t24
# 12435  nmdc:procsm-11-3rfvyd88  nmdc:extrp-11-qw3ca676  nmdc:bsm-11-xhzk6v39
#
#             pooling_has_output              pooling_id soil_horizon  \
# 0      nmdc:procsm-11-z19p2488  nmdc:poolp-11-phdxxg80    O horizon
# 1      nmdc:procsm-11-z19p2488  nmdc:poolp-11-phdxxg80    O horizon
# 2      nmdc:procsm-11-z19p2488  nmdc:poolp-11-phdxxg80    O horizon
# 9      nmdc:procsm-11-22s7xc89  nmdc:poolp-11-qapwf603    M horizon
# 10     nmdc:procsm-11-22s7xc89  nmdc:poolp-11-qapwf603    M horizon
# ...                        ...                     ...          ...
# 12425  nmdc:procsm-11-e273jx66  nmdc:poolp-11-marzp505    M horizon
# 12426  nmdc:procsm-11-e273jx66  nmdc:poolp-11-marzp505    M horizon
# 12433  nmdc:procsm-11-qpqz4w54  nmdc:poolp-11-evtggs98    O horizon
# 12434  nmdc:procsm-11-qpqz4w54  nmdc:poolp-11-evtggs98    O horizon
# 12435  nmdc:procsm-11-qpqz4w54  nmdc:poolp-11-evtggs98    O horizon
#
#                biosample_id        processed_sample1        processed_sample2  \
# 0      nmdc:bsm-11-01g9wf51  nmdc:procsm-11-z19p2488  nmdc:procsm-11-6p7xet10
# 1      nmdc:bsm-11-d8mzds05  nmdc:procsm-11-z19p2488  nmdc:procsm-11-6p7xet10
# 2      nmdc:bsm-11-qf98ze18  nmdc:procsm-11-z19p2488  nmdc:procsm-11-6p7xet10
# 9      nmdc:bsm-11-rry3a275  nmdc:procsm-11-22s7xc89  nmdc:procsm-11-e3pwqj47
# 10     nmdc:bsm-11-0g28x785  nmdc:procsm-11-22s7xc89  nmdc:procsm-11-e3pwqj47
# ...                     ...                      ...                      ...
# 12425  nmdc:bsm-11-yhmy3172  nmdc:procsm-11-e273jx66  nmdc:procsm-11-tn3was93
# 12426  nmdc:bsm-11-xedk6s97  nmdc:procsm-11-e273jx66  nmdc:procsm-11-tn3was93
# 12433  nmdc:bsm-11-wbaszj27  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 12434  nmdc:bsm-11-zr7b5t24  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 12435  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
#
#              processed_sample3
# 0      nmdc:procsm-11-062rbk44
# 1      nmdc:procsm-11-062rbk44
# 2      nmdc:procsm-11-062rbk44
# 9      nmdc:procsm-11-0tkbt064
# 10     nmdc:procsm-11-0tkbt064
# ...                        ...
# 12425  nmdc:procsm-11-69fjnv37
# 12426  nmdc:procsm-11-69fjnv37
# 12433  nmdc:procsm-11-h6y3cf29
# 12434  nmdc:procsm-11-h6y3cf29
# 12435  nmdc:procsm-11-h6y3cf29
#
# [4339 rows x 16 columns]

# %%
# Get metagenome_annotation_activity_set from "op_id"
# Use the omics_process_set results identifier "op_id" to query the metagenome_annotation_activity_set collection matching
# the "was_informed_by" field. Return "was_informed_by" and "has_output"
meta_act_ann_set = get_id_results(omics_process_set, "op_id", "metagenome_annotation_activity_set", "was_informed_by", "has_output,was_informed_by,id")

# clarify names
for mga in meta_act_ann_set:
    mga["mga_id"] = mga.pop("id")
    mga["mga_was_informed_by"] = mga.pop("was_informed_by")
    mga["mga_has_output"] = mga.pop("has_output")

# convert to data frame
mga_df = convert_df(meta_act_ann_set)
mga_df
# Out:
#                          mga_id     mga_was_informed_by  \
# 0     nmdc:wfmgan-11-h05qba23.1  nmdc:omprc-11-5qs1cd02
# 1     nmdc:wfmgan-11-4h48ff64.1  nmdc:omprc-11-1zehaw93
# 2     nmdc:wfmgan-11-f8cseh97.1  nmdc:omprc-11-bn309345
# 3     nmdc:wfmgan-11-bajw6h61.1  nmdc:omprc-11-dsv3f325
# 4     nmdc:wfmgan-11-0w0rnd53.1  nmdc:omprc-11-897qak81
# ...                         ...                     ...
# 3748  nmdc:wfmgan-11-r9xyg197.1  nmdc:omprc-11-qg2e3t41
# 3749  nmdc:wfmgan-11-dxqxre60.1  nmdc:omprc-11-cpqbew37
# 3750  nmdc:wfmgan-11-14gcar54.1  nmdc:omprc-11-px5df021
# 3751  nmdc:wfmgan-11-z6d94p37.1  nmdc:omprc-11-cv9ymw96
# 3752  nmdc:wfmgan-11-5rqhd816.1  nmdc:omprc-11-f9x2k996
#
#                                          mga_has_output
# 0     [nmdc:dobj-11-808cyq50, nmdc:dobj-11-13d79a82,...
# 1     [nmdc:dobj-11-m70ftn50, nmdc:dobj-11-kwbeyv20,...
# 2     [nmdc:dobj-11-f1trcg75, nmdc:dobj-11-5pqvfm47,...
# 3     [nmdc:dobj-11-qzsjp850, nmdc:dobj-11-tmp0t041,...
# 4     [nmdc:dobj-11-0dfd5b92, nmdc:dobj-11-04jsg262,...
# ...                                                 ...
# 3748  [nmdc:dobj-11-aav9vk45, nmdc:dobj-11-eats2y81,...
# 3749  [nmdc:dobj-11-7f8e4a45, nmdc:dobj-11-4rmq5t75,...
# 3750  [nmdc:dobj-11-dy2jsc18, nmdc:dobj-11-3amwd664,...
# 3751  [nmdc:dobj-11-f251gr10, nmdc:dobj-11-207dgx57,...
# 3752  [nmdc:dobj-11-wc0y8n82, nmdc:dobj-11-t6jrx266,...
#
# [3753 rows x 3 columns]

# %%
# Merge metagenome activity set with merged_list on mga_has_input
merged_df8 = merge_items(merged_df7, mga_df,  "op_id", "mga_was_informed_by", False, True, "mga_has_output")
merged_df8
# Out:
#                   op_has_input                   op_id  \
# 0      nmdc:procsm-11-062rbk44  nmdc:omprc-11-bn309345
# 0      nmdc:procsm-11-062rbk44  nmdc:omprc-11-bn309345
# 0      nmdc:procsm-11-062rbk44  nmdc:omprc-11-bn309345
# 0      nmdc:procsm-11-062rbk44  nmdc:omprc-11-bn309345
# 0      nmdc:procsm-11-062rbk44  nmdc:omprc-11-bn309345
# ...                        ...                     ...
# 11082  nmdc:procsm-11-h6y3cf29  nmdc:omprc-11-bj2afq20
# 11082  nmdc:procsm-11-h6y3cf29  nmdc:omprc-11-bj2afq20
# 11082  nmdc:procsm-11-h6y3cf29  nmdc:omprc-11-bj2afq20
# 11082  nmdc:procsm-11-h6y3cf29  nmdc:omprc-11-bj2afq20
# 11082  nmdc:procsm-11-h6y3cf29  nmdc:omprc-11-bj2afq20
#
#                   lp_has_input            lp_has_output  \
# 0      nmdc:procsm-11-6p7xet10  nmdc:procsm-11-062rbk44
# 0      nmdc:procsm-11-6p7xet10  nmdc:procsm-11-062rbk44
# 0      nmdc:procsm-11-6p7xet10  nmdc:procsm-11-062rbk44
# 0      nmdc:procsm-11-6p7xet10  nmdc:procsm-11-062rbk44
# 0      nmdc:procsm-11-6p7xet10  nmdc:procsm-11-062rbk44
# ...                        ...                      ...
# 11082  nmdc:procsm-11-3rfvyd88  nmdc:procsm-11-h6y3cf29
# 11082  nmdc:procsm-11-3rfvyd88  nmdc:procsm-11-h6y3cf29
# 11082  nmdc:procsm-11-3rfvyd88  nmdc:procsm-11-h6y3cf29
# 11082  nmdc:procsm-11-3rfvyd88  nmdc:procsm-11-h6y3cf29
# 11082  nmdc:procsm-11-3rfvyd88  nmdc:procsm-11-h6y3cf29
#
#                          lp_id        extract_has_input  \
# 0      nmdc:libprp-11-2cy94060  nmdc:procsm-11-z19p2488
# 0      nmdc:libprp-11-2cy94060  nmdc:procsm-11-z19p2488
# 0      nmdc:libprp-11-2cy94060  nmdc:procsm-11-z19p2488
# 0      nmdc:libprp-11-2cy94060  nmdc:procsm-11-z19p2488
# 0      nmdc:libprp-11-2cy94060  nmdc:procsm-11-z19p2488
# ...                        ...                      ...
# 11082  nmdc:libprp-11-86c4n641  nmdc:procsm-11-qpqz4w54
# 11082  nmdc:libprp-11-86c4n641  nmdc:procsm-11-qpqz4w54
# 11082  nmdc:libprp-11-86c4n641  nmdc:procsm-11-qpqz4w54
# 11082  nmdc:libprp-11-86c4n641  nmdc:procsm-11-qpqz4w54
# 11082  nmdc:libprp-11-86c4n641  nmdc:procsm-11-qpqz4w54
#
#             extract_has_output              extract_id     pooling_has_input  \
# 0      nmdc:procsm-11-6p7xet10  nmdc:extrp-11-1w7rz874  nmdc:bsm-11-01g9wf51
# 0      nmdc:procsm-11-6p7xet10  nmdc:extrp-11-1w7rz874  nmdc:bsm-11-01g9wf51
# 0      nmdc:procsm-11-6p7xet10  nmdc:extrp-11-1w7rz874  nmdc:bsm-11-01g9wf51
# 0      nmdc:procsm-11-6p7xet10  nmdc:extrp-11-1w7rz874  nmdc:bsm-11-01g9wf51
# 0      nmdc:procsm-11-6p7xet10  nmdc:extrp-11-1w7rz874  nmdc:bsm-11-01g9wf51
# ...                        ...                     ...                   ...
# 11082  nmdc:procsm-11-3rfvyd88  nmdc:extrp-11-qw3ca676  nmdc:bsm-11-xhzk6v39
# 11082  nmdc:procsm-11-3rfvyd88  nmdc:extrp-11-qw3ca676  nmdc:bsm-11-xhzk6v39
# 11082  nmdc:procsm-11-3rfvyd88  nmdc:extrp-11-qw3ca676  nmdc:bsm-11-xhzk6v39
# 11082  nmdc:procsm-11-3rfvyd88  nmdc:extrp-11-qw3ca676  nmdc:bsm-11-xhzk6v39
# 11082  nmdc:procsm-11-3rfvyd88  nmdc:extrp-11-qw3ca676  nmdc:bsm-11-xhzk6v39
#
#             pooling_has_output              pooling_id soil_horizon  \
# 0      nmdc:procsm-11-z19p2488  nmdc:poolp-11-phdxxg80    O horizon
# 0      nmdc:procsm-11-z19p2488  nmdc:poolp-11-phdxxg80    O horizon
# 0      nmdc:procsm-11-z19p2488  nmdc:poolp-11-phdxxg80    O horizon
# 0      nmdc:procsm-11-z19p2488  nmdc:poolp-11-phdxxg80    O horizon
# 0      nmdc:procsm-11-z19p2488  nmdc:poolp-11-phdxxg80    O horizon
# ...                        ...                     ...          ...
# 11082  nmdc:procsm-11-qpqz4w54  nmdc:poolp-11-evtggs98    O horizon
# 11082  nmdc:procsm-11-qpqz4w54  nmdc:poolp-11-evtggs98    O horizon
# 11082  nmdc:procsm-11-qpqz4w54  nmdc:poolp-11-evtggs98    O horizon
# 11082  nmdc:procsm-11-qpqz4w54  nmdc:poolp-11-evtggs98    O horizon
# 11082  nmdc:procsm-11-qpqz4w54  nmdc:poolp-11-evtggs98    O horizon
#
#                biosample_id        processed_sample1        processed_sample2  \
# 0      nmdc:bsm-11-01g9wf51  nmdc:procsm-11-z19p2488  nmdc:procsm-11-6p7xet10
# 0      nmdc:bsm-11-01g9wf51  nmdc:procsm-11-z19p2488  nmdc:procsm-11-6p7xet10
# 0      nmdc:bsm-11-01g9wf51  nmdc:procsm-11-z19p2488  nmdc:procsm-11-6p7xet10
# 0      nmdc:bsm-11-01g9wf51  nmdc:procsm-11-z19p2488  nmdc:procsm-11-6p7xet10
# 0      nmdc:bsm-11-01g9wf51  nmdc:procsm-11-z19p2488  nmdc:procsm-11-6p7xet10
# ...                     ...                      ...                      ...
# 11082  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 11082  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 11082  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 11082  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 11082  nmdc:bsm-11-xhzk6v39  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
#
#              processed_sample3                     mga_id  \
# 0      nmdc:procsm-11-062rbk44  nmdc:wfmgan-11-f8cseh97.1
# 0      nmdc:procsm-11-062rbk44  nmdc:wfmgan-11-f8cseh97.1
# 0      nmdc:procsm-11-062rbk44  nmdc:wfmgan-11-f8cseh97.1
# 0      nmdc:procsm-11-062rbk44  nmdc:wfmgan-11-f8cseh97.1
# 0      nmdc:procsm-11-062rbk44  nmdc:wfmgan-11-f8cseh97.1
# ...                        ...                        ...
# 11082  nmdc:procsm-11-h6y3cf29  nmdc:wfmgan-11-wcy28p27.1
# 11082  nmdc:procsm-11-h6y3cf29  nmdc:wfmgan-11-wcy28p27.1
# 11082  nmdc:procsm-11-h6y3cf29  nmdc:wfmgan-11-wcy28p27.1
# 11082  nmdc:procsm-11-h6y3cf29  nmdc:wfmgan-11-wcy28p27.1
# 11082  nmdc:procsm-11-h6y3cf29  nmdc:wfmgan-11-wcy28p27.1
#
#           mga_was_informed_by         mga_has_output
# 0      nmdc:omprc-11-bn309345  nmdc:dobj-11-f1trcg75
# 0      nmdc:omprc-11-bn309345  nmdc:dobj-11-5pqvfm47
# 0      nmdc:omprc-11-bn309345  nmdc:dobj-11-55n2dk28
# 0      nmdc:omprc-11-bn309345  nmdc:dobj-11-5x2ebc40
# 0      nmdc:omprc-11-bn309345  nmdc:dobj-11-18y0s926
# ...                       ...                    ...
# 11082  nmdc:omprc-11-bj2afq20  nmdc:dobj-11-csq6r402
# 11082  nmdc:omprc-11-bj2afq20  nmdc:dobj-11-wv9ha238
# 11082  nmdc:omprc-11-bj2afq20  nmdc:dobj-11-eq8ytw35
# 11082  nmdc:omprc-11-bj2afq20  nmdc:dobj-11-f0eg5v22
# 11082  nmdc:omprc-11-bj2afq20  nmdc:dobj-11-7j41fk22
#
# [89125 rows x 19 columns]

# %%
# Get data_object_set from "mga_has_output"
# Use the met_act_ann_set results identifier "mga_has_output" to query the data_object_set collection matching
# the "id" field. Return "id", "data_object_type": "Scaffold Lineage tsv", "data_object_url"
data_ob_set = get_id_results(meta_act_ann_set, "mga_has_output", "data_object_set", '"data_object_type": "Scaffold Lineage tsv", "id"', 
                             "id,data_object_type,url")

# clarify fields
for ob in data_ob_set:
    ob["data_ob_id"] = ob.pop("id")

# convert to data frame
do_df = convert_df(data_ob_set)
do_df
# Out:
#           data_object_type                                                url  \
# 0     Scaffold Lineage tsv  https://data.microbiomedata.org/data/nmdc:ompr...
# 1     Scaffold Lineage tsv  https://data.microbiomedata.org/data/nmdc:ompr...
# 2     Scaffold Lineage tsv  https://data.microbiomedata.org/data/nmdc:ompr...
# 3     Scaffold Lineage tsv  https://data.microbiomedata.org/data/nmdc:ompr...
# 4     Scaffold Lineage tsv  https://data.microbiomedata.org/data/nmdc:ompr...
# ...                    ...                                                ...
# 3748  Scaffold Lineage tsv  https://data.microbiomedata.org/data/nmdc:ompr...
# 3749  Scaffold Lineage tsv  https://data.microbiomedata.org/data/nmdc:ompr...
# 3750  Scaffold Lineage tsv  https://data.microbiomedata.org/data/nmdc:ompr...
# 3751  Scaffold Lineage tsv  https://data.microbiomedata.org/data/nmdc:ompr...
# 3752  Scaffold Lineage tsv  https://data.microbiomedata.org/data/nmdc:ompr...
#
#                  data_ob_id
# 0     nmdc:dobj-11-1txpq765
# 1     nmdc:dobj-11-2tmqv903
# 2     nmdc:dobj-11-5c9hjp21
# 3     nmdc:dobj-11-mwz10b29
# 4     nmdc:dobj-11-q65rb692
# ...                     ...
# 3748  nmdc:dobj-11-1n0vjp57
# 3749  nmdc:dobj-11-3e557398
# 3750  nmdc:dobj-11-g995v511
# 3751  nmdc:dobj-11-q3de6z81
# 3752  nmdc:dobj-11-rvvrac16
#
# [3753 rows x 3 columns]

# %%
# Merge data_object_set with merged_list on id
merged_df9 = merge_items(do_df, merged_df8, "data_ob_id", "mga_has_output", False, False)
merged_df9
# Out:
#            data_object_type  \
# 0      Scaffold Lineage tsv
# 1      Scaffold Lineage tsv
# 2      Scaffold Lineage tsv
# 9      Scaffold Lineage tsv
# 10     Scaffold Lineage tsv
# ...                     ...
# 11068  Scaffold Lineage tsv
# 11069  Scaffold Lineage tsv
# 11076  Scaffold Lineage tsv
# 11077  Scaffold Lineage tsv
# 11078  Scaffold Lineage tsv
#
#                                                      url  \
# 0      https://data.microbiomedata.org/data/nmdc:ompr...
# 1      https://data.microbiomedata.org/data/nmdc:ompr...
# 2      https://data.microbiomedata.org/data/nmdc:ompr...
# 9      https://data.microbiomedata.org/data/nmdc:ompr...
# 10     https://data.microbiomedata.org/data/nmdc:ompr...
# ...                                                  ...
# 11068  https://data.microbiomedata.org/data/nmdc:ompr...
# 11069  https://data.microbiomedata.org/data/nmdc:ompr...
# 11076  https://data.microbiomedata.org/data/nmdc:ompr...
# 11077  https://data.microbiomedata.org/data/nmdc:ompr...
# 11078  https://data.microbiomedata.org/data/nmdc:ompr...
#
#                   data_ob_id             op_has_input                   op_id  \
# 0      nmdc:dobj-11-1txpq765  nmdc:procsm-11-je3jg029  nmdc:omprc-11-897qak81
# 1      nmdc:dobj-11-1txpq765  nmdc:procsm-11-je3jg029  nmdc:omprc-11-897qak81
# 2      nmdc:dobj-11-1txpq765  nmdc:procsm-11-je3jg029  nmdc:omprc-11-897qak81
# 9      nmdc:dobj-11-2tmqv903  nmdc:procsm-11-062rbk44  nmdc:omprc-11-bn309345
# 10     nmdc:dobj-11-2tmqv903  nmdc:procsm-11-062rbk44  nmdc:omprc-11-bn309345
# ...                      ...                      ...                     ...
# 11068  nmdc:dobj-11-prc39h15  nmdc:procsm-11-69fjnv37  nmdc:omprc-11-fm395k32
# 11069  nmdc:dobj-11-prc39h15  nmdc:procsm-11-69fjnv37  nmdc:omprc-11-fm395k32
# 11076  nmdc:dobj-11-5wyv2j19  nmdc:procsm-11-h6y3cf29  nmdc:omprc-11-bj2afq20
# 11077  nmdc:dobj-11-5wyv2j19  nmdc:procsm-11-h6y3cf29  nmdc:omprc-11-bj2afq20
# 11078  nmdc:dobj-11-5wyv2j19  nmdc:procsm-11-h6y3cf29  nmdc:omprc-11-bj2afq20
#
#                   lp_has_input            lp_has_output  \
# 0      nmdc:procsm-11-4508yv43  nmdc:procsm-11-je3jg029
# 1      nmdc:procsm-11-4508yv43  nmdc:procsm-11-je3jg029
# 2      nmdc:procsm-11-4508yv43  nmdc:procsm-11-je3jg029
# 9      nmdc:procsm-11-6p7xet10  nmdc:procsm-11-062rbk44
# 10     nmdc:procsm-11-6p7xet10  nmdc:procsm-11-062rbk44
# ...                        ...                      ...
# 11068  nmdc:procsm-11-tn3was93  nmdc:procsm-11-69fjnv37
# 11069  nmdc:procsm-11-tn3was93  nmdc:procsm-11-69fjnv37
# 11076  nmdc:procsm-11-3rfvyd88  nmdc:procsm-11-h6y3cf29
# 11077  nmdc:procsm-11-3rfvyd88  nmdc:procsm-11-h6y3cf29
# 11078  nmdc:procsm-11-3rfvyd88  nmdc:procsm-11-h6y3cf29
#
#                          lp_id        extract_has_input  \
# 0      nmdc:libprp-11-7ffq2g12  nmdc:procsm-11-xdbhma02
# 1      nmdc:libprp-11-7ffq2g12  nmdc:procsm-11-xdbhma02
# 2      nmdc:libprp-11-7ffq2g12  nmdc:procsm-11-xdbhma02
# 9      nmdc:libprp-11-2cy94060  nmdc:procsm-11-z19p2488
# 10     nmdc:libprp-11-2cy94060  nmdc:procsm-11-z19p2488
# ...                        ...                      ...
# 11068  nmdc:libprp-11-wz8cmz63  nmdc:procsm-11-e273jx66
# 11069  nmdc:libprp-11-wz8cmz63  nmdc:procsm-11-e273jx66
# 11076  nmdc:libprp-11-86c4n641  nmdc:procsm-11-qpqz4w54
# 11077  nmdc:libprp-11-86c4n641  nmdc:procsm-11-qpqz4w54
# 11078  nmdc:libprp-11-86c4n641  nmdc:procsm-11-qpqz4w54
#
#             extract_has_output  ...       pooling_has_output  \
# 0      nmdc:procsm-11-4508yv43  ...  nmdc:procsm-11-xdbhma02
# 1      nmdc:procsm-11-4508yv43  ...  nmdc:procsm-11-xdbhma02
# 2      nmdc:procsm-11-4508yv43  ...  nmdc:procsm-11-xdbhma02
# 9      nmdc:procsm-11-6p7xet10  ...  nmdc:procsm-11-z19p2488
# 10     nmdc:procsm-11-6p7xet10  ...  nmdc:procsm-11-z19p2488
# ...                        ...  ...                      ...
# 11068  nmdc:procsm-11-tn3was93  ...  nmdc:procsm-11-e273jx66
# 11069  nmdc:procsm-11-tn3was93  ...  nmdc:procsm-11-e273jx66
# 11076  nmdc:procsm-11-3rfvyd88  ...  nmdc:procsm-11-qpqz4w54
# 11077  nmdc:procsm-11-3rfvyd88  ...  nmdc:procsm-11-qpqz4w54
# 11078  nmdc:procsm-11-3rfvyd88  ...  nmdc:procsm-11-qpqz4w54
#
#                    pooling_id soil_horizon          biosample_id  \
# 0      nmdc:poolp-11-5p6tjm70    M horizon  nmdc:bsm-11-158pa966
# 1      nmdc:poolp-11-5p6tjm70    M horizon  nmdc:bsm-11-6y6bv491
# 2      nmdc:poolp-11-5p6tjm70    M horizon  nmdc:bsm-11-naha5e81
# 9      nmdc:poolp-11-phdxxg80    O horizon  nmdc:bsm-11-01g9wf51
# 10     nmdc:poolp-11-phdxxg80    O horizon  nmdc:bsm-11-d8mzds05
# ...                       ...          ...                   ...
# 11068  nmdc:poolp-11-marzp505    M horizon  nmdc:bsm-11-yhmy3172
# 11069  nmdc:poolp-11-marzp505    M horizon  nmdc:bsm-11-xedk6s97
# 11076  nmdc:poolp-11-evtggs98    O horizon  nmdc:bsm-11-wbaszj27
# 11077  nmdc:poolp-11-evtggs98    O horizon  nmdc:bsm-11-zr7b5t24
# 11078  nmdc:poolp-11-evtggs98    O horizon  nmdc:bsm-11-xhzk6v39
#
#              processed_sample1        processed_sample2  \
# 0      nmdc:procsm-11-xdbhma02  nmdc:procsm-11-4508yv43
# 1      nmdc:procsm-11-xdbhma02  nmdc:procsm-11-4508yv43
# 2      nmdc:procsm-11-xdbhma02  nmdc:procsm-11-4508yv43
# 9      nmdc:procsm-11-z19p2488  nmdc:procsm-11-6p7xet10
# 10     nmdc:procsm-11-z19p2488  nmdc:procsm-11-6p7xet10
# ...                        ...                      ...
# 11068  nmdc:procsm-11-e273jx66  nmdc:procsm-11-tn3was93
# 11069  nmdc:procsm-11-e273jx66  nmdc:procsm-11-tn3was93
# 11076  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 11077  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
# 11078  nmdc:procsm-11-qpqz4w54  nmdc:procsm-11-3rfvyd88
#
#              processed_sample3                     mga_id  \
# 0      nmdc:procsm-11-je3jg029  nmdc:wfmgan-11-0w0rnd53.1
# 1      nmdc:procsm-11-je3jg029  nmdc:wfmgan-11-0w0rnd53.1
# 2      nmdc:procsm-11-je3jg029  nmdc:wfmgan-11-0w0rnd53.1
# 9      nmdc:procsm-11-062rbk44  nmdc:wfmgan-11-f8cseh97.1
# 10     nmdc:procsm-11-062rbk44  nmdc:wfmgan-11-f8cseh97.1
# ...                        ...                        ...
# 11068  nmdc:procsm-11-69fjnv37  nmdc:wfmgan-11-z0rn4p56.1
# 11069  nmdc:procsm-11-69fjnv37  nmdc:wfmgan-11-z0rn4p56.1
# 11076  nmdc:procsm-11-h6y3cf29  nmdc:wfmgan-11-wcy28p27.1
# 11077  nmdc:procsm-11-h6y3cf29  nmdc:wfmgan-11-wcy28p27.1
# 11078  nmdc:procsm-11-h6y3cf29  nmdc:wfmgan-11-wcy28p27.1
#
#           mga_was_informed_by         mga_has_output
# 0      nmdc:omprc-11-897qak81  nmdc:dobj-11-1txpq765
# 1      nmdc:omprc-11-897qak81  nmdc:dobj-11-1txpq765
# 2      nmdc:omprc-11-897qak81  nmdc:dobj-11-1txpq765
# 9      nmdc:omprc-11-bn309345  nmdc:dobj-11-2tmqv903
# 10     nmdc:omprc-11-bn309345  nmdc:dobj-11-2tmqv903
# ...                       ...                    ...
# 11068  nmdc:omprc-11-fm395k32  nmdc:dobj-11-prc39h15
# 11069  nmdc:omprc-11-fm395k32  nmdc:dobj-11-prc39h15
# 11076  nmdc:omprc-11-bj2afq20  nmdc:dobj-11-5wyv2j19
# 11077  nmdc:omprc-11-bj2afq20  nmdc:dobj-11-5wyv2j19
# 11078  nmdc:omprc-11-bj2afq20  nmdc:dobj-11-5wyv2j19
#
# [3875 rows x 22 columns]

# %%
# clean up data frame - remove all middle "joining columns" because the merge is getting slow\
column_list = merged_df9.columns.tolist()
columns_to_keep = ["soil_horizon", "biosample_id", "url"]
columns_to_remove = list(set(column_list).difference(columns_to_keep))
# Drop unnecessary rows
df9_cleaned = merged_df9.drop(columns=columns_to_remove)

# remove duplicates
df9_cleaned.drop_duplicates(keep="first", inplace=True)

# check rows when we reagrregate/implode, 
final_df = df9_cleaned.groupby(["soil_horizon", "biosample_id"]).agg({"url": list}).reset_index()

final_df
# Out:
#      soil_horizon          biosample_id  \
# 0       M horizon  nmdc:bsm-11-00dkyf35
# 1       M horizon  nmdc:bsm-11-02kcw433
# 2       M horizon  nmdc:bsm-11-02n85875
# 3       M horizon  nmdc:bsm-11-034x5t48
# 4       M horizon  nmdc:bsm-11-043hgn06
# ...           ...                   ...
# 3858    O horizon  nmdc:bsm-11-zv1dn095
# 3859    O horizon  nmdc:bsm-11-zvepbm45
# 3860    O horizon  nmdc:bsm-11-zw5rb344
# 3861    O horizon  nmdc:bsm-11-zx7j9919
# 3862    O horizon  nmdc:bsm-11-zxvtgn65
#
#                                                     url
# 0     [https://data.microbiomedata.org/data/nmdc:omp...
# 1     [https://data.microbiomedata.org/data/nmdc:omp...
# 2     [https://data.microbiomedata.org/data/nmdc:omp...
# 3     [https://data.microbiomedata.org/data/nmdc:omp...
# 4     [https://data.microbiomedata.org/data/nmdc:omp...
# ...                                                 ...
# 3858  [https://data.microbiomedata.org/data/nmdc:omp...
# 3859  [https://data.microbiomedata.org/data/nmdc:omp...
# 3860  [https://data.microbiomedata.org/data/nmdc:omp...
# 3861  [https://data.microbiomedata.org/data/nmdc:omp...
# 3862  [https://data.microbiomedata.org/data/nmdc:omp...
#
# [3863 rows x 3 columns]

# %%
# make url column a string (would not work correctly in agg above)
final_df["url"] = final_df["url"].apply(lambda x: ', '.join(map(str, x)))
final_df
# Out:
#      soil_horizon          biosample_id  \
# 0       M horizon  nmdc:bsm-11-00dkyf35
# 1       M horizon  nmdc:bsm-11-02kcw433
# 2       M horizon  nmdc:bsm-11-02n85875
# 3       M horizon  nmdc:bsm-11-034x5t48
# 4       M horizon  nmdc:bsm-11-043hgn06
# ...           ...                   ...
# 3858    O horizon  nmdc:bsm-11-zv1dn095
# 3859    O horizon  nmdc:bsm-11-zvepbm45
# 3860    O horizon  nmdc:bsm-11-zw5rb344
# 3861    O horizon  nmdc:bsm-11-zx7j9919
# 3862    O horizon  nmdc:bsm-11-zxvtgn65
#
#                                                     url
# 0     https://data.microbiomedata.org/data/nmdc:ompr...
# 1     https://data.microbiomedata.org/data/nmdc:ompr...
# 2     https://data.microbiomedata.org/data/nmdc:ompr...
# 3     https://data.microbiomedata.org/data/nmdc:ompr...
# 4     https://data.microbiomedata.org/data/nmdc:ompr...
# ...                                                 ...
# 3858  https://data.microbiomedata.org/data/nmdc:ompr...
# 3859  https://data.microbiomedata.org/data/nmdc:ompr...
# 3860  https://data.microbiomedata.org/data/nmdc:ompr...
# 3861  https://data.microbiomedata.org/data/nmdc:ompr...
# 3862  https://data.microbiomedata.org/data/nmdc:ompr...
#
# [3863 rows x 3 columns]

# %%
# Save to csv to avoid rerunning all cells while notebook in development
final_df.to_csv("metadata_joined_cleaned.csv", index=False)

# %%
# Test df
df_test = final_df[:1]
# df_test

url = df_test.iloc[0]["url"]

print(url)
# Out:
# https://data.microbiomedata.org/data/nmdc:omprc-11-qc8gjy19/nmdc:wfmgan-11-j8jjt181.1/nmdc_wfmgan-11-j8jjt181.1_scaffold_lineage.tsv

# %%
for index, row in df_test.iterrows():

    url = row["url"]

    response = requests.get(url)
    if response.status_code == 200:
        tsv_data = StringIO(response.text)

        tsv_df = pd.read_csv(tsv_data, delimiter="\t")

        # Give columns names
        tsv_df.columns = ["id", "taxa", "percent"]

        # split taxa column into a list where a semicolon (;) is the delimeter
        tsv_df["taxa"] = tsv_df["taxa"].str.split(";")

        # explode and make into a list
        tsv_df_exploded = tsv_df.explode("taxa").reset_index(drop=True)
        taxa_list = tsv_df_exploded["taxa"].tolist()
        print(taxa_list)

    else:
        print("error")
# Out:
# <class 'str'>
